# %%
import cv2
import os
from PySide6.QtWidgets import QApplication, QMainWindow, QWidget, \
    QLabel, QGridLayout, QScrollArea, QSizePolicy, QFileDialog, QMessageBox
from PySide6.QtGui import QPixmap, QIcon, QImage, QPalette, QPainter, QPen, QColor
from PySide6.QtCore import QThread, Signal, Qt, QEvent, QObject, Slot
from PySide6 import QtCore
import sys
import time
import datetime
import json
import numpy as np
from PIL import Image
from onvif_control import *

from face_faiss_db import FaceDB
from embeddings import Embeddings
from ui_Face_Overlay import *
from rknnlite.api import RKNNLite

def extract_filename(file_path):
    full_filename = os.path.basename(file_path)
    filename_without_extension = os.path.splitext(full_filename)[0]
    return filename_without_extension

def read_jpg_files(directory):
    jpg_files = []
    for file in os.listdir(directory):
        if file.lower().endswith('.jpg'):
            jpg_files.append(os.path.join(directory, file))
    return jpg_files

def save_json(path, data):
    """
    numpy.ndarray 타입의 feature를 list로 바꿔서 JSON 저장
    """
    serializable_data = []
    for item in data:
        serializable_item = {
            "name": item["name"],
            "feature": item["feature"].tolist() if isinstance(item["feature"], np.ndarray) else item["feature"]
        }
        serializable_data.append(serializable_item)
    
    with open(path, "w", encoding="utf-8") as f:
        json.dump(serializable_data, f, ensure_ascii=False, indent=4)
    print("저장 완료:", path)

def load_json(path):
    """
    JSON을 불러온 후 list → numpy.ndarray 로 복원
    """
    with open(path, "r", encoding="utf-8") as f:
        loaded = json.load(f)
    
    for item in loaded:
        item["feature"] = np.array(item["feature"])
    print("불러오기 완료:", path)
    return loaded

class VideoThread(QThread):
    frame_update = Signal(np.ndarray)
    face_update = Signal(np.ndarray)

    def __init__(self, rtsp_url, resize_size=None, overlay_path=None, overlay_ok_path=None, overlay_size=None, crop_rect=None):
        super().__init__()
        self.rtsp_url = rtsp_url
        self.resize_size = resize_size
        self.overlay_path = overlay_path
        self.overlay_ok_path = overlay_ok_path
        self.overlay_size = overlay_size
        self.crop_rect = crop_rect
        #self.overlay_point = (60, 30)
        self.overlay_point = (
            int((self.crop_rect[2] - self.crop_rect[0]) / 2 - self.overlay_size[0] / 2),
            int((self.crop_rect[3] - self.crop_rect[1]) / 2 - self.overlay_size[1] / 2)
        )
        self.running = True
        self.embeddings = Embeddings('./RetinaFace_mobile320_i8_v2.3.2.rknn', './rk3588_mobilefacenet/mobilefacenet_v2.3.2.rknn')
        self.embedder_ret = None
        #self.process = False

        overlay = Image.open(self.overlay_path).convert("RGBA")
        self.overlay_resized = overlay.resize(self.overlay_size)

        overlay = Image.open(self.overlay_ok_path).convert("RGBA")
        self.overlay_ok_resized = overlay.resize(self.overlay_size)

        self.face_check = False

    def run(self):
        cap = cv2.VideoCapture(self.rtsp_url)

        while self.running:
            ret, frame = cap.read()
            if not ret:
                continue

            if self.resize_size:
                frame = cv2.resize(frame, self.resize_size, interpolation=cv2.INTER_AREA)

            if self.crop_rect:
                x1, y1, x2, y2 = self.crop_rect
                self.crop_frame = frame[y1:y2, x1:x2].copy()

            #if overlay_resized is not None:
            #    frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).convert("RGBA")
            #    frame_pil.paste(overlay_resized, self.overlay_point, overlay_resized)
            #    frame = cv2.cvtColor(np.array(frame_pil), cv2.COLOR_RGBA2BGR)
            retina_ret = self.embeddings.retinaface.get_faces(self.crop_frame)
            
            if not self.face_check:
                self.embedder_ret = []
                # LeftEye: 145, 185, RightEye: 229, 181
                # LeftEye: 137, 156, RightEye: 217, 149
                # LeftEye: 114, 169, RightEye: 201, 160
                # LeftEye: 129, 175, RightEye: 193, 160
                for face in retina_ret:
                    '''
                    if (175 <= face['nose'][0] <= 220) and ( 175 <= face['nose'][1] <= 220 ):                    
                        embedding = self.embeddings.mobilefacenet.get_feat(face['face'])
                        self.embedder_ret.append({'score': face['score'], 'embedding': embedding})
                        self.face_check = True
                        #self.process = True
                        self.face_update.emit(face['face_crop'])
                    else:
                        self.face_check = False
                    '''

                    if  ( 110 <= face['leftEyeCenter'][0] <= 160 ) and ( 150 <= face['leftEyeCenter'][1] <= 200 ) and ( 190 <= face['rightEyeCenter'][0] <= 250 ) and ( 140 <= face['rightEyeCenter'][1] <= 200 ):
                        embedding = self.embeddings.mobilefacenet.get_feat(face['face'])
                        self.embedder_ret.append({'score': face['score'], 'embedding': embedding})
                        self.face_check = True
                        #self.process = True
                        self.face_update.emit(face['face_crop'])
                    else:
                        self.face_check = False
                        
                    print(f"LeftEye: {face['leftEyeCenter'][0]}, {face['leftEyeCenter'][1]}, RightEye: {face['rightEyeCenter'][0]}, {face['rightEyeCenter'][1]}")

            self.frame_update.emit(self.crop_frame)

        cap.release()

    def stop(self):
        self.running = False
        self.wait()

class MyWindow(QMainWindow, Ui_MainWindow) :
    def __init__(self) :
        super().__init__()
        self.resize_size=(640, 360)
        self.crop_rect=(140, 0, 500, 360)
        self.overlay_size=(300, 300)
        self.face_size=(128, 128)
        self.images = read_jpg_files('./img')
        self.setupUi(self)

        # Thread 1 - 그림1
        self.camera = VideoThread(
            "rtsp://darkice:sys3275423@192.168.0.166:554/stream2",
            resize_size=self.resize_size,
            overlay_path="facial-recognition.png",
            overlay_ok_path="facial-recognition_ok.png",
            overlay_size=self.overlay_size,
            #crop_rect=(0, 0, 640, 360)  # x1, y1, x2, y2
            #crop_rect=(140, 0, 500, 360)
            crop_rect=self.crop_rect
        )
        self.camera.frame_update.connect(self.update_overlay)
        self.camera.face_update.connect(self.update_face)
        self.db = FaceDB(dim=128, db_path="./")
        self.save_db()

        camera_ip = '192.168.0.166'  # 카메라 IP 주소
        camera_port = 2020  # 카메라 포트 번호
        camera_user = 'darkice'  # 사용자 이름
        camera_password = 'sys3275423'  # 비밀번호
        self.cam = OnvifCamera(camera_ip, camera_port, camera_user, camera_password, './wsdl')
        a = self.cam.absolute_move( 0, 0, 0, 1)
        self.camera.start()

    def save_db(self):
        for j in range(len(self.images)):
            img2 = cv2.imread(self.images[j])
            get_face2 = self.camera.embeddings.get_embeddings(img2)
            personname = extract_filename(self.images[j])
            for i in range(len(get_face2)):
                feature = get_face2[i]['embedding']
                #print(f'feature: {type(feature)}')
            #embedding = {'feature' : feature, 'personname' : personname}
            #features.append(embedding)
            a = self.db.search_by_name(personname)
            if a is not None:
                #print(f'Embedding for {personname} already exists in the database.')
                continue
            else:
                self.db.add(personname, feature)

    def update_overlay(self, frame):

        if self.camera.overlay_path is not None:
            frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).convert("RGBA")
            if self.camera.face_check:
                frame_pil.paste(self.camera.overlay_ok_resized, self.camera.overlay_point, self.camera.overlay_ok_resized)
                result = self.db.search(self.camera.embedder_ret[0]['embedding'])
                if result:
                    #print(f'Face recognized: {result[0]["name"]}')
                    self.lineEdit.setText(result[0]["name"])
                else:
                    #print('Face not recognized')
                    self.lineEdit.setText("모름!!")

                self.camera.face_check = False
            else:
                frame_pil.paste(self.camera.overlay_resized, self.camera.overlay_point, self.camera.overlay_resized)
                self.lineEdit.setText("모름!!")

            frame_overlay = cv2.cvtColor(np.array(frame_pil), cv2.COLOR_RGBA2BGR)
        else:
            frame_overlay = frame

        h, w, ch = frame_overlay.shape
        qimg = QImage(frame_overlay.data, w, h, ch * w, QImage.Format_BGR888)
        pix = QPixmap.fromImage(qimg).scaled(
            self.label.width(), self.label.height(),
            Qt.KeepAspectRatio, Qt.SmoothTransformation
        )
        self.label.setPixmap(pix)

    def update_face(self, frame):
        frame_face = cv2.resize(frame, self.face_size, interpolation=cv2.INTER_AREA)
        h, w, ch = frame_face.shape
        qimg = QImage(frame_face.data, w, h, ch * w, QImage.Format_BGR888)
        pix = QPixmap.fromImage(qimg).scaled(
            self.label_2.width(), self.label_2.height(),
            Qt.KeepAspectRatio, Qt.SmoothTransformation
        )
        self.label_2.setPixmap(pix)

    def save_button_clicked(self):
        # Handle push button click event
        #pass
        print("Push button clicked")
        
        name = self.lineEdit_2.text()  # 예: "capture"
        base_path = "./img/"
        ext = ".jpg"

        # 처음 시도할 파일명
        save_path = os.path.join(base_path, name + ext)

        # 파일이 존재하면 뒤에 _1, _2 ... 붙이기
        counter = 0
        while os.path.exists(save_path):
            counter += 1
            save_path = os.path.join(base_path, f"{name}_{counter}{ext}")
            
        cv2.imwrite(save_path, self.camera.crop_frame)
        self.images.append(save_path)
        #self.images = read_jpg_files('./img')
        #img2 = cv2.imread(self.images[j])
        get_face = self.camera.embeddings.get_embeddings(self.camera.crop_frame)
        personname = extract_filename(save_path)
        for i in range(len(get_face)):
            feature = get_face[i]['embedding']
        self.db.add(personname, feature)

    def up_button_clicked(self):
        a = self.cam.relative_move( 0, -0.1, 0, 1)

    def down_button_clicked(self):
        a = self.cam.relative_move( 0, 0.1, 0, 1)

    def right_button_clicked(self):
        a = self.cam.relative_move( 0.05, 0, 0, 1)

    def left_button_clicked(self):
        a = self.cam.relative_move( -0.05, 0, 0, 1)

    def db_button_clicked(self):
        # 데이터베이스 초기화
        if os.path.exists(self.db.index_file):   # 파일 존재 확인
            os.remove(self.db.index_file)
            os.remove(self.db.meta_file)

        self.images = read_jpg_files('./img')
        self.db = FaceDB(dim=128, db_path="./")
        self.save_db()
        print("데이터베이스 초기화 완료")

    def closeEvent(self, event):
        self.camera.stop()
        event.accept()

if __name__ == "__main__":
    import sys
    if not QApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QApplication.instance()

    myWindow = MyWindow() 
    myWindow.show()
    sys.exit(app.exec())
# Out:
# INFO:faiss.loader:Loading faiss.
# INFO:faiss.loader:Successfully loaded faiss.
# W rknn-toolkit-lite2 version: 2.3.2
# W Query dynamic range failed. Ret code: RKNN_ERR_MODEL_INVALID. (If it is a static shape RKNN model, please ignore the above warning message.)
# W rknn-toolkit-lite2 version: 2.3.2
# W Query dynamic range failed. Ret code: RKNN_ERR_MODEL_INVALID. (If it is a static shape RKNN model, please ignore the above warning message.)
# I RKNN: [22:15:36.923] RKNN Runtime Information, librknnrt version: 2.3.2 (429f97ae6b@2025-04-09T09:09:27)
# I RKNN: [22:15:36.924] RKNN Driver Information, version: 0.9.8
# I RKNN: [22:15:36.925] RKNN Model Information, version: 6, toolkit version: 2.3.2(compiler version: 2.3.2 (e045de294f@2025-04-07T19:48:25)), target: RKNPU v2, target platform: rk3588, framework name: ONNX, framework layout: NCHW, model inference type: static_shape
# W RKNN: [22:15:36.949] query RKNN_QUERY_INPUT_DYNAMIC_RANGE error, rknn model is static shape type, please export rknn with dynamic_shapes
# I RKNN: [22:15:37.048] RKNN Runtime Information, librknnrt version: 2.3.2 (429f97ae6b@2025-04-09T09:09:27)
# I RKNN: [22:15:37.048] RKNN Driver Information, version: 0.9.8
# I RKNN: [22:15:37.048] RKNN Model Information, version: 6, toolkit version: 2.3.2(compiler version: 2.3.2 (e045de294f@2025-04-07T19:48:25)), target: RKNPU v2, target platform: rk3588, framework name: Caffe, framework layout: NCHW, model inference type: static_shape
# W RKNN: [22:15:37.053] query RKNN_QUERY_INPUT_DYNAMIC_RANGE error, rknn model is static shape type, please export rknn with dynamic_shapes
# LeftEye: 129, 279, RightEye: 191, 276
# LeftEye: 126, 276, RightEye: 191, 276
# LeftEye: 127, 281, RightEye: 189, 276
# LeftEye: 127, 281, RightEye: 189, 279
# LeftEye: 127, 280, RightEye: 189, 279
# LeftEye: 126, 276, RightEye: 186, 275
# LeftEye: 129, 276, RightEye: 189, 273
# LeftEye: 126, 275, RightEye: 191, 271
# LeftEye: 129, 276, RightEye: 190, 271
# LeftEye: 127, 279, RightEye: 186, 270
# LeftEye: 127, 280, RightEye: 189, 271
# LeftEye: 129, 280, RightEye: 190, 273
# LeftEye: 126, 282, RightEye: 190, 275
# LeftEye: 127, 276, RightEye: 186, 271
# LeftEye: 127, 276, RightEye: 185, 272
# LeftEye: 129, 276, RightEye: 189, 274
# LeftEye: 129, 279, RightEye: 184, 274
# LeftEye: 130, 274, RightEye: 186, 275
# LeftEye: 133, 276, RightEye: 189, 282
# LeftEye: 132, 274, RightEye: 189, 281
# LeftEye: 137, 271, RightEye: 191, 281
# LeftEye: 139, 270, RightEye: 193, 279
# LeftEye: 154, 265, RightEye: 203, 274
# LeftEye: 149, 267, RightEye: 199, 274
# LeftEye: 150, 267, RightEye: 202, 273
# LeftEye: 149, 271, RightEye: 201, 274
# LeftEye: 154, 268, RightEye: 202, 272
# LeftEye: 139, 272, RightEye: 192, 279
# LeftEye: 147, 271, RightEye: 194, 274
# LeftEye: 146, 273, RightEye: 195, 275
# LeftEye: 144, 273, RightEye: 191, 276
# LeftEye: 138, 274, RightEye: 184, 279
# LeftEye: 135, 279, RightEye: 181, 275
# LeftEye: 135, 276, RightEye: 178, 275
# LeftEye: 138, 276, RightEye: 180, 274
# LeftEye: 137, 276, RightEye: 177, 274
# LeftEye: 136, 280, RightEye: 175, 275
# LeftEye: 136, 281, RightEye: 175, 276
# LeftEye: 142, 279, RightEye: 183, 275
# LeftEye: 148, 280, RightEye: 180, 277
# LeftEye: 145, 276, RightEye: 185, 275
# LeftEye: 148, 279, RightEye: 186, 274
# LeftEye: 148, 279, RightEye: 190, 275
# LeftEye: 153, 279, RightEye: 190, 273
# LeftEye: 149, 279, RightEye: 183, 276
# LeftEye: 148, 280, RightEye: 183, 276
# LeftEye: 146, 279, RightEye: 183, 275
# LeftEye: 146, 279, RightEye: 185, 275
# LeftEye: 145, 280, RightEye: 182, 275
# LeftEye: 142, 280, RightEye: 180, 275
# LeftEye: 142, 280, RightEye: 180, 275
# LeftEye: 144, 280, RightEye: 181, 275
# LeftEye: 146, 280, RightEye: 183, 275
# LeftEye: 145, 281, RightEye: 184, 279
# LeftEye: 145, 280, RightEye: 185, 279
# LeftEye: 144, 281, RightEye: 181, 275
# LeftEye: 141, 283, RightEye: 174, 279
# LeftEye: 141, 286, RightEye: 174, 280
# LeftEye: 139, 286, RightEye: 171, 281
# LeftEye: 141, 286, RightEye: 171, 283
# LeftEye: 139, 280, RightEye: 169, 279
# LeftEye: 139, 280, RightEye: 172, 279
# LeftEye: 139, 282, RightEye: 172, 279
# LeftEye: 139, 282, RightEye: 177, 276
# LeftEye: 144, 279, RightEye: 180, 276
# LeftEye: 138, 281, RightEye: 174, 275
# LeftEye: 144, 279, RightEye: 184, 274
# LeftEye: 142, 281, RightEye: 181, 275
# LeftEye: 137, 281, RightEye: 178, 279
# LeftEye: 141, 282, RightEye: 183, 276
# LeftEye: 141, 280, RightEye: 185, 276
# LeftEye: 138, 283, RightEye: 189, 279
# LeftEye: 141, 283, RightEye: 193, 276
# LeftEye: 139, 282, RightEye: 186, 279
# LeftEye: 138, 283, RightEye: 186, 279
# LeftEye: 141, 284, RightEye: 185, 279
# LeftEye: 142, 283, RightEye: 185, 275
# LeftEye: 142, 281, RightEye: 186, 275
# LeftEye: 142, 280, RightEye: 190, 274
# LeftEye: 132, 285, RightEye: 180, 282
# LeftEye: 136, 286, RightEye: 184, 282
# LeftEye: 137, 283, RightEye: 185, 276
# LeftEye: 137, 283, RightEye: 184, 276
# LeftEye: 138, 282, RightEye: 183, 275
# LeftEye: 136, 283, RightEye: 182, 280
# LeftEye: 133, 283, RightEye: 178, 280
# LeftEye: 130, 282, RightEye: 174, 275
# LeftEye: 127, 282, RightEye: 173, 275
# LeftEye: 126, 283, RightEye: 174, 283
# LeftEye: 124, 282, RightEye: 173, 285
# LeftEye: 124, 283, RightEye: 174, 285
# LeftEye: 123, 283, RightEye: 176, 285
# LeftEye: 127, 281, RightEye: 177, 282
# LeftEye: 127, 283, RightEye: 174, 282
# LeftEye: 130, 285, RightEye: 178, 282
# LeftEye: 133, 282, RightEye: 182, 283
# LeftEye: 132, 282, RightEye: 182, 283
# LeftEye: 135, 282, RightEye: 182, 280
# LeftEye: 132, 285, RightEye: 181, 282
# LeftEye: 135, 285, RightEye: 184, 283
# LeftEye: 133, 282, RightEye: 182, 282
# LeftEye: 133, 283, RightEye: 185, 285
# LeftEye: 131, 283, RightEye: 185, 288
# LeftEye: 127, 283, RightEye: 184, 288
# LeftEye: 129, 283, RightEye: 184, 288
# LeftEye: 129, 282, RightEye: 184, 288
# LeftEye: 129, 282, RightEye: 183, 286
# LeftEye: 129, 282, RightEye: 184, 288
# LeftEye: 126, 283, RightEye: 183, 289
# LeftEye: 127, 283, RightEye: 184, 291
# LeftEye: 129, 283, RightEye: 183, 289
# LeftEye: 132, 282, RightEye: 185, 288
# LeftEye: 130, 282, RightEye: 184, 286
# LeftEye: 130, 281, RightEye: 184, 288
# LeftEye: 131, 282, RightEye: 184, 288
# LeftEye: 130, 282, RightEye: 184, 288
# LeftEye: 132, 282, RightEye: 185, 288
# LeftEye: 131, 282, RightEye: 184, 288
# LeftEye: 130, 282, RightEye: 184, 288
# LeftEye: 130, 282, RightEye: 183, 288
# LeftEye: 133, 283, RightEye: 189, 286
# LeftEye: 132, 283, RightEye: 186, 288
# LeftEye: 133, 282, RightEye: 191, 288
# LeftEye: 144, 281, RightEye: 199, 286
# LeftEye: 146, 279, RightEye: 202, 284
# LeftEye: 137, 280, RightEye: 193, 289
# LeftEye: 139, 281, RightEye: 194, 288
# LeftEye: 141, 279, RightEye: 196, 286
# LeftEye: 137, 280, RightEye: 192, 288
# LeftEye: 136, 279, RightEye: 192, 288
# LeftEye: 133, 280, RightEye: 191, 286
# LeftEye: 135, 279, RightEye: 192, 288
# LeftEye: 133, 279, RightEye: 191, 286
# LeftEye: 133, 279, RightEye: 191, 285
# LeftEye: 132, 277, RightEye: 190, 286
# LeftEye: 133, 279, RightEye: 190, 286
# LeftEye: 133, 279, RightEye: 190, 286
# LeftEye: 127, 280, RightEye: 185, 285
# LeftEye: 126, 281, RightEye: 184, 285
# LeftEye: 132, 280, RightEye: 190, 286
# LeftEye: 131, 281, RightEye: 189, 288
# LeftEye: 127, 280, RightEye: 185, 284
# LeftEye: 126, 279, RightEye: 186, 283
# LeftEye: 129, 274, RightEye: 190, 280
# LeftEye: 130, 273, RightEye: 190, 274
# LeftEye: 131, 274, RightEye: 192, 275
# LeftEye: 135, 274, RightEye: 195, 276
# LeftEye: 133, 274, RightEye: 196, 280
# LeftEye: 135, 275, RightEye: 198, 276
# LeftEye: 135, 275, RightEye: 196, 276
# LeftEye: 135, 275, RightEye: 196, 276
# LeftEye: 133, 276, RightEye: 198, 279
# LeftEye: 133, 275, RightEye: 199, 276
# LeftEye: 133, 276, RightEye: 198, 276
# LeftEye: 132, 275, RightEye: 198, 276
# LeftEye: 132, 275, RightEye: 195, 274
# LeftEye: 133, 279, RightEye: 195, 274
# LeftEye: 132, 275, RightEye: 193, 274
# LeftEye: 131, 279, RightEye: 194, 275
# LeftEye: 131, 279, RightEye: 194, 274
# LeftEye: 131, 276, RightEye: 194, 275
# LeftEye: 131, 279, RightEye: 194, 275
# LeftEye: 130, 279, RightEye: 193, 274
# LeftEye: 131, 276, RightEye: 194, 274
# LeftEye: 131, 276, RightEye: 194, 274
# LeftEye: 130, 276, RightEye: 194, 274
# LeftEye: 131, 276, RightEye: 195, 274
# LeftEye: 132, 279, RightEye: 195, 275
# LeftEye: 133, 279, RightEye: 195, 275
# LeftEye: 133, 279, RightEye: 196, 275
# LeftEye: 132, 279, RightEye: 196, 275
# LeftEye: 133, 279, RightEye: 196, 275
# LeftEye: 133, 276, RightEye: 198, 275
# LeftEye: 135, 275, RightEye: 198, 275
# LeftEye: 133, 276, RightEye: 199, 275
# LeftEye: 133, 279, RightEye: 198, 276
# LeftEye: 132, 279, RightEye: 196, 279
# LeftEye: 133, 280, RightEye: 196, 279
# LeftEye: 132, 280, RightEye: 196, 279
# LeftEye: 130, 275, RightEye: 199, 281
# LeftEye: 130, 276, RightEye: 198, 280
# LeftEye: 130, 276, RightEye: 198, 281
# LeftEye: 131, 280, RightEye: 198, 284
# LeftEye: 131, 281, RightEye: 198, 284
# LeftEye: 131, 280, RightEye: 198, 283
# LeftEye: 129, 279, RightEye: 198, 281
# LeftEye: 131, 276, RightEye: 198, 281
# LeftEye: 131, 274, RightEye: 198, 279
# LeftEye: 131, 275, RightEye: 199, 280
# LeftEye: 132, 276, RightEye: 198, 281
# LeftEye: 131, 276, RightEye: 199, 281
# LeftEye: 131, 275, RightEye: 198, 279
# LeftEye: 130, 276, RightEye: 195, 280
# LeftEye: 132, 275, RightEye: 199, 280
# LeftEye: 132, 275, RightEye: 198, 279
# LeftEye: 132, 274, RightEye: 199, 277
# LeftEye: 132, 274, RightEye: 198, 277
# LeftEye: 131, 274, RightEye: 195, 279
# LeftEye: 132, 275, RightEye: 198, 279
# LeftEye: 132, 275, RightEye: 199, 277
# LeftEye: 132, 274, RightEye: 198, 277
# LeftEye: 131, 273, RightEye: 198, 276
# LeftEye: 131, 275, RightEye: 196, 279
# LeftEye: 132, 275, RightEye: 198, 279
# LeftEye: 132, 274, RightEye: 199, 277
# LeftEye: 131, 275, RightEye: 195, 279
# LeftEye: 131, 275, RightEye: 196, 279
# LeftEye: 131, 275, RightEye: 198, 280
# LeftEye: 135, 274, RightEye: 200, 277
# LeftEye: 131, 275, RightEye: 196, 276
# LeftEye: 132, 274, RightEye: 198, 277
# LeftEye: 135, 274, RightEye: 198, 276
# LeftEye: 132, 273, RightEye: 198, 276
# LeftEye: 135, 273, RightEye: 199, 277
# LeftEye: 135, 274, RightEye: 198, 276
# LeftEye: 135, 275, RightEye: 198, 277
# LeftEye: 136, 275, RightEye: 198, 277
# LeftEye: 136, 274, RightEye: 199, 277
# LeftEye: 135, 274, RightEye: 198, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 200, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 200, 279
# LeftEye: 135, 276, RightEye: 200, 277
# LeftEye: 135, 276, RightEye: 199, 277
# LeftEye: 135, 276, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 276, RightEye: 199, 279
# LeftEye: 135, 276, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 276, RightEye: 198, 279
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 274, RightEye: 200, 279
# LeftEye: 135, 275, RightEye: 200, 277
# LeftEye: 132, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 275, RightEye: 199, 277
# LeftEye: 135, 276, RightEye: 199, 277
# LeftEye: 132, 275, RightEye: 198, 277
# LeftEye: 132, 275, RightEye: 199, 277
# LeftEye: 135, 276, RightEye: 200, 277
# LeftEye: 132, 277, RightEye: 198, 279
# LeftEye: 131, 277, RightEye: 196, 279
# LeftEye: 131, 276, RightEye: 198, 277
# LeftEye: 131, 277, RightEye: 198, 279
# LeftEye: 130, 276, RightEye: 196, 279
# LeftEye: 130, 277, RightEye: 196, 279
# LeftEye: 129, 276, RightEye: 196, 279
# LeftEye: 129, 275, RightEye: 193, 279
# LeftEye: 129, 275, RightEye: 196, 280
# LeftEye: 129, 275, RightEye: 196, 279
# LeftEye: 127, 274, RightEye: 192, 280
# LeftEye: 124, 275, RightEye: 187, 281
# LeftEye: 118, 274, RightEye: 183, 281
# LeftEye: 118, 275, RightEye: 185, 281
# LeftEye: 117, 274, RightEye: 180, 285
# LeftEye: 119, 275, RightEye: 178, 283
# LeftEye: 121, 275, RightEye: 183, 283
# LeftEye: 122, 280, RightEye: 182, 281
# LeftEye: 120, 276, RightEye: 181, 283
# LeftEye: 120, 276, RightEye: 181, 283
# LeftEye: 121, 276, RightEye: 182, 283
# LeftEye: 121, 277, RightEye: 182, 282
# LeftEye: 120, 279, RightEye: 181, 283
# LeftEye: 119, 280, RightEye: 177, 284
# LeftEye: 121, 279, RightEye: 181, 283
# LeftEye: 120, 281, RightEye: 178, 283
# LeftEye: 120, 280, RightEye: 178, 283
# LeftEye: 118, 281, RightEye: 177, 285
# LeftEye: 120, 280, RightEye: 180, 285
# LeftEye: 121, 282, RightEye: 180, 286
# LeftEye: 122, 282, RightEye: 181, 286
# LeftEye: 122, 281, RightEye: 182, 289
# LeftEye: 121, 281, RightEye: 181, 289
# LeftEye: 122, 281, RightEye: 182, 288
# LeftEye: 122, 283, RightEye: 180, 288
# LeftEye: 123, 283, RightEye: 181, 286
# LeftEye: 122, 281, RightEye: 180, 285
# LeftEye: 123, 281, RightEye: 180, 286
# LeftEye: 117, 281, RightEye: 174, 286
# LeftEye: 120, 282, RightEye: 178, 286
# LeftEye: 120, 282, RightEye: 177, 286
# LeftEye: 119, 281, RightEye: 177, 285
# LeftEye: 119, 280, RightEye: 177, 285
# LeftEye: 118, 279, RightEye: 175, 285
# LeftEye: 120, 282, RightEye: 176, 286
# LeftEye: 119, 283, RightEye: 176, 286
# LeftEye: 120, 282, RightEye: 177, 286
# LeftEye: 119, 283, RightEye: 176, 286
# LeftEye: 121, 283, RightEye: 177, 286
# LeftEye: 120, 282, RightEye: 178, 285
# LeftEye: 120, 281, RightEye: 181, 282
# LeftEye: 122, 277, RightEye: 181, 281
# LeftEye: 122, 279, RightEye: 181, 281
# LeftEye: 122, 276, RightEye: 180, 280
# LeftEye: 123, 280, RightEye: 180, 283
# LeftEye: 126, 281, RightEye: 184, 285
# LeftEye: 124, 282, RightEye: 182, 284
# LeftEye: 123, 281, RightEye: 182, 283
# LeftEye: 145, 279, RightEye: 201, 279
# LeftEye: 122, 284, RightEye: 182, 285
# LeftEye: 130, 283, RightEye: 191, 285
# LeftEye: 129, 284, RightEye: 189, 285
# LeftEye: 129, 283, RightEye: 191, 286
# LeftEye: 145, 279, RightEye: 199, 276
# LeftEye: 144, 279, RightEye: 199, 280
# LeftEye: 129, 284, RightEye: 190, 286
# LeftEye: 147, 276, RightEye: 204, 276
# LeftEye: 147, 276, RightEye: 203, 276
# LeftEye: 146, 276, RightEye: 204, 276
# LeftEye: 146, 276, RightEye: 204, 276
# LeftEye: 136, 275, RightEye: 191, 280
# LeftEye: 136, 274, RightEye: 191, 279
# LeftEye: 137, 275, RightEye: 192, 279
# LeftEye: 132, 276, RightEye: 186, 280
# LeftEye: 133, 276, RightEye: 186, 280
# LeftEye: 133, 276, RightEye: 189, 280
# LeftEye: 127, 276, RightEye: 183, 281
# LeftEye: 130, 276, RightEye: 184, 281
# LeftEye: 130, 275, RightEye: 183, 280
# LeftEye: 129, 275, RightEye: 185, 282
# LeftEye: 126, 275, RightEye: 181, 281
# LeftEye: 128, 274, RightEye: 185, 282
# LeftEye: 130, 275, RightEye: 186, 282
# LeftEye: 130, 274, RightEye: 187, 281
# LeftEye: 131, 275, RightEye: 189, 282
# LeftEye: 132, 274, RightEye: 189, 282
# LeftEye: 131, 275, RightEye: 186, 282
# LeftEye: 130, 274, RightEye: 186, 282
# LeftEye: 132, 274, RightEye: 189, 281
# LeftEye: 131, 275, RightEye: 186, 283
# LeftEye: 129, 276, RightEye: 183, 280
# LeftEye: 131, 276, RightEye: 184, 281
# LeftEye: 131, 274, RightEye: 186, 282
# LeftEye: 130, 276, RightEye: 185, 283
# LeftEye: 130, 276, RightEye: 185, 283
# LeftEye: 129, 275, RightEye: 184, 282
# LeftEye: 130, 275, RightEye: 185, 282
# LeftEye: 130, 275, RightEye: 185, 282
# LeftEye: 129, 275, RightEye: 185, 283
# LeftEye: 129, 275, RightEye: 184, 283
# LeftEye: 130, 275, RightEye: 185, 283
# LeftEye: 131, 275, RightEye: 186, 281
# LeftEye: 132, 275, RightEye: 185, 280
# LeftEye: 135, 275, RightEye: 189, 282
# LeftEye: 135, 274, RightEye: 190, 281
# LeftEye: 133, 276, RightEye: 186, 280
# LeftEye: 135, 276, RightEye: 189, 282
# LeftEye: 131, 279, RightEye: 184, 283
# LeftEye: 132, 279, RightEye: 185, 282
# LeftEye: 136, 276, RightEye: 191, 281
# LeftEye: 135, 276, RightEye: 189, 282
# LeftEye: 135, 275, RightEye: 189, 283
# LeftEye: 129, 275, RightEye: 183, 284
# LeftEye: 136, 275, RightEye: 189, 281
# LeftEye: 133, 274, RightEye: 185, 282
# LeftEye: 130, 276, RightEye: 183, 282
# LeftEye: 130, 274, RightEye: 185, 282
# LeftEye: 128, 274, RightEye: 183, 282
# LeftEye: 131, 274, RightEye: 184, 280
# LeftEye: 137, 273, RightEye: 191, 282
# LeftEye: 132, 274, RightEye: 187, 281
# LeftEye: 133, 275, RightEye: 186, 281
# LeftEye: 132, 274, RightEye: 187, 281
# LeftEye: 136, 274, RightEye: 190, 281
# LeftEye: 137, 274, RightEye: 191, 279
# LeftEye: 131, 273, RightEye: 186, 280
# LeftEye: 135, 274, RightEye: 189, 281
# LeftEye: 141, 275, RightEye: 194, 279
# LeftEye: 136, 279, RightEye: 190, 280
# LeftEye: 138, 280, RightEye: 191, 279
# LeftEye: 137, 279, RightEye: 193, 283
# LeftEye: 135, 279, RightEye: 191, 283
# LeftEye: 135, 276, RightEye: 192, 283
# LeftEye: 135, 279, RightEye: 192, 283
# LeftEye: 135, 276, RightEye: 192, 283
# LeftEye: 136, 279, RightEye: 193, 283
# LeftEye: 131, 279, RightEye: 189, 283
# LeftEye: 132, 279, RightEye: 190, 283
# LeftEye: 136, 279, RightEye: 191, 284
# LeftEye: 137, 276, RightEye: 192, 284
# LeftEye: 135, 279, RightEye: 191, 284
# LeftEye: 136, 279, RightEye: 191, 284
# LeftEye: 132, 279, RightEye: 190, 284
# LeftEye: 132, 279, RightEye: 190, 283
# LeftEye: 132, 279, RightEye: 189, 283
# LeftEye: 131, 280, RightEye: 186, 282
# LeftEye: 132, 276, RightEye: 189, 282
# LeftEye: 131, 279, RightEye: 185, 282
# LeftEye: 130, 279, RightEye: 184, 283
# LeftEye: 131, 279, RightEye: 186, 283
# LeftEye: 132, 275, RightEye: 189, 283
# LeftEye: 132, 279, RightEye: 186, 282
# LeftEye: 135, 279, RightEye: 190, 281
# LeftEye: 133, 279, RightEye: 189, 282
# LeftEye: 135, 280, RightEye: 190, 281
# LeftEye: 136, 280, RightEye: 190, 282
# LeftEye: 133, 280, RightEye: 189, 282
# LeftEye: 133, 279, RightEye: 186, 282
# LeftEye: 129, 279, RightEye: 183, 283
# LeftEye: 130, 276, RightEye: 184, 283
# LeftEye: 127, 276, RightEye: 183, 283
# LeftEye: 127, 279, RightEye: 183, 283
# LeftEye: 129, 279, RightEye: 183, 283
# LeftEye: 126, 279, RightEye: 181, 283
# LeftEye: 126, 276, RightEye: 182, 283
# LeftEye: 126, 279, RightEye: 182, 283
# LeftEye: 126, 276, RightEye: 183, 283
# LeftEye: 127, 276, RightEye: 183, 282
# LeftEye: 130, 276, RightEye: 185, 282
# LeftEye: 131, 276, RightEye: 185, 282
# LeftEye: 133, 276, RightEye: 189, 282
# LeftEye: 132, 276, RightEye: 186, 282
# LeftEye: 130, 279, RightEye: 184, 282
# LeftEye: 130, 279, RightEye: 183, 282
# LeftEye: 131, 279, RightEye: 185, 282
# LeftEye: 129, 276, RightEye: 183, 281
# LeftEye: 130, 276, RightEye: 183, 281
# LeftEye: 132, 276, RightEye: 185, 280
# LeftEye: 130, 275, RightEye: 184, 283
# LeftEye: 131, 279, RightEye: 184, 281
# LeftEye: 132, 279, RightEye: 185, 281
# LeftEye: 131, 275, RightEye: 186, 282
# LeftEye: 131, 279, RightEye: 184, 281
# LeftEye: 132, 279, RightEye: 185, 281
# LeftEye: 131, 279, RightEye: 184, 282
# LeftEye: 129, 280, RightEye: 183, 282
# LeftEye: 130, 279, RightEye: 183, 281
# LeftEye: 127, 280, RightEye: 182, 282
# LeftEye: 131, 279, RightEye: 185, 281
# LeftEye: 132, 280, RightEye: 185, 281
# LeftEye: 147, 274, RightEye: 193, 275
# LeftEye: 147, 271, RightEye: 194, 273
# LeftEye: 123, 276, RightEye: 177, 282
# LeftEye: 121, 276, RightEye: 174, 280
# LeftEye: 126, 273, RightEye: 180, 279
# LeftEye: 123, 272, RightEye: 176, 281
# LeftEye: 129, 272, RightEye: 181, 279
# LeftEye: 127, 272, RightEye: 183, 280
# LeftEye: 119, 273, RightEye: 176, 281
# LeftEye: 120, 274, RightEye: 176, 282
# LeftEye: 120, 275, RightEye: 177, 282
# LeftEye: 120, 275, RightEye: 176, 283
# LeftEye: 120, 275, RightEye: 177, 284
# LeftEye: 121, 275, RightEye: 178, 284
# LeftEye: 131, 280, RightEye: 187, 284
# LeftEye: 132, 280, RightEye: 190, 285
# LeftEye: 130, 276, RightEye: 189, 284
# LeftEye: 129, 280, RightEye: 186, 284
# LeftEye: 121, 280, RightEye: 178, 284
# LeftEye: 123, 279, RightEye: 183, 283
# LeftEye: 121, 279, RightEye: 177, 284
# LeftEye: 121, 276, RightEye: 174, 280
# LeftEye: 123, 279, RightEye: 177, 283
# LeftEye: 126, 274, RightEye: 180, 281
# LeftEye: 123, 276, RightEye: 177, 282
# LeftEye: 123, 275, RightEye: 180, 283
# LeftEye: 145, 275, RightEye: 199, 280
# LeftEye: 141, 279, RightEye: 193, 281
# LeftEye: 140, 276, RightEye: 191, 280
# LeftEye: 147, 280, RightEye: 196, 281
# LeftEye: 142, 279, RightEye: 193, 282
# LeftEye: 136, 279, RightEye: 190, 280
# LeftEye: 135, 283, RightEye: 185, 288
# LeftEye: 138, 279, RightEye: 190, 280
# LeftEye: 139, 282, RightEye: 190, 285
# LeftEye: 139, 279, RightEye: 187, 276
# LeftEye: 144, 276, RightEye: 193, 274
# LeftEye: 140, 280, RightEye: 189, 276
# LeftEye: 138, 276, RightEye: 185, 275
# LeftEye: 137, 279, RightEye: 184, 275
# LeftEye: 138, 276, RightEye: 186, 275
# LeftEye: 131, 276, RightEye: 180, 276
# LeftEye: 129, 275, RightEye: 178, 279
# LeftEye: 129, 277, RightEye: 178, 280
# LeftEye: 139, 276, RightEye: 180, 277
# LeftEye: 136, 275, RightEye: 178, 277
# LeftEye: 135, 277, RightEye: 176, 277
# LeftEye: 135, 277, RightEye: 176, 277
# LeftEye: 135, 276, RightEye: 176, 275
# LeftEye: 124, 279, RightEye: 173, 279
# LeftEye: 130, 276, RightEye: 180, 276
# LeftEye: 129, 279, RightEye: 180, 276
# LeftEye: 127, 279, RightEye: 177, 276
# LeftEye: 126, 276, RightEye: 175, 276
# LeftEye: 132, 279, RightEye: 181, 276
# LeftEye: 124, 279, RightEye: 180, 276
# LeftEye: 127, 283, RightEye: 180, 286
# LeftEye: 131, 275, RightEye: 182, 274
# LeftEye: 124, 279, RightEye: 177, 276
# LeftEye: 137, 275, RightEye: 185, 273
# LeftEye: 132, 275, RightEye: 181, 274
# LeftEye: 132, 275, RightEye: 182, 274
# LeftEye: 118, 282, RightEye: 168, 285
# LeftEye: 124, 279, RightEye: 174, 279
# LeftEye: 122, 280, RightEye: 171, 281
# LeftEye: 119, 280, RightEye: 173, 280
# LeftEye: 130, 275, RightEye: 180, 274
# LeftEye: 130, 274, RightEye: 182, 275
# LeftEye: 126, 275, RightEye: 178, 276
# LeftEye: 128, 274, RightEye: 181, 276
# LeftEye: 124, 275, RightEye: 177, 276
# LeftEye: 124, 274, RightEye: 177, 279
# LeftEye: 127, 276, RightEye: 177, 279
# LeftEye: 129, 275, RightEye: 178, 279
# LeftEye: 128, 275, RightEye: 177, 280
# LeftEye: 128, 275, RightEye: 178, 280
# LeftEye: 129, 275, RightEye: 180, 279
# LeftEye: 129, 275, RightEye: 178, 279
# LeftEye: 128, 276, RightEye: 177, 279
# LeftEye: 123, 275, RightEye: 175, 280
# LeftEye: 133, 273, RightEye: 184, 275
# LeftEye: 133, 274, RightEye: 181, 276
# LeftEye: 135, 272, RightEye: 185, 274
# LeftEye: 135, 272, RightEye: 185, 274
# LeftEye: 133, 272, RightEye: 183, 275
# LeftEye: 133, 273, RightEye: 181, 275
# LeftEye: 133, 273, RightEye: 182, 274
# LeftEye: 131, 273, RightEye: 180, 276
# LeftEye: 130, 273, RightEye: 177, 276
# LeftEye: 128, 275, RightEye: 178, 281
# LeftEye: 129, 273, RightEye: 177, 276
# LeftEye: 130, 273, RightEye: 178, 276
# LeftEye: 129, 273, RightEye: 178, 276
# LeftEye: 130, 273, RightEye: 180, 276
# LeftEye: 130, 273, RightEye: 178, 276
# LeftEye: 128, 275, RightEye: 176, 280
# LeftEye: 126, 275, RightEye: 175, 279
# LeftEye: 126, 275, RightEye: 176, 279
# LeftEye: 126, 276, RightEye: 175, 280
# LeftEye: 126, 275, RightEye: 176, 280
# LeftEye: 127, 276, RightEye: 176, 280
# LeftEye: 128, 275, RightEye: 178, 280
# LeftEye: 129, 275, RightEye: 178, 280
# LeftEye: 127, 275, RightEye: 177, 280
# LeftEye: 126, 274, RightEye: 177, 279
# LeftEye: 128, 275, RightEye: 177, 280
# LeftEye: 127, 274, RightEye: 178, 279
# LeftEye: 130, 275, RightEye: 180, 280
# LeftEye: 126, 275, RightEye: 176, 279
# LeftEye: 127, 275, RightEye: 177, 279
# LeftEye: 124, 275, RightEye: 175, 279
# LeftEye: 126, 274, RightEye: 177, 279
# LeftEye: 127, 275, RightEye: 177, 279
# LeftEye: 129, 275, RightEye: 178, 279
# LeftEye: 129, 275, RightEye: 177, 279
# LeftEye: 129, 275, RightEye: 178, 279
# LeftEye: 127, 274, RightEye: 178, 279
# LeftEye: 129, 276, RightEye: 178, 279
# LeftEye: 127, 274, RightEye: 177, 276
# LeftEye: 127, 275, RightEye: 177, 279
# LeftEye: 126, 273, RightEye: 175, 276
# LeftEye: 128, 274, RightEye: 177, 279
# LeftEye: 123, 274, RightEye: 175, 279
# LeftEye: 124, 274, RightEye: 175, 279
# LeftEye: 124, 274, RightEye: 175, 280
# LeftEye: 123, 275, RightEye: 174, 280
# LeftEye: 123, 274, RightEye: 175, 279
# LeftEye: 126, 274, RightEye: 175, 279
# LeftEye: 124, 274, RightEye: 177, 279
# LeftEye: 124, 274, RightEye: 175, 279
# LeftEye: 127, 275, RightEye: 178, 279
# LeftEye: 126, 276, RightEye: 177, 279
# LeftEye: 127, 276, RightEye: 177, 279
# LeftEye: 128, 275, RightEye: 178, 279
# LeftEye: 128, 275, RightEye: 177, 280
# LeftEye: 126, 275, RightEye: 175, 276
# LeftEye: 126, 275, RightEye: 177, 275
# LeftEye: 126, 274, RightEye: 174, 273
# LeftEye: 127, 274, RightEye: 173, 275
# LeftEye: 130, 273, RightEye: 178, 275
# LeftEye: 139, 271, RightEye: 185, 273
# LeftEye: 124, 273, RightEye: 184, 281
# LeftEye: 127, 271, RightEye: 187, 279
# LeftEye: 120, 271, RightEye: 180, 276
# LeftEye: 121, 271, RightEye: 181, 279
# LeftEye: 121, 271, RightEye: 181, 280
# LeftEye: 121, 271, RightEye: 181, 279
# LeftEye: 121, 271, RightEye: 181, 276
# LeftEye: 121, 270, RightEye: 180, 276
# LeftEye: 127, 270, RightEye: 186, 275
# LeftEye: 130, 270, RightEye: 189, 275
# LeftEye: 123, 271, RightEye: 181, 276
# LeftEye: 135, 271, RightEye: 193, 276
# LeftEye: 128, 271, RightEye: 186, 275
# LeftEye: 136, 271, RightEye: 192, 275
# LeftEye: 132, 271, RightEye: 190, 274
# LeftEye: 132, 272, RightEye: 191, 276
# LeftEye: 131, 272, RightEye: 190, 275
# LeftEye: 136, 272, RightEye: 192, 275
# LeftEye: 136, 272, RightEye: 192, 275
# LeftEye: 131, 272, RightEye: 190, 275
# LeftEye: 132, 272, RightEye: 190, 275
# LeftEye: 131, 273, RightEye: 189, 275
# LeftEye: 131, 272, RightEye: 189, 275
# LeftEye: 127, 272, RightEye: 184, 279
# LeftEye: 121, 273, RightEye: 180, 281
# LeftEye: 127, 271, RightEye: 184, 276
# LeftEye: 131, 271, RightEye: 189, 275
# LeftEye: 136, 272, RightEye: 192, 275
# LeftEye: 132, 273, RightEye: 190, 276
# LeftEye: 137, 271, RightEye: 193, 273
# LeftEye: 138, 273, RightEye: 193, 275
# LeftEye: 136, 273, RightEye: 192, 275
# LeftEye: 137, 271, RightEye: 190, 272
# LeftEye: 153, 271, RightEye: 201, 267
# LeftEye: 153, 271, RightEye: 203, 270
# LeftEye: 153, 270, RightEye: 202, 268
# LeftEye: 151, 271, RightEye: 202, 268
# LeftEye: 153, 273, RightEye: 201, 270
# LeftEye: 148, 273, RightEye: 199, 272
# LeftEye: 147, 271, RightEye: 195, 268
# LeftEye: 145, 272, RightEye: 195, 271
# LeftEye: 144, 272, RightEye: 196, 270
# LeftEye: 137, 273, RightEye: 189, 274
# LeftEye: 137, 275, RightEye: 190, 275
# LeftEye: 140, 275, RightEye: 186, 275
# LeftEye: 138, 274, RightEye: 186, 276
# LeftEye: 136, 276, RightEye: 180, 276
# LeftEye: 136, 275, RightEye: 181, 279
# LeftEye: 132, 276, RightEye: 178, 279
# LeftEye: 135, 275, RightEye: 180, 274
# LeftEye: 132, 276, RightEye: 180, 275
# LeftEye: 124, 276, RightEye: 177, 276
# 데이터베이스 초기화 완료
# LeftEye: 127, 274, RightEye: 178, 276
# LeftEye: 127, 274, RightEye: 178, 275
# LeftEye: 130, 273, RightEye: 181, 275
# LeftEye: 126, 274, RightEye: 178, 276
# LeftEye: 129, 275, RightEye: 180, 276
# LeftEye: 123, 275, RightEye: 173, 279
# LeftEye: 126, 275, RightEye: 178, 276
# LeftEye: 123, 275, RightEye: 173, 279
# LeftEye: 123, 275, RightEye: 174, 279
# LeftEye: 123, 275, RightEye: 174, 276
# LeftEye: 126, 276, RightEye: 174, 276
# LeftEye: 124, 276, RightEye: 174, 276
# LeftEye: 124, 275, RightEye: 174, 276
# LeftEye: 126, 276, RightEye: 175, 276
# LeftEye: 126, 275, RightEye: 175, 276
# LeftEye: 127, 275, RightEye: 177, 276
# LeftEye: 126, 274, RightEye: 177, 275
# LeftEye: 126, 275, RightEye: 175, 276
# LeftEye: 124, 275, RightEye: 174, 276
# LeftEye: 126, 275, RightEye: 174, 276
# LeftEye: 126, 276, RightEye: 175, 279
# LeftEye: 124, 274, RightEye: 174, 276
# LeftEye: 124, 275, RightEye: 175, 276
# LeftEye: 124, 274, RightEye: 174, 276
# LeftEye: 124, 275, RightEye: 174, 276
# LeftEye: 126, 275, RightEye: 175, 276
# LeftEye: 127, 274, RightEye: 177, 276
# LeftEye: 129, 274, RightEye: 177, 275
# LeftEye: 127, 274, RightEye: 177, 275
# LeftEye: 127, 275, RightEye: 175, 275
# LeftEye: 126, 275, RightEye: 174, 275
# LeftEye: 124, 275, RightEye: 175, 276
# LeftEye: 126, 275, RightEye: 177, 276
# LeftEye: 129, 274, RightEye: 178, 275
# LeftEye: 129, 274, RightEye: 178, 275
# LeftEye: 129, 275, RightEye: 178, 275
# LeftEye: 129, 274, RightEye: 178, 275
# LeftEye: 126, 274, RightEye: 177, 276
# LeftEye: 126, 275, RightEye: 177, 276
# LeftEye: 124, 275, RightEye: 175, 276
# LeftEye: 126, 275, RightEye: 175, 276
# LeftEye: 124, 274, RightEye: 175, 276
# LeftEye: 127, 275, RightEye: 177, 276
# LeftEye: 129, 275, RightEye: 178, 275
# LeftEye: 129, 275, RightEye: 178, 275
# LeftEye: 126, 275, RightEye: 177, 275
# LeftEye: 127, 274, RightEye: 177, 275
# LeftEye: 129, 274, RightEye: 180, 274
# LeftEye: 124, 274, RightEye: 175, 274
# LeftEye: 127, 274, RightEye: 178, 275
# LeftEye: 130, 274, RightEye: 180, 274
# LeftEye: 129, 274, RightEye: 178, 273
# LeftEye: 129, 273, RightEye: 180, 273
# LeftEye: 129, 273, RightEye: 178, 274
# LeftEye: 129, 274, RightEye: 178, 274
# LeftEye: 127, 274, RightEye: 178, 274
# LeftEye: 129, 274, RightEye: 178, 275
# LeftEye: 130, 274, RightEye: 181, 274
# LeftEye: 136, 273, RightEye: 178, 274
# LeftEye: 124, 273, RightEye: 175, 274
# LeftEye: 138, 272, RightEye: 182, 273
# LeftEye: 139, 272, RightEye: 182, 273
# LeftEye: 139, 272, RightEye: 183, 273
# LeftEye: 138, 272, RightEye: 182, 273
# LeftEye: 139, 272, RightEye: 182, 273
# LeftEye: 138, 272, RightEye: 182, 273
# LeftEye: 138, 271, RightEye: 182, 273
# LeftEye: 138, 272, RightEye: 182, 273
# LeftEye: 139, 272, RightEye: 183, 273
# LeftEye: 138, 272, RightEye: 182, 274
# LeftEye: 139, 272, RightEye: 183, 273
# LeftEye: 140, 271, RightEye: 185, 272
# LeftEye: 139, 272, RightEye: 184, 273
# LeftEye: 139, 273, RightEye: 184, 273
# LeftEye: 138, 273, RightEye: 183, 273
# LeftEye: 140, 272, RightEye: 185, 272
# LeftEye: 138, 274, RightEye: 181, 274
# LeftEye: 137, 273, RightEye: 181, 274
# LeftEye: 132, 273, RightEye: 182, 272
# LeftEye: 132, 272, RightEye: 182, 272
# LeftEye: 136, 273, RightEye: 180, 275
# LeftEye: 137, 273, RightEye: 180, 274
# LeftEye: 136, 273, RightEye: 181, 274
# LeftEye: 135, 273, RightEye: 180, 275
# LeftEye: 135, 273, RightEye: 180, 274
# LeftEye: 136, 273, RightEye: 180, 275
# LeftEye: 132, 273, RightEye: 177, 275
# LeftEye: 131, 273, RightEye: 174, 276
# LeftEye: 129, 274, RightEye: 175, 276
# LeftEye: 131, 275, RightEye: 178, 279
# LeftEye: 130, 275, RightEye: 175, 279
# LeftEye: 130, 275, RightEye: 175, 276
# LeftEye: 124, 274, RightEye: 178, 273
# LeftEye: 126, 274, RightEye: 180, 275
# LeftEye: 129, 274, RightEye: 180, 273
# LeftEye: 126, 279, RightEye: 177, 275
# LeftEye: 123, 276, RightEye: 177, 274
# LeftEye: 124, 276, RightEye: 178, 275
# LeftEye: 126, 275, RightEye: 180, 274
# LeftEye: 127, 275, RightEye: 181, 273
# LeftEye: 130, 274, RightEye: 183, 273
# LeftEye: 123, 279, RightEye: 174, 275
# LeftEye: 124, 280, RightEye: 178, 279
# LeftEye: 124, 276, RightEye: 178, 276
# LeftEye: 120, 276, RightEye: 175, 279
# LeftEye: 121, 276, RightEye: 182, 280
# LeftEye: 126, 275, RightEye: 184, 276
# LeftEye: 120, 275, RightEye: 178, 280
# LeftEye: 122, 276, RightEye: 178, 280
# LeftEye: 122, 276, RightEye: 178, 280
# LeftEye: 127, 276, RightEye: 181, 279
# LeftEye: 123, 276, RightEye: 178, 276
# LeftEye: 123, 276, RightEye: 177, 279
# LeftEye: 124, 276, RightEye: 181, 279
# LeftEye: 123, 276, RightEye: 178, 279
# LeftEye: 124, 279, RightEye: 180, 276
# LeftEye: 121, 276, RightEye: 175, 279
# LeftEye: 120, 279, RightEye: 175, 280
# LeftEye: 123, 279, RightEye: 174, 285
# LeftEye: 123, 276, RightEye: 173, 282
# LeftEye: 124, 279, RightEye: 175, 283
# LeftEye: 124, 279, RightEye: 175, 283
# LeftEye: 123, 276, RightEye: 174, 282
# LeftEye: 124, 275, RightEye: 177, 282
# LeftEye: 124, 275, RightEye: 175, 282
# LeftEye: 123, 275, RightEye: 175, 283
# LeftEye: 126, 276, RightEye: 177, 282
# LeftEye: 124, 277, RightEye: 175, 282
# LeftEye: 121, 281, RightEye: 174, 286
# LeftEye: 124, 280, RightEye: 175, 286
# LeftEye: 120, 280, RightEye: 173, 286
# LeftEye: 120, 281, RightEye: 172, 286
# LeftEye: 124, 281, RightEye: 174, 286
# LeftEye: 123, 281, RightEye: 174, 285
# LeftEye: 124, 281, RightEye: 174, 286
# LeftEye: 126, 280, RightEye: 173, 284
# LeftEye: 123, 281, RightEye: 174, 286
# LeftEye: 121, 281, RightEye: 173, 286
# LeftEye: 119, 282, RightEye: 171, 288
# LeftEye: 119, 282, RightEye: 168, 286
# LeftEye: 120, 282, RightEye: 171, 286
# LeftEye: 120, 282, RightEye: 171, 286
# LeftEye: 121, 282, RightEye: 173, 286
# LeftEye: 120, 282, RightEye: 172, 286
# LeftEye: 121, 282, RightEye: 172, 286
# LeftEye: 121, 282, RightEye: 173, 286
# LeftEye: 118, 281, RightEye: 172, 286
# LeftEye: 130, 264, RightEye: 174, 268
# LeftEye: 123, 263, RightEye: 175, 271
# LeftEye: 132, 261, RightEye: 178, 270
# LeftEye: 130, 261, RightEye: 173, 271
# LeftEye: 130, 262, RightEye: 178, 272
# LeftEye: 129, 264, RightEye: 178, 275
# LeftEye: 131, 264, RightEye: 178, 272
# LeftEye: 129, 265, RightEye: 175, 273
# LeftEye: 129, 265, RightEye: 178, 275
# LeftEye: 126, 266, RightEye: 173, 280
# LeftEye: 129, 266, RightEye: 173, 280
# LeftEye: 127, 268, RightEye: 167, 277
# LeftEye: 127, 270, RightEye: 166, 281
# LeftEye: 126, 270, RightEye: 165, 279
# LeftEye: 124, 270, RightEye: 162, 280
# LeftEye: 124, 271, RightEye: 163, 280
# LeftEye: 124, 270, RightEye: 165, 280
# LeftEye: 124, 270, RightEye: 165, 280
# LeftEye: 127, 270, RightEye: 167, 281
# LeftEye: 129, 271, RightEye: 166, 281
# LeftEye: 130, 270, RightEye: 168, 281
# LeftEye: 127, 270, RightEye: 166, 279
# LeftEye: 126, 270, RightEye: 169, 280
# LeftEye: 129, 271, RightEye: 166, 280
# LeftEye: 129, 271, RightEye: 166, 280
# LeftEye: 127, 273, RightEye: 166, 280
# LeftEye: 126, 273, RightEye: 168, 280
# LeftEye: 126, 271, RightEye: 168, 280
# LeftEye: 122, 273, RightEye: 166, 283
# LeftEye: 123, 271, RightEye: 169, 283
# LeftEye: 130, 275, RightEye: 165, 279
# LeftEye: 130, 275, RightEye: 162, 276
# LeftEye: 129, 274, RightEye: 160, 276
# LeftEye: 131, 271, RightEye: 166, 275
# LeftEye: 135, 271, RightEye: 171, 275
# LeftEye: 133, 273, RightEye: 168, 275
# LeftEye: 133, 273, RightEye: 173, 276
# LeftEye: 133, 273, RightEye: 171, 275
# LeftEye: 132, 274, RightEye: 172, 276
# LeftEye: 131, 275, RightEye: 171, 276
# LeftEye: 130, 274, RightEye: 169, 277
# LeftEye: 130, 275, RightEye: 169, 277
# LeftEye: 131, 276, RightEye: 172, 277
# LeftEye: 130, 276, RightEye: 172, 279
# LeftEye: 131, 275, RightEye: 173, 277
# LeftEye: 131, 276, RightEye: 173, 279
# LeftEye: 130, 274, RightEye: 174, 273
# LeftEye: 132, 276, RightEye: 167, 276
# LeftEye: 132, 276, RightEye: 174, 276
# LeftEye: 132, 276, RightEye: 172, 279
# LeftEye: 127, 279, RightEye: 169, 279
# LeftEye: 129, 276, RightEye: 173, 279
# LeftEye: 131, 275, RightEye: 174, 274
# LeftEye: 131, 275, RightEye: 174, 274
# LeftEye: 132, 275, RightEye: 173, 272
# LeftEye: 136, 274, RightEye: 174, 272
# LeftEye: 131, 275, RightEye: 174, 272
# LeftEye: 131, 276, RightEye: 171, 273
# LeftEye: 130, 276, RightEye: 168, 273
# LeftEye: 130, 275, RightEye: 171, 274
# LeftEye: 127, 276, RightEye: 167, 274
# LeftEye: 129, 275, RightEye: 169, 273
# LeftEye: 129, 274, RightEye: 167, 271
# LeftEye: 127, 274, RightEye: 167, 272
# LeftEye: 128, 273, RightEye: 167, 271
# LeftEye: 129, 273, RightEye: 163, 271
# LeftEye: 129, 274, RightEye: 167, 271
# LeftEye: 130, 272, RightEye: 167, 270
# LeftEye: 129, 273, RightEye: 168, 272
# LeftEye: 127, 274, RightEye: 165, 272
# LeftEye: 130, 273, RightEye: 165, 271
# LeftEye: 129, 273, RightEye: 165, 272
# LeftEye: 127, 273, RightEye: 163, 272
# LeftEye: 128, 275, RightEye: 165, 272
# LeftEye: 127, 274, RightEye: 160, 273
# LeftEye: 126, 275, RightEye: 160, 273
# LeftEye: 130, 276, RightEye: 159, 276
# LeftEye: 129, 274, RightEye: 162, 273
# LeftEye: 130, 274, RightEye: 163, 272
# LeftEye: 127, 279, RightEye: 164, 272
# LeftEye: 127, 275, RightEye: 162, 272
# LeftEye: 129, 274, RightEye: 165, 273
# LeftEye: 130, 275, RightEye: 164, 272
# LeftEye: 130, 275, RightEye: 165, 272
# LeftEye: 132, 275, RightEye: 159, 274
# LeftEye: 132, 276, RightEye: 159, 275
# LeftEye: 129, 275, RightEye: 163, 273
# LeftEye: 131, 276, RightEye: 158, 275
# LeftEye: 131, 276, RightEye: 158, 275
# LeftEye: 131, 276, RightEye: 158, 275
# LeftEye: 130, 276, RightEye: 158, 275
# LeftEye: 131, 276, RightEye: 158, 275
# LeftEye: 131, 276, RightEye: 159, 275
# LeftEye: 130, 276, RightEye: 158, 275
# LeftEye: 130, 276, RightEye: 160, 275
# LeftEye: 131, 276, RightEye: 159, 275
# LeftEye: 130, 271, RightEye: 166, 271
# LeftEye: 128, 274, RightEye: 165, 272
# LeftEye: 130, 272, RightEye: 165, 271
# LeftEye: 130, 273, RightEye: 165, 273
# LeftEye: 128, 276, RightEye: 163, 274
# LeftEye: 128, 276, RightEye: 162, 274
# LeftEye: 129, 276, RightEye: 164, 273
# LeftEye: 129, 276, RightEye: 164, 273
# LeftEye: 128, 275, RightEye: 165, 273
# LeftEye: 129, 275, RightEye: 165, 273
# LeftEye: 129, 276, RightEye: 165, 273
# LeftEye: 129, 275, RightEye: 164, 273
# LeftEye: 131, 276, RightEye: 158, 275
# LeftEye: 131, 275, RightEye: 160, 275
# LeftEye: 127, 275, RightEye: 156, 273
# LeftEye: 130, 276, RightEye: 155, 275
# LeftEye: 131, 276, RightEye: 156, 275
# LeftEye: 130, 277, RightEye: 157, 276
# LeftEye: 131, 276, RightEye: 160, 273
# LeftEye: 129, 275, RightEye: 160, 273
# LeftEye: 128, 279, RightEye: 164, 273
# LeftEye: 128, 280, RightEye: 162, 274
# LeftEye: 129, 279, RightEye: 163, 274
# LeftEye: 128, 276, RightEye: 163, 273
# LeftEye: 127, 276, RightEye: 162, 274
# LeftEye: 129, 274, RightEye: 167, 268
# LeftEye: 129, 275, RightEye: 167, 268
# LeftEye: 129, 275, RightEye: 167, 267
# LeftEye: 129, 275, RightEye: 166, 268
# LeftEye: 128, 274, RightEye: 167, 268
# LeftEye: 129, 275, RightEye: 167, 268
# LeftEye: 130, 274, RightEye: 167, 268
# LeftEye: 128, 275, RightEye: 167, 270
# LeftEye: 128, 274, RightEye: 166, 270
# LeftEye: 129, 274, RightEye: 168, 268
# LeftEye: 131, 273, RightEye: 173, 267
# LeftEye: 136, 270, RightEye: 177, 263
# LeftEye: 137, 268, RightEye: 178, 262
# LeftEye: 135, 271, RightEye: 176, 263
# LeftEye: 130, 274, RightEye: 172, 270
# LeftEye: 130, 275, RightEye: 172, 271
# LeftEye: 129, 275, RightEye: 172, 271
# LeftEye: 131, 276, RightEye: 172, 274
# LeftEye: 130, 273, RightEye: 175, 268
# LeftEye: 131, 273, RightEye: 175, 268
# LeftEye: 131, 274, RightEye: 177, 273
# LeftEye: 129, 274, RightEye: 173, 271
# LeftEye: 130, 274, RightEye: 174, 271
# LeftEye: 130, 273, RightEye: 174, 272
# LeftEye: 129, 274, RightEye: 174, 271
# LeftEye: 128, 274, RightEye: 173, 272
# LeftEye: 130, 272, RightEye: 175, 270
# LeftEye: 129, 275, RightEye: 172, 274
# LeftEye: 129, 273, RightEye: 173, 272
# LeftEye: 129, 273, RightEye: 172, 270
# LeftEye: 130, 273, RightEye: 172, 270
# LeftEye: 128, 273, RightEye: 173, 271
# LeftEye: 130, 273, RightEye: 173, 270
# LeftEye: 128, 273, RightEye: 172, 271
# LeftEye: 132, 271, RightEye: 175, 268
# LeftEye: 131, 272, RightEye: 174, 270
# LeftEye: 130, 272, RightEye: 173, 268
# LeftEye: 129, 272, RightEye: 173, 270
# LeftEye: 130, 272, RightEye: 173, 270
# LeftEye: 130, 272, RightEye: 173, 271
# LeftEye: 131, 271, RightEye: 176, 270
# LeftEye: 133, 272, RightEye: 178, 272
# LeftEye: 133, 272, RightEye: 175, 273
# LeftEye: 132, 273, RightEye: 174, 273
# LeftEye: 137, 270, RightEye: 182, 271
# LeftEye: 140, 267, RightEye: 180, 270
# LeftEye: 142, 262, RightEye: 185, 264
# LeftEye: 141, 264, RightEye: 185, 268
# LeftEye: 139, 267, RightEye: 183, 272
# LeftEye: 140, 265, RightEye: 183, 268
# LeftEye: 139, 268, RightEye: 182, 271
# LeftEye: 141, 267, RightEye: 183, 267
# LeftEye: 139, 264, RightEye: 181, 267
# LeftEye: 139, 268, RightEye: 180, 270
# LeftEye: 140, 267, RightEye: 180, 268
# LeftEye: 140, 265, RightEye: 183, 268
# LeftEye: 147, 261, RightEye: 186, 264
# LeftEye: 144, 262, RightEye: 186, 264
# LeftEye: 145, 263, RightEye: 186, 267
# LeftEye: 142, 271, RightEye: 182, 272
# LeftEye: 141, 270, RightEye: 182, 272
# LeftEye: 141, 265, RightEye: 183, 268
# LeftEye: 140, 268, RightEye: 181, 272
# LeftEye: 140, 270, RightEye: 181, 273
# LeftEye: 140, 267, RightEye: 183, 270
# LeftEye: 138, 271, RightEye: 183, 270
# LeftEye: 138, 273, RightEye: 182, 272
# LeftEye: 138, 272, RightEye: 184, 272
# LeftEye: 137, 272, RightEye: 183, 273
# LeftEye: 139, 270, RightEye: 184, 271
# LeftEye: 141, 268, RightEye: 185, 270
# LeftEye: 140, 264, RightEye: 185, 265
# LeftEye: 139, 268, RightEye: 185, 270
# LeftEye: 138, 271, RightEye: 183, 271
# LeftEye: 139, 271, RightEye: 184, 272
# LeftEye: 138, 271, RightEye: 184, 272
# LeftEye: 138, 271, RightEye: 183, 270
# LeftEye: 138, 272, RightEye: 183, 272
# LeftEye: 137, 271, RightEye: 184, 271
# LeftEye: 139, 268, RightEye: 185, 270
# LeftEye: 139, 267, RightEye: 183, 267
# LeftEye: 140, 265, RightEye: 183, 265
# LeftEye: 141, 268, RightEye: 186, 268
# LeftEye: 139, 265, RightEye: 184, 267
# LeftEye: 139, 265, RightEye: 183, 267
# LeftEye: 137, 271, RightEye: 183, 270
# LeftEye: 139, 267, RightEye: 181, 265
# LeftEye: 138, 270, RightEye: 178, 267
# LeftEye: 138, 271, RightEye: 184, 270
# LeftEye: 136, 273, RightEye: 183, 272
# LeftEye: 137, 273, RightEye: 183, 271
# LeftEye: 139, 271, RightEye: 184, 270
# LeftEye: 139, 271, RightEye: 183, 270
# LeftEye: 139, 271, RightEye: 183, 270
# LeftEye: 141, 271, RightEye: 182, 270
# LeftEye: 141, 268, RightEye: 183, 267
# LeftEye: 141, 270, RightEye: 183, 268
# LeftEye: 141, 268, RightEye: 183, 268
# LeftEye: 142, 268, RightEye: 184, 267
# LeftEye: 142, 263, RightEye: 184, 264
# LeftEye: 144, 262, RightEye: 184, 263
# LeftEye: 144, 267, RightEye: 185, 265
# LeftEye: 139, 270, RightEye: 183, 270
# LeftEye: 141, 265, RightEye: 183, 265
# LeftEye: 139, 270, RightEye: 182, 270
# LeftEye: 141, 265, RightEye: 183, 265
# LeftEye: 141, 268, RightEye: 182, 270
# LeftEye: 141, 267, RightEye: 182, 270
# LeftEye: 141, 267, RightEye: 182, 268
# LeftEye: 142, 265, RightEye: 186, 265
# LeftEye: 144, 264, RightEye: 189, 264
# LeftEye: 141, 267, RightEye: 186, 267
# LeftEye: 142, 264, RightEye: 185, 264
# LeftEye: 137, 273, RightEye: 181, 275
# LeftEye: 138, 271, RightEye: 181, 273
# LeftEye: 138, 273, RightEye: 182, 275
# LeftEye: 138, 271, RightEye: 183, 274
# LeftEye: 138, 273, RightEye: 182, 276
# LeftEye: 139, 271, RightEye: 184, 273
# LeftEye: 138, 271, RightEye: 180, 273
# LeftEye: 139, 270, RightEye: 181, 272
# LeftEye: 139, 271, RightEye: 182, 274
# LeftEye: 139, 270, RightEye: 181, 270
# LeftEye: 144, 267, RightEye: 183, 268
# LeftEye: 144, 265, RightEye: 178, 264
# LeftEye: 142, 265, RightEye: 177, 265
# LeftEye: 142, 265, RightEye: 178, 267
# LeftEye: 138, 267, RightEye: 174, 268
# LeftEye: 141, 265, RightEye: 174, 267
# LeftEye: 141, 265, RightEye: 174, 267
# LeftEye: 141, 271, RightEye: 178, 271
# LeftEye: 141, 273, RightEye: 174, 271
# LeftEye: 141, 270, RightEye: 180, 268
# LeftEye: 138, 265, RightEye: 174, 267
# LeftEye: 138, 267, RightEye: 174, 268
# LeftEye: 138, 268, RightEye: 177, 268
# LeftEye: 141, 271, RightEye: 180, 268
# LeftEye: 139, 265, RightEye: 175, 265
# LeftEye: 138, 273, RightEye: 177, 271
# LeftEye: 141, 264, RightEye: 177, 265
# LeftEye: 139, 265, RightEye: 175, 264
# LeftEye: 139, 264, RightEye: 177, 265
# LeftEye: 138, 264, RightEye: 175, 264
# LeftEye: 141, 264, RightEye: 181, 265
# LeftEye: 139, 265, RightEye: 178, 265
# LeftEye: 141, 265, RightEye: 178, 267
# LeftEye: 139, 265, RightEye: 175, 265
# LeftEye: 139, 265, RightEye: 177, 265
# LeftEye: 139, 265, RightEye: 175, 265
# LeftEye: 139, 265, RightEye: 178, 264
# LeftEye: 140, 265, RightEye: 181, 264
# LeftEye: 139, 265, RightEye: 178, 264
# LeftEye: 139, 265, RightEye: 178, 264
# LeftEye: 138, 264, RightEye: 175, 264
# LeftEye: 138, 265, RightEye: 175, 264
# LeftEye: 138, 270, RightEye: 181, 268
# LeftEye: 138, 265, RightEye: 175, 265
# LeftEye: 139, 267, RightEye: 173, 265
# LeftEye: 138, 267, RightEye: 174, 267
# LeftEye: 138, 267, RightEye: 174, 265
# LeftEye: 139, 268, RightEye: 174, 265
# LeftEye: 138, 267, RightEye: 174, 265
# LeftEye: 138, 267, RightEye: 177, 265
# LeftEye: 138, 270, RightEye: 182, 270
# LeftEye: 139, 268, RightEye: 175, 265
# LeftEye: 137, 271, RightEye: 181, 271
# LeftEye: 138, 271, RightEye: 181, 270
# LeftEye: 138, 270, RightEye: 172, 267
# LeftEye: 138, 268, RightEye: 172, 265
# LeftEye: 139, 267, RightEye: 174, 264
# LeftEye: 138, 267, RightEye: 173, 265
# LeftEye: 138, 265, RightEye: 174, 264
# LeftEye: 137, 270, RightEye: 181, 272
# LeftEye: 136, 268, RightEye: 174, 267
# LeftEye: 136, 267, RightEye: 173, 267
# LeftEye: 136, 267, RightEye: 173, 267
# LeftEye: 136, 267, RightEye: 174, 267
# LeftEye: 136, 267, RightEye: 173, 267
# LeftEye: 136, 267, RightEye: 173, 268
# LeftEye: 135, 276, RightEye: 166, 274
# LeftEye: 135, 276, RightEye: 165, 274
# LeftEye: 135, 276, RightEye: 166, 273
# LeftEye: 133, 276, RightEye: 165, 275
# LeftEye: 136, 275, RightEye: 168, 273
# LeftEye: 135, 274, RightEye: 167, 273
# LeftEye: 136, 275, RightEye: 167, 273
# LeftEye: 135, 275, RightEye: 166, 273
# LeftEye: 135, 275, RightEye: 167, 273
# LeftEye: 132, 273, RightEye: 172, 270
# LeftEye: 132, 272, RightEye: 168, 270
# LeftEye: 132, 275, RightEye: 167, 274
# LeftEye: 132, 273, RightEye: 168, 268
# LeftEye: 130, 275, RightEye: 166, 271
# LeftEye: 130, 276, RightEye: 166, 271
# LeftEye: 132, 277, RightEye: 163, 274
# LeftEye: 129, 279, RightEye: 164, 271
# LeftEye: 129, 279, RightEye: 165, 270
# LeftEye: 129, 280, RightEye: 159, 275
# LeftEye: 129, 279, RightEye: 164, 272
# LeftEye: 129, 280, RightEye: 164, 271
# LeftEye: 130, 281, RightEye: 159, 274
# LeftEye: 130, 280, RightEye: 165, 270
# LeftEye: 130, 281, RightEye: 158, 275
# LeftEye: 129, 279, RightEye: 165, 270
# LeftEye: 131, 279, RightEye: 163, 275
# LeftEye: 132, 279, RightEye: 163, 274
# LeftEye: 132, 279, RightEye: 162, 274
# LeftEye: 132, 279, RightEye: 163, 273
# LeftEye: 132, 279, RightEye: 163, 273
# LeftEye: 132, 277, RightEye: 162, 274
# LeftEye: 132, 276, RightEye: 165, 274
# LeftEye: 132, 276, RightEye: 163, 274
# LeftEye: 132, 275, RightEye: 166, 274
# LeftEye: 131, 276, RightEye: 163, 274
# LeftEye: 132, 276, RightEye: 165, 274
# LeftEye: 132, 276, RightEye: 163, 274
# LeftEye: 132, 276, RightEye: 163, 274
# LeftEye: 133, 276, RightEye: 163, 274
# LeftEye: 133, 276, RightEye: 163, 274
# LeftEye: 133, 275, RightEye: 165, 274
# LeftEye: 133, 275, RightEye: 163, 274
# LeftEye: 133, 275, RightEye: 165, 274
# LeftEye: 133, 275, RightEye: 166, 274
# LeftEye: 133, 275, RightEye: 165, 274
# LeftEye: 133, 268, RightEye: 168, 268
# LeftEye: 132, 268, RightEye: 169, 270
# LeftEye: 133, 274, RightEye: 167, 274
# LeftEye: 132, 271, RightEye: 168, 271
# LeftEye: 133, 275, RightEye: 166, 275
# LeftEye: 133, 271, RightEye: 168, 271
# LeftEye: 133, 270, RightEye: 169, 270
# LeftEye: 133, 271, RightEye: 169, 271
# LeftEye: 135, 276, RightEye: 166, 276
# LeftEye: 133, 271, RightEye: 169, 270
# LeftEye: 135, 271, RightEye: 168, 270
# LeftEye: 133, 271, RightEye: 169, 270
# LeftEye: 135, 276, RightEye: 165, 275
# LeftEye: 133, 279, RightEye: 165, 276
# LeftEye: 135, 277, RightEye: 167, 275
# LeftEye: 129, 277, RightEye: 159, 276
# LeftEye: 127, 281, RightEye: 160, 281
# LeftEye: 126, 281, RightEye: 159, 282
# LeftEye: 126, 281, RightEye: 159, 281
# LeftEye: 127, 280, RightEye: 159, 281
# LeftEye: 126, 280, RightEye: 159, 281
# LeftEye: 126, 280, RightEye: 158, 280
# LeftEye: 132, 270, RightEye: 169, 268
# LeftEye: 132, 270, RightEye: 168, 270
# LeftEye: 130, 271, RightEye: 166, 271
# LeftEye: 129, 273, RightEye: 163, 272
# LeftEye: 132, 270, RightEye: 172, 265
# LeftEye: 131, 272, RightEye: 163, 271
# LeftEye: 137, 270, RightEye: 171, 270
# LeftEye: 136, 274, RightEye: 168, 274
# LeftEye: 137, 271, RightEye: 174, 273
# LeftEye: 133, 275, RightEye: 175, 275
# LeftEye: 133, 277, RightEye: 180, 277
# LeftEye: 145, 274, RightEye: 186, 273
# LeftEye: 140, 276, RightEye: 185, 276
# LeftEye: 129, 285, RightEye: 177, 285
# LeftEye: 147, 273, RightEye: 194, 276
# LeftEye: 146, 268, RightEye: 184, 272
# LeftEye: 144, 271, RightEye: 183, 276
# LeftEye: 149, 268, RightEye: 185, 270
# LeftEye: 145, 267, RightEye: 186, 270
# LeftEye: 139, 264, RightEye: 185, 268
# LeftEye: 140, 263, RightEye: 187, 268
# LeftEye: 131, 267, RightEye: 175, 272
# LeftEye: 135, 265, RightEye: 180, 271
# LeftEye: 137, 265, RightEye: 181, 273
# LeftEye: 136, 266, RightEye: 178, 273
# LeftEye: 133, 266, RightEye: 177, 271
# LeftEye: 131, 267, RightEye: 174, 273
# LeftEye: 133, 267, RightEye: 173, 274
# LeftEye: 132, 268, RightEye: 174, 274
# LeftEye: 132, 268, RightEye: 172, 274
# LeftEye: 135, 267, RightEye: 177, 273
# LeftEye: 133, 267, RightEye: 174, 273
# LeftEye: 132, 268, RightEye: 175, 274
# LeftEye: 135, 266, RightEye: 178, 271
# LeftEye: 133, 267, RightEye: 174, 273
# LeftEye: 132, 266, RightEye: 173, 273
# LeftEye: 133, 266, RightEye: 174, 273
# LeftEye: 133, 266, RightEye: 175, 271
# LeftEye: 135, 266, RightEye: 177, 273
# LeftEye: 130, 267, RightEye: 172, 273
# LeftEye: 135, 263, RightEye: 181, 265
# LeftEye: 136, 265, RightEye: 177, 270
# LeftEye: 132, 267, RightEye: 172, 273
# LeftEye: 132, 265, RightEye: 173, 271
# LeftEye: 131, 271, RightEye: 175, 275
# LeftEye: 132, 273, RightEye: 175, 275
# LeftEye: 130, 271, RightEye: 173, 275
# LeftEye: 132, 270, RightEye: 174, 275
# LeftEye: 133, 267, RightEye: 177, 274
# LeftEye: 133, 268, RightEye: 177, 274
# LeftEye: 136, 266, RightEye: 180, 273
# LeftEye: 141, 261, RightEye: 185, 265
# LeftEye: 132, 265, RightEye: 175, 272
# LeftEye: 132, 267, RightEye: 181, 272
# LeftEye: 135, 270, RightEye: 182, 273
# LeftEye: 137, 267, RightEye: 184, 270
# LeftEye: 138, 263, RightEye: 186, 268
# LeftEye: 137, 264, RightEye: 184, 270
# LeftEye: 136, 265, RightEye: 184, 272
# LeftEye: 136, 267, RightEye: 183, 272
# LeftEye: 136, 267, RightEye: 184, 272
# LeftEye: 145, 261, RightEye: 192, 264
# LeftEye: 145, 264, RightEye: 191, 267
# LeftEye: 142, 263, RightEye: 189, 267
# LeftEye: 142, 263, RightEye: 189, 264
# LeftEye: 141, 264, RightEye: 189, 267
# LeftEye: 142, 264, RightEye: 189, 267
# LeftEye: 142, 267, RightEye: 189, 268
# LeftEye: 142, 263, RightEye: 189, 267
# LeftEye: 144, 263, RightEye: 190, 265
# LeftEye: 144, 262, RightEye: 190, 265
# LeftEye: 145, 264, RightEye: 191, 267
# LeftEye: 145, 262, RightEye: 191, 265
# LeftEye: 147, 262, RightEye: 192, 264
# LeftEye: 145, 262, RightEye: 191, 265
# LeftEye: 145, 261, RightEye: 191, 265
# LeftEye: 144, 265, RightEye: 190, 268
# LeftEye: 145, 264, RightEye: 190, 267
# LeftEye: 144, 262, RightEye: 191, 265
# LeftEye: 145, 262, RightEye: 191, 265
# LeftEye: 146, 263, RightEye: 192, 265
# ...
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 141, 183, RightEye: 208, 184
# LeftEye: 139, 184, RightEye: 208, 184
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 142, 185, RightEye: 208, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 139, 186, RightEye: 207, 185
# LeftEye: 141, 184, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 208, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 208, 185
# LeftEye: 139, 185, RightEye: 208, 184
# LeftEye: 142, 185, RightEye: 208, 185
# LeftEye: 141, 185, RightEye: 208, 185
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 139, 185, RightEye: 207, 185
# LeftEye: 139, 184, RightEye: 208, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 139, 184, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 139, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 185
# LeftEye: 142, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 184
# LeftEye: 141, 185, RightEye: 207, 184
# LeftEye: 141, 186, RightEye: 207, 185
# LeftEye: 141, 184, RightEye: 207, 184
# LeftEye: 141, 184, RightEye: 208, 184
# LeftEye: 139, 184, RightEye: 207, 185
# LeftEye: 138, 183, RightEye: 207, 183
# LeftEye: 138, 184, RightEye: 207, 184
# LeftEye: 137, 183, RightEye: 207, 183
# LeftEye: 136, 183, RightEye: 204, 183
# LeftEye: 135, 184, RightEye: 204, 183
# LeftEye: 133, 181, RightEye: 207, 183
# LeftEye: 136, 180, RightEye: 205, 181
# LeftEye: 135, 178, RightEye: 207, 181
# LeftEye: 135, 177, RightEye: 207, 180
# LeftEye: 133, 176, RightEye: 208, 180
# LeftEye: 133, 177, RightEye: 207, 180
# LeftEye: 132, 177, RightEye: 207, 180
# LeftEye: 132, 177, RightEye: 205, 178
# LeftEye: 131, 177, RightEye: 205, 178
# LeftEye: 131, 178, RightEye: 204, 178
# LeftEye: 131, 177, RightEye: 204, 178
# LeftEye: 131, 178, RightEye: 205, 180
# LeftEye: 130, 177, RightEye: 204, 180
# LeftEye: 130, 178, RightEye: 204, 180
# LeftEye: 130, 181, RightEye: 204, 183
# LeftEye: 131, 183, RightEye: 203, 185
# LeftEye: 130, 180, RightEye: 204, 181
# LeftEye: 131, 184, RightEye: 203, 185
# LeftEye: 129, 180, RightEye: 203, 180
# LeftEye: 131, 181, RightEye: 205, 184
# LeftEye: 132, 181, RightEye: 205, 184
# LeftEye: 129, 180, RightEye: 203, 180
# LeftEye: 129, 178, RightEye: 204, 181
# LeftEye: 129, 177, RightEye: 204, 180
# LeftEye: 129, 177, RightEye: 203, 178
# LeftEye: 129, 175, RightEye: 203, 177
# LeftEye: 129, 175, RightEye: 204, 178
# LeftEye: 129, 176, RightEye: 203, 176
# LeftEye: 130, 177, RightEye: 203, 178
# LeftEye: 129, 177, RightEye: 203, 178
# LeftEye: 130, 176, RightEye: 203, 177
# LeftEye: 129, 175, RightEye: 204, 178
# LeftEye: 127, 174, RightEye: 205, 177
# LeftEye: 131, 180, RightEye: 205, 183
# LeftEye: 129, 174, RightEye: 204, 178
# LeftEye: 127, 175, RightEye: 205, 178
# LeftEye: 129, 175, RightEye: 204, 177
# LeftEye: 129, 176, RightEye: 203, 181
# LeftEye: 130, 174, RightEye: 204, 175
# LeftEye: 130, 175, RightEye: 204, 180
# LeftEye: 130, 174, RightEye: 204, 180
# LeftEye: 131, 173, RightEye: 204, 177
# LeftEye: 130, 174, RightEye: 202, 177
# LeftEye: 129, 174, RightEye: 202, 177
# LeftEye: 126, 177, RightEye: 198, 176
# LeftEye: 124, 176, RightEye: 196, 175
# LeftEye: 124, 175, RightEye: 196, 175
# LeftEye: 123, 174, RightEye: 196, 174
# LeftEye: 123, 175, RightEye: 196, 175
# LeftEye: 122, 175, RightEye: 195, 177
# LeftEye: 122, 177, RightEye: 194, 178
# LeftEye: 121, 176, RightEye: 193, 175
# LeftEye: 120, 176, RightEye: 193, 175
# LeftEye: 120, 175, RightEye: 194, 175
# LeftEye: 122, 174, RightEye: 193, 175
# LeftEye: 121, 174, RightEye: 194, 174
# LeftEye: 120, 174, RightEye: 193, 174
# LeftEye: 119, 174, RightEye: 192, 174
# LeftEye: 120, 171, RightEye: 192, 173
# LeftEye: 119, 171, RightEye: 192, 172
# LeftEye: 118, 171, RightEye: 192, 174
# LeftEye: 114, 168, RightEye: 192, 173
# LeftEye: 113, 169, RightEye: 192, 173
# LeftEye: 112, 168, RightEye: 190, 173
# LeftEye: 113, 169, RightEye: 191, 173
# LeftEye: 113, 169, RightEye: 190, 172
# LeftEye: 112, 169, RightEye: 189, 172
# LeftEye: 112, 171, RightEye: 189, 172
# LeftEye: 112, 172, RightEye: 186, 174
# LeftEye: 112, 171, RightEye: 185, 173
# LeftEye: 111, 172, RightEye: 185, 174
# LeftEye: 111, 171, RightEye: 184, 174
# LeftEye: 112, 174, RightEye: 185, 178
# LeftEye: 109, 172, RightEye: 183, 175
# LeftEye: 110, 173, RightEye: 183, 174
# LeftEye: 109, 172, RightEye: 184, 174
# LeftEye: 109, 173, RightEye: 183, 174
# LeftEye: 110, 173, RightEye: 184, 175
# LeftEye: 109, 169, RightEye: 184, 174
# LeftEye: 108, 169, RightEye: 184, 174
# LeftEye: 109, 173, RightEye: 183, 175
# LeftEye: 110, 173, RightEye: 183, 176
# LeftEye: 110, 169, RightEye: 184, 175
# LeftEye: 109, 168, RightEye: 184, 174
# LeftEye: 109, 169, RightEye: 184, 174
# LeftEye: 109, 172, RightEye: 185, 177
# LeftEye: 109, 171, RightEye: 184, 177
# LeftEye: 109, 171, RightEye: 185, 177
# LeftEye: 109, 171, RightEye: 185, 175
# LeftEye: 109, 173, RightEye: 185, 178
# LeftEye: 111, 174, RightEye: 185, 178
# LeftEye: 110, 171, RightEye: 185, 178
# LeftEye: 112, 173, RightEye: 185, 180
# LeftEye: 112, 171, RightEye: 186, 178
# LeftEye: 112, 172, RightEye: 186, 180
# LeftEye: 113, 172, RightEye: 190, 181
# LeftEye: 115, 175, RightEye: 190, 181
# LeftEye: 112, 173, RightEye: 185, 178
# LeftEye: 114, 172, RightEye: 190, 178
# LeftEye: 113, 172, RightEye: 192, 175
# LeftEye: 117, 173, RightEye: 193, 178
# LeftEye: 114, 172, RightEye: 192, 175
# LeftEye: 114, 173, RightEye: 192, 175
# LeftEye: 119, 172, RightEye: 193, 177
# LeftEye: 119, 174, RightEye: 194, 177
# LeftEye: 118, 172, RightEye: 196, 172
# LeftEye: 117, 175, RightEye: 198, 175
# LeftEye: 119, 172, RightEye: 199, 173
# LeftEye: 120, 173, RightEye: 201, 173
# LeftEye: 122, 171, RightEye: 205, 173
# LeftEye: 127, 175, RightEye: 208, 178
# LeftEye: 123, 169, RightEye: 209, 173
# LeftEye: 127, 168, RightEye: 211, 172
# LeftEye: 127, 169, RightEye: 211, 171
# LeftEye: 129, 168, RightEye: 213, 171
# LeftEye: 130, 168, RightEye: 214, 168
# LeftEye: 129, 169, RightEye: 214, 169
# LeftEye: 130, 169, RightEye: 216, 169
# LeftEye: 129, 169, RightEye: 216, 169
# LeftEye: 129, 169, RightEye: 213, 169
# LeftEye: 127, 171, RightEye: 216, 171
# LeftEye: 127, 171, RightEye: 214, 171
# LeftEye: 129, 169, RightEye: 216, 169
# LeftEye: 129, 171, RightEye: 216, 171
# LeftEye: 129, 169, RightEye: 216, 169
# LeftEye: 127, 171, RightEye: 216, 171
# LeftEye: 126, 169, RightEye: 211, 168
# LeftEye: 126, 169, RightEye: 211, 168
# LeftEye: 127, 176, RightEye: 212, 175
# LeftEye: 127, 169, RightEye: 214, 169
# LeftEye: 127, 172, RightEye: 213, 172
# LeftEye: 126, 171, RightEye: 213, 172
# LeftEye: 127, 169, RightEye: 211, 172
# LeftEye: 127, 172, RightEye: 210, 172
# LeftEye: 124, 172, RightEye: 210, 171
# LeftEye: 124, 171, RightEye: 210, 171
# LeftEye: 126, 172, RightEye: 210, 171
# LeftEye: 123, 171, RightEye: 210, 169
# LeftEye: 124, 172, RightEye: 209, 171
# LeftEye: 126, 177, RightEye: 208, 175
# LeftEye: 123, 172, RightEye: 208, 169
# LeftEye: 126, 177, RightEye: 205, 175
# LeftEye: 123, 172, RightEye: 208, 169
# LeftEye: 123, 172, RightEye: 208, 169
# LeftEye: 123, 171, RightEye: 208, 169
# LeftEye: 122, 172, RightEye: 205, 168
# LeftEye: 123, 171, RightEye: 208, 169
# LeftEye: 124, 172, RightEye: 208, 169
# LeftEye: 124, 172, RightEye: 208, 169
# LeftEye: 124, 171, RightEye: 208, 169
# LeftEye: 124, 171, RightEye: 208, 171
# LeftEye: 123, 171, RightEye: 207, 171
# LeftEye: 124, 171, RightEye: 208, 171
# LeftEye: 124, 171, RightEye: 209, 171
# LeftEye: 123, 172, RightEye: 208, 171
# LeftEye: 123, 171, RightEye: 207, 169
# LeftEye: 122, 172, RightEye: 205, 171
# LeftEye: 122, 174, RightEye: 204, 172
# LeftEye: 124, 178, RightEye: 204, 175
# LeftEye: 121, 173, RightEye: 205, 169
# LeftEye: 124, 178, RightEye: 204, 175
# LeftEye: 122, 174, RightEye: 204, 172
# LeftEye: 124, 178, RightEye: 203, 176
# LeftEye: 124, 180, RightEye: 202, 176
# LeftEye: 124, 178, RightEye: 202, 175
# LeftEye: 124, 178, RightEye: 203, 176
# LeftEye: 124, 178, RightEye: 203, 175
# LeftEye: 124, 180, RightEye: 203, 175
# LeftEye: 124, 180, RightEye: 203, 175
# LeftEye: 124, 178, RightEye: 203, 175
# LeftEye: 123, 177, RightEye: 203, 175
# LeftEye: 126, 178, RightEye: 204, 175
# LeftEye: 124, 178, RightEye: 203, 175
# LeftEye: 124, 177, RightEye: 203, 175
# LeftEye: 126, 177, RightEye: 204, 175
# LeftEye: 122, 173, RightEye: 204, 169
# LeftEye: 124, 177, RightEye: 204, 175
# LeftEye: 126, 180, RightEye: 204, 177
# LeftEye: 126, 181, RightEye: 204, 177
# LeftEye: 124, 180, RightEye: 204, 177
# LeftEye: 122, 174, RightEye: 207, 169
# LeftEye: 122, 173, RightEye: 207, 171
# LeftEye: 124, 178, RightEye: 205, 176
# LeftEye: 122, 173, RightEye: 207, 169
# LeftEye: 122, 173, RightEye: 207, 169
# LeftEye: 124, 180, RightEye: 204, 176
# LeftEye: 122, 175, RightEye: 207, 171
# LeftEye: 124, 180, RightEye: 203, 175
# LeftEye: 123, 180, RightEye: 204, 175
# LeftEye: 123, 180, RightEye: 203, 175
# LeftEye: 123, 181, RightEye: 202, 176
# LeftEye: 123, 181, RightEye: 203, 176
# LeftEye: 123, 181, RightEye: 202, 175
# LeftEye: 123, 181, RightEye: 203, 175
# LeftEye: 123, 181, RightEye: 202, 176
# LeftEye: 123, 181, RightEye: 202, 176
# LeftEye: 123, 181, RightEye: 202, 175
# LeftEye: 123, 181, RightEye: 202, 176
# LeftEye: 123, 181, RightEye: 202, 175
# LeftEye: 121, 177, RightEye: 203, 169
# LeftEye: 121, 177, RightEye: 203, 169
# LeftEye: 123, 181, RightEye: 201, 175
# LeftEye: 123, 180, RightEye: 202, 175
# LeftEye: 123, 180, RightEye: 203, 175
# LeftEye: 120, 175, RightEye: 204, 169
# LeftEye: 121, 178, RightEye: 202, 175
# LeftEye: 119, 175, RightEye: 203, 171
# LeftEye: 123, 178, RightEye: 202, 176
# LeftEye: 121, 178, RightEye: 202, 175
# LeftEye: 123, 178, RightEye: 202, 176
# LeftEye: 119, 175, RightEye: 202, 168
# LeftEye: 119, 174, RightEye: 202, 168
# LeftEye: 120, 177, RightEye: 201, 174
# LeftEye: 120, 177, RightEye: 201, 174
# LeftEye: 118, 174, RightEye: 201, 169
# LeftEye: 118, 175, RightEye: 199, 169
# LeftEye: 117, 174, RightEye: 199, 169
# LeftEye: 118, 174, RightEye: 198, 169
# LeftEye: 114, 177, RightEye: 195, 172
# LeftEye: 118, 175, RightEye: 194, 171
# LeftEye: 117, 177, RightEye: 194, 172
# LeftEye: 114, 180, RightEye: 190, 173
# LeftEye: 113, 180, RightEye: 186, 173
# LeftEye: 113, 175, RightEye: 189, 171
# LeftEye: 113, 174, RightEye: 189, 173
# LeftEye: 111, 174, RightEye: 184, 173
# LeftEye: 109, 169, RightEye: 183, 168
# LeftEye: 106, 176, RightEye: 182, 172
# LeftEye: 104, 173, RightEye: 176, 169
# LeftEye: 104, 173, RightEye: 175, 171
# LeftEye: 102, 172, RightEye: 174, 172
# LeftEye: 103, 173, RightEye: 172, 172
# LeftEye: 102, 172, RightEye: 167, 171
# LeftEye: 100, 177, RightEye: 163, 171
# LeftEye: 100, 175, RightEye: 165, 173
# LeftEye: 100, 175, RightEye: 165, 173
# LeftEye: 99, 176, RightEye: 160, 174
# LeftEye: 100, 177, RightEye: 160, 173
# LeftEye: 99, 181, RightEye: 159, 174
# LeftEye: 96, 181, RightEye: 157, 174
# LeftEye: 95, 178, RightEye: 156, 174
# LeftEye: 95, 175, RightEye: 157, 174
# LeftEye: 96, 183, RightEye: 153, 177
# LeftEye: 96, 177, RightEye: 154, 176
# LeftEye: 95, 185, RightEye: 149, 178
# LeftEye: 97, 184, RightEye: 154, 181
# LeftEye: 93, 184, RightEye: 150, 178
# LeftEye: 94, 185, RightEye: 150, 180
# LeftEye: 95, 185, RightEye: 150, 181
# LeftEye: 95, 184, RightEye: 149, 181
# LeftEye: 94, 185, RightEye: 149, 180
# LeftEye: 94, 189, RightEye: 149, 182
# LeftEye: 94, 186, RightEye: 148, 181
# LeftEye: 94, 185, RightEye: 149, 183
# LeftEye: 93, 185, RightEye: 148, 181
# LeftEye: 91, 185, RightEye: 147, 177
# LeftEye: 91, 186, RightEye: 147, 180
# LeftEye: 91, 189, RightEye: 144, 182
# LeftEye: 91, 189, RightEye: 146, 185
# LeftEye: 93, 189, RightEye: 145, 184
# LeftEye: 94, 196, RightEye: 146, 193
# LeftEye: 93, 201, RightEye: 142, 193
# LeftEye: 95, 207, RightEye: 146, 201
# LeftEye: 93, 211, RightEye: 147, 202
# LeftEye: 91, 214, RightEye: 145, 203
# LeftEye: 91, 220, RightEye: 145, 209
# LeftEye: 92, 220, RightEye: 148, 210
# LeftEye: 93, 223, RightEye: 145, 213
# LeftEye: 90, 225, RightEye: 145, 213
# LeftEye: 94, 226, RightEye: 147, 217
# LeftEye: 94, 223, RightEye: 147, 216
# LeftEye: 95, 225, RightEye: 147, 219
# LeftEye: 94, 225, RightEye: 146, 217
# LeftEye: 94, 219, RightEye: 147, 214
# LeftEye: 88, 217, RightEye: 144, 208
# LeftEye: 93, 216, RightEye: 144, 209
# LeftEye: 91, 208, RightEye: 141, 202
# LeftEye: 93, 201, RightEye: 141, 199
# LeftEye: 96, 193, RightEye: 147, 196
# LeftEye: 95, 190, RightEye: 144, 193
# LeftEye: 101, 192, RightEye: 147, 194
# LeftEye: 103, 195, RightEye: 149, 200
# LeftEye: 100, 199, RightEye: 139, 198
# LeftEye: 108, 198, RightEye: 145, 201
# LeftEye: 110, 199, RightEye: 147, 199
# LeftEye: 109, 196, RightEye: 148, 196
# LeftEye: 117, 186, RightEye: 153, 189
# LeftEye: 108, 187, RightEye: 147, 187
# LeftEye: 115, 184, RightEye: 155, 184
# LeftEye: 92, 186, RightEye: 141, 187
# LeftEye: 79, 189, RightEye: 130, 190
# LeftEye: 82, 189, RightEye: 131, 189
# LeftEye: 81, 189, RightEye: 130, 187
# LeftEye: 76, 189, RightEye: 126, 185
# LeftEye: 94, 183, RightEye: 140, 180
# LeftEye: 82, 186, RightEye: 135, 183
# LeftEye: 77, 190, RightEye: 132, 185
# LeftEye: 70, 191, RightEye: 122, 185
# LeftEye: 74, 190, RightEye: 127, 186
# LeftEye: 76, 184, RightEye: 126, 184
# LeftEye: 83, 185, RightEye: 130, 184
# LeftEye: 74, 185, RightEye: 121, 184
# LeftEye: 81, 189, RightEye: 126, 183
# LeftEye: 87, 189, RightEye: 132, 184
# LeftEye: 93, 185, RightEye: 136, 182
# LeftEye: 84, 190, RightEye: 129, 182
# LeftEye: 66, 190, RightEye: 112, 183
# LeftEye: 61, 186, RightEye: 106, 182
# LeftEye: 75, 189, RightEye: 121, 181
# LeftEye: 83, 185, RightEye: 127, 180
# LeftEye: 85, 184, RightEye: 127, 175
# LeftEye: 83, 182, RightEye: 127, 175
# LeftEye: 70, 182, RightEye: 117, 174
# LeftEye: 83, 175, RightEye: 127, 172
# LeftEye: 78, 177, RightEye: 121, 173
# LeftEye: 72, 180, RightEye: 117, 173
# LeftEye: 73, 177, RightEye: 117, 169
# LeftEye: 67, 181, RightEye: 113, 173
# LeftEye: 64, 181, RightEye: 106, 171
# LeftEye: 65, 178, RightEye: 111, 168
# LeftEye: 66, 178, RightEye: 112, 168
# LeftEye: 60, 177, RightEye: 106, 169
# LeftEye: 55, 180, RightEye: 101, 171
# LeftEye: 58, 175, RightEye: 105, 167
# LeftEye: 55, 175, RightEye: 102, 167
# LeftEye: 57, 173, RightEye: 101, 166
# LeftEye: 55, 175, RightEye: 100, 167
# LeftEye: 51, 178, RightEye: 96, 171
# LeftEye: 51, 180, RightEye: 97, 168
# LeftEye: 51, 180, RightEye: 99, 168
# LeftEye: 54, 180, RightEye: 101, 171
# LeftEye: 54, 181, RightEye: 101, 169
# LeftEye: 47, 181, RightEye: 93, 172
# LeftEye: 51, 183, RightEye: 96, 171
# LeftEye: 40, 183, RightEye: 82, 171
# LeftEye: 45, 185, RightEye: 85, 173
# LeftEye: 43, 184, RightEye: 84, 172
# LeftEye: 45, 185, RightEye: 84, 173
# LeftEye: 42, 184, RightEye: 84, 173
# LeftEye: 45, 184, RightEye: 87, 174
# LeftEye: 45, 184, RightEye: 90, 173
# LeftEye: 48, 184, RightEye: 91, 174
# LeftEye: 46, 184, RightEye: 92, 174
# LeftEye: 46, 185, RightEye: 92, 175
# LeftEye: 46, 185, RightEye: 93, 178
# LeftEye: 43, 183, RightEye: 90, 177
# LeftEye: 57, 184, RightEye: 105, 178
# LeftEye: 46, 182, RightEye: 93, 180
# LeftEye: 58, 182, RightEye: 105, 177
# LeftEye: 67, 180, RightEye: 114, 174
# LeftEye: 66, 178, RightEye: 111, 173
# LeftEye: 56, 183, RightEye: 102, 177
# LeftEye: 48, 178, RightEye: 100, 178
# LeftEye: 54, 180, RightEye: 105, 177
# LeftEye: 60, 177, RightEye: 112, 173
# LeftEye: 60, 174, RightEye: 111, 174
# LeftEye: 65, 177, RightEye: 113, 174
# LeftEye: 60, 177, RightEye: 112, 174
# LeftEye: 66, 175, RightEye: 112, 172
# LeftEye: 73, 174, RightEye: 120, 169
# LeftEye: 77, 171, RightEye: 124, 167
# LeftEye: 72, 174, RightEye: 123, 171
# LeftEye: 64, 175, RightEye: 114, 173
# LeftEye: 58, 174, RightEye: 111, 172
# LeftEye: 56, 175, RightEye: 109, 174
# LeftEye: 56, 176, RightEye: 109, 175
# LeftEye: 56, 176, RightEye: 111, 172
# LeftEye: 88, 159, RightEye: 130, 158
# LeftEye: 85, 160, RightEye: 127, 159
# LeftEye: 92, 159, RightEye: 130, 157
# LeftEye: 92, 159, RightEye: 132, 158
# LeftEye: 92, 160, RightEye: 132, 159
# LeftEye: 93, 162, RightEye: 133, 159
# LeftEye: 92, 163, RightEye: 133, 158
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/darkice/miniconda3/envs/pyside6rknn/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
a = []
print( a.)
