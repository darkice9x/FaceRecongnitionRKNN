# %%
import cv2
import os
from PySide6.QtWidgets import QApplication, QMainWindow, QWidget, \
    QLabel, QGridLayout, QScrollArea, QSizePolicy, QFileDialog, QMessageBox
from PySide6.QtGui import QPixmap, QIcon, QImage, QPalette, QPainter, QPen, QColor
from PySide6.QtCore import QThread, Signal, Qt, QEvent, QObject, Slot
from PySide6 import QtCore
import sys
import time
import datetime
import json
import numpy as np
from PIL import Image
from onvif_control import *

from face_faiss_db import FaceDB
from embeddings import Embeddings
from ui_Face_Overlay import *
from rknnlite.api import RKNNLite

def extract_filename(file_path):
    full_filename = os.path.basename(file_path)
    filename_without_extension = os.path.splitext(full_filename)[0]
    return filename_without_extension

def read_jpg_files(directory):
    jpg_files = []
    for file in os.listdir(directory):
        if file.lower().endswith('.jpg'):
            jpg_files.append(os.path.join(directory, file))
    return jpg_files

def save_json(path, data):
    """
    numpy.ndarray 타입의 feature를 list로 바꿔서 JSON 저장
    """
    serializable_data = []
    for item in data:
        serializable_item = {
            "name": item["name"],
            "feature": item["feature"].tolist() if isinstance(item["feature"], np.ndarray) else item["feature"]
        }
        serializable_data.append(serializable_item)
    
    with open(path, "w", encoding="utf-8") as f:
        json.dump(serializable_data, f, ensure_ascii=False, indent=4)
    print("저장 완료:", path)

def load_json(path):
    """
    JSON을 불러온 후 list → numpy.ndarray 로 복원
    """
    with open(path, "r", encoding="utf-8") as f:
        loaded = json.load(f)
    
    for item in loaded:
        item["feature"] = np.array(item["feature"])
    print("불러오기 완료:", path)
    return loaded

class VideoThread(QThread):
    frame_update = Signal(np.ndarray)
    face_update = Signal(np.ndarray)

    def __init__(self, rtsp_url, resize_size=None, overlay_path=None, overlay_ok_path=None, overlay_size=None, crop_rect=None):
        super().__init__()
        self.rtsp_url = rtsp_url
        self.resize_size = resize_size
        self.overlay_path = overlay_path
        self.overlay_ok_path = overlay_ok_path
        self.overlay_size = overlay_size
        self.crop_rect = crop_rect
        #self.overlay_point = (60, 30)
        self.overlay_point = (
            int((self.crop_rect[2] - self.crop_rect[0]) / 2 - self.overlay_size[0] / 2),
            int((self.crop_rect[3] - self.crop_rect[1]) / 2 - self.overlay_size[1] / 2)
        )
        self.running = True
        self.embeddings = Embeddings('./RetinaFace_mobile320_i8_v2.3.2.rknn', './rk3588_mobilefacenet/mobilefacenet_v2.3.2.rknn')
        self.embedder_ret = None
        #self.process = False

        overlay = Image.open(self.overlay_path).convert("RGBA")
        self.overlay_resized = overlay.resize(self.overlay_size)

        overlay = Image.open(self.overlay_ok_path).convert("RGBA")
        self.overlay_ok_resized = overlay.resize(self.overlay_size)

        self.face_check = False

    def run(self):
        cap = cv2.VideoCapture(self.rtsp_url)

        while self.running:
            ret, frame = cap.read()
            if not ret:
                continue

            if self.resize_size:
                frame = cv2.resize(frame, self.resize_size, interpolation=cv2.INTER_AREA)

            if self.crop_rect:
                x1, y1, x2, y2 = self.crop_rect
                self.crop_frame = frame[y1:y2, x1:x2].copy()

            #if overlay_resized is not None:
            #    frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).convert("RGBA")
            #    frame_pil.paste(overlay_resized, self.overlay_point, overlay_resized)
            #    frame = cv2.cvtColor(np.array(frame_pil), cv2.COLOR_RGBA2BGR)
            retina_ret = self.embeddings.retinaface.get_faces(self.crop_frame)
            
            if not self.face_check:
                self.embedder_ret = []
                # LeftEye: 145, 185, RightEye: 229, 181
                # LeftEye: 137, 156, RightEye: 217, 149
                # LeftEye: 114, 169, RightEye: 201, 160
                # LeftEye: 129, 175, RightEye: 193, 160
                for face in retina_ret:
                    '''
                    if (175 <= face['nose'][0] <= 220) and ( 175 <= face['nose'][1] <= 220 ):                    
                        embedding = self.embeddings.mobilefacenet.get_feat(face['face'])
                        self.embedder_ret.append({'score': face['score'], 'embedding': embedding})
                        self.face_check = True
                        #self.process = True
                        self.face_update.emit(face['face_crop'])
                    else:
                        self.face_check = False
                    '''

                    if  ( 110 <= face['leftEyeCenter'][0] <= 160 ) and ( 150 <= face['leftEyeCenter'][1] <= 200 ) and ( 190 <= face['rightEyeCenter'][0] <= 250 ) and ( 140 <= face['rightEyeCenter'][1] <= 200 ):
                        embedding = self.embeddings.mobilefacenet.get_feat(face['face'])
                        self.embedder_ret.append({'score': face['score'], 'embedding': embedding})
                        self.face_check = True
                        #self.process = True
                        self.face_update.emit(face['face_crop'])
                    else:
                        self.face_check = False
                        
                    print(f"LeftEye: {face['leftEyeCenter'][0]}, {face['leftEyeCenter'][1]}, RightEye: {face['rightEyeCenter'][0]}, {face['rightEyeCenter'][1]}")

            self.frame_update.emit(self.crop_frame)

        cap.release()

    def stop(self):
        self.running = False
        self.wait()

class MyWindow(QMainWindow, Ui_MainWindow) :
    def __init__(self) :
        super().__init__()
        self.resize_size=(640, 360)
        self.crop_rect=(140, 0, 500, 360)
        self.overlay_size=(300, 300)
        self.face_size=(128, 128)
        self.images = read_jpg_files('./img')
        self.setupUi(self)

        # Thread 1 - 그림1
        self.camera = VideoThread(
            "rtsp://darkice:sys3275423@192.168.0.166:554/stream2",
            resize_size=self.resize_size,
            overlay_path="facial-recognition.png",
            overlay_ok_path="facial-recognition_ok.png",
            overlay_size=self.overlay_size,
            #crop_rect=(0, 0, 640, 360)  # x1, y1, x2, y2
            #crop_rect=(140, 0, 500, 360)
            crop_rect=self.crop_rect
        )
        self.camera.frame_update.connect(self.update_overlay)
        self.camera.face_update.connect(self.update_face)
        self.db = FaceDB(dim=128, db_path="./")
        self.save_db()

        camera_ip = '192.168.0.166'  # 카메라 IP 주소
        camera_port = 2020  # 카메라 포트 번호
        camera_user = 'darkice'  # 사용자 이름
        camera_password = 'sys3275423'  # 비밀번호
        self.cam = OnvifCamera(camera_ip, camera_port, camera_user, camera_password, './wsdl')
        a = self.cam.absolute_move( 0, 0, 0, 1)
        self.camera.start()

    def save_db(self):
        for j in range(len(self.images)):
            img2 = cv2.imread(self.images[j])
            get_face2 = self.camera.embeddings.get_embeddings(img2)
            personname = extract_filename(self.images[j])
            for i in range(len(get_face2)):
                feature = get_face2[i]['embedding']
                #print(f'feature: {type(feature)}')
            #embedding = {'feature' : feature, 'personname' : personname}
            #features.append(embedding)
            a = self.db.search_by_name(personname)
            if a is not None:
                #print(f'Embedding for {personname} already exists in the database.')
                continue
            else:
                self.db.add(personname, feature)

    def update_overlay(self, frame):

        if self.camera.overlay_path is not None:
            frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).convert("RGBA")
            if self.camera.face_check:
                frame_pil.paste(self.camera.overlay_ok_resized, self.camera.overlay_point, self.camera.overlay_ok_resized)
                result = self.db.search(self.camera.embedder_ret[0]['embedding'])
                if result:
                    #print(f'Face recognized: {result[0]["name"]}')
                    self.lineEdit.setText(result[0]["name"])
                else:
                    #print('Face not recognized')
                    self.lineEdit.setText("모름!!")

                self.camera.face_check = False
            else:
                frame_pil.paste(self.camera.overlay_resized, self.camera.overlay_point, self.camera.overlay_resized)
                self.lineEdit.setText("모름!!")

            frame_overlay = cv2.cvtColor(np.array(frame_pil), cv2.COLOR_RGBA2BGR)
        else:
            frame_overlay = frame

        h, w, ch = frame_overlay.shape
        qimg = QImage(frame_overlay.data, w, h, ch * w, QImage.Format_BGR888)
        pix = QPixmap.fromImage(qimg).scaled(
            self.label.width(), self.label.height(),
            Qt.KeepAspectRatio, Qt.SmoothTransformation
        )
        self.label.setPixmap(pix)

    def update_face(self, frame):
        frame_face = cv2.resize(frame, self.face_size, interpolation=cv2.INTER_AREA)
        h, w, ch = frame_face.shape
        qimg = QImage(frame_face.data, w, h, ch * w, QImage.Format_BGR888)
        pix = QPixmap.fromImage(qimg).scaled(
            self.label_2.width(), self.label_2.height(),
            Qt.KeepAspectRatio, Qt.SmoothTransformation
        )
        self.label_2.setPixmap(pix)

    def save_button_clicked(self):
        # Handle push button click event
        #pass
        print("Push button clicked")
        
        name = self.lineEdit_2.text()  # 예: "capture"
        base_path = "./img/"
        ext = ".jpg"

        # 처음 시도할 파일명
        save_path = os.path.join(base_path, name + ext)

        # 파일이 존재하면 뒤에 _1, _2 ... 붙이기
        counter = 0
        while os.path.exists(save_path):
            counter += 1
            save_path = os.path.join(base_path, f"{name}_{counter}{ext}")
            
        cv2.imwrite(save_path, self.camera.crop_frame)
        self.images.append(save_path)
        #self.images = read_jpg_files('./img')
        #img2 = cv2.imread(self.images[j])
        get_face = self.camera.embeddings.get_embeddings(self.camera.crop_frame)
        personname = extract_filename(save_path)
        for i in range(len(get_face)):
            feature = get_face[i]['embedding']
        self.db.add(personname, feature)

    def up_button_clicked(self):
        a = self.cam.relative_move( 0, -0.1, 0, 1)

    def down_button_clicked(self):
        a = self.cam.relative_move( 0, 0.1, 0, 1)

    def right_button_clicked(self):
        a = self.cam.relative_move( 0.05, 0, 0, 1)

    def left_button_clicked(self):
        a = self.cam.relative_move( -0.05, 0, 0, 1)


    def closeEvent(self, event):
        self.camera.stop()
        event.accept()

if __name__ == "__main__":
    import sys
    if not QApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QApplication.instance()

    myWindow = MyWindow() 
    myWindow.show()
    sys.exit(app.exec())
# Out:
# INFO:faiss.loader:Loading faiss.
# INFO:faiss.loader:Successfully loaded faiss.
# W rknn-toolkit-lite2 version: 2.3.2
# W Query dynamic range failed. Ret code: RKNN_ERR_MODEL_INVALID. (If it is a static shape RKNN model, please ignore the above warning message.)
# W rknn-toolkit-lite2 version: 2.3.2
# W Query dynamic range failed. Ret code: RKNN_ERR_MODEL_INVALID. (If it is a static shape RKNN model, please ignore the above warning message.)
# I RKNN: [18:50:41.432] RKNN Runtime Information, librknnrt version: 2.3.2 (429f97ae6b@2025-04-09T09:09:27)
# I RKNN: [18:50:41.432] RKNN Driver Information, version: 0.9.8
# I RKNN: [18:50:41.433] RKNN Model Information, version: 6, toolkit version: 2.3.2(compiler version: 2.3.2 (e045de294f@2025-04-07T19:48:25)), target: RKNPU v2, target platform: rk3588, framework name: ONNX, framework layout: NCHW, model inference type: static_shape
# W RKNN: [18:50:41.456] query RKNN_QUERY_INPUT_DYNAMIC_RANGE error, rknn model is static shape type, please export rknn with dynamic_shapes
# I RKNN: [18:50:41.539] RKNN Runtime Information, librknnrt version: 2.3.2 (429f97ae6b@2025-04-09T09:09:27)
# I RKNN: [18:50:41.539] RKNN Driver Information, version: 0.9.8
# I RKNN: [18:50:41.539] RKNN Model Information, version: 6, toolkit version: 2.3.2(compiler version: 2.3.2 (e045de294f@2025-04-07T19:48:25)), target: RKNPU v2, target platform: rk3588, framework name: Caffe, framework layout: NCHW, model inference type: static_shape
# W RKNN: [18:50:41.545] query RKNN_QUERY_INPUT_DYNAMIC_RANGE error, rknn model is static shape type, please export rknn with dynamic_shapes
# LeftEye: 192, 72, RightEye: 261, 59
# LeftEye: 191, 75, RightEye: 261, 60
# LeftEye: 191, 79, RightEye: 258, 65
# LeftEye: 185, 70, RightEye: 259, 56
# LeftEye: 185, 66, RightEye: 261, 54
# LeftEye: 186, 70, RightEye: 261, 57
# LeftEye: 177, 64, RightEye: 257, 47
# LeftEye: 186, 72, RightEye: 261, 56
# LeftEye: 189, 70, RightEye: 262, 55
# LeftEye: 187, 69, RightEye: 263, 54
# LeftEye: 191, 69, RightEye: 265, 55
# LeftEye: 189, 68, RightEye: 264, 52
# LeftEye: 192, 68, RightEye: 268, 55
# LeftEye: 192, 69, RightEye: 268, 56
# LeftEye: 191, 66, RightEye: 270, 52
# LeftEye: 186, 61, RightEye: 265, 48
# LeftEye: 189, 63, RightEye: 267, 50
# LeftEye: 190, 59, RightEye: 267, 49
# LeftEye: 192, 60, RightEye: 268, 52
# LeftEye: 193, 60, RightEye: 270, 51
# LeftEye: 192, 59, RightEye: 270, 50
# LeftEye: 191, 57, RightEye: 270, 48
# LeftEye: 189, 61, RightEye: 268, 49
# LeftEye: 186, 58, RightEye: 267, 46
# LeftEye: 187, 60, RightEye: 267, 48
# LeftEye: 187, 60, RightEye: 268, 47
# LeftEye: 189, 60, RightEye: 268, 48
# LeftEye: 189, 60, RightEye: 267, 48
# LeftEye: 189, 60, RightEye: 270, 48
# LeftEye: 187, 60, RightEye: 268, 47
# LeftEye: 186, 63, RightEye: 267, 48
# LeftEye: 189, 61, RightEye: 270, 48
# LeftEye: 195, 68, RightEye: 272, 55
# LeftEye: 198, 67, RightEye: 273, 57
# LeftEye: 199, 69, RightEye: 272, 59
# LeftEye: 195, 72, RightEye: 266, 60
# LeftEye: 191, 70, RightEye: 268, 54
# LeftEye: 196, 69, RightEye: 272, 57
# LeftEye: 196, 76, RightEye: 272, 65
# LeftEye: 187, 73, RightEye: 264, 59
# LeftEye: 187, 81, RightEye: 265, 65
# LeftEye: 183, 90, RightEye: 258, 69
# LeftEye: 180, 85, RightEye: 259, 68
# LeftEye: 177, 85, RightEye: 259, 66
# LeftEye: 180, 86, RightEye: 263, 75
# LeftEye: 181, 104, RightEye: 264, 90
# LeftEye: 175, 100, RightEye: 266, 83
# LeftEye: 175, 105, RightEye: 262, 83
# LeftEye: 158, 108, RightEye: 255, 95
# LeftEye: 198, 165, RightEye: 280, 166
# LeftEye: 202, 191, RightEye: 289, 196
# LeftEye: 199, 196, RightEye: 291, 196
# LeftEye: 183, 208, RightEye: 271, 195
# LeftEye: 184, 201, RightEye: 276, 199
# LeftEye: 187, 199, RightEye: 276, 195
# LeftEye: 186, 180, RightEye: 275, 175
# LeftEye: 190, 178, RightEye: 279, 174
# LeftEye: 182, 175, RightEye: 268, 169
# LeftEye: 168, 159, RightEye: 263, 157
# LeftEye: 156, 139, RightEye: 250, 129
# LeftEye: 148, 108, RightEye: 243, 97
# LeftEye: 146, 110, RightEye: 243, 100
# LeftEye: 148, 108, RightEye: 248, 97
# LeftEye: 139, 100, RightEye: 248, 83
# LeftEye: 146, 103, RightEye: 243, 91
# LeftEye: 146, 97, RightEye: 248, 85
# LeftEye: 142, 91, RightEye: 244, 85
# LeftEye: 139, 95, RightEye: 240, 87
# LeftEye: 139, 97, RightEye: 246, 91
# LeftEye: 145, 100, RightEye: 247, 93
# LeftEye: 138, 103, RightEye: 239, 91
# LeftEye: 140, 119, RightEye: 235, 104
# LeftEye: 144, 121, RightEye: 240, 114
# LeftEye: 146, 127, RightEye: 243, 121
# LeftEye: 142, 133, RightEye: 239, 127
# LeftEye: 140, 136, RightEye: 239, 129
# LeftEye: 140, 139, RightEye: 235, 131
# LeftEye: 140, 139, RightEye: 237, 131
# LeftEye: 141, 139, RightEye: 243, 131
# LeftEye: 139, 139, RightEye: 240, 131
# LeftEye: 142, 133, RightEye: 237, 131
# LeftEye: 139, 139, RightEye: 240, 129
# LeftEye: 145, 133, RightEye: 239, 129
# LeftEye: 145, 136, RightEye: 239, 129
# LeftEye: 139, 139, RightEye: 238, 129
# LeftEye: 142, 136, RightEye: 237, 131
# LeftEye: 140, 133, RightEye: 237, 129
# LeftEye: 140, 133, RightEye: 235, 131
# LeftEye: 139, 139, RightEye: 236, 131
# LeftEye: 130, 136, RightEye: 231, 131
# LeftEye: 130, 136, RightEye: 229, 131
# LeftEye: 130, 139, RightEye: 229, 131
# LeftEye: 126, 136, RightEye: 227, 131
# LeftEye: 122, 144, RightEye: 222, 131
# LeftEye: 122, 144, RightEye: 222, 131
# LeftEye: 126, 139, RightEye: 225, 131
# LeftEye: 122, 141, RightEye: 225, 131
# LeftEye: 122, 141, RightEye: 225, 131
# LeftEye: 126, 141, RightEye: 225, 131
# LeftEye: 122, 141, RightEye: 227, 131
# LeftEye: 128, 141, RightEye: 225, 133
# LeftEye: 128, 144, RightEye: 222, 133
# LeftEye: 122, 146, RightEye: 219, 133
# LeftEye: 122, 146, RightEye: 219, 136
# LeftEye: 122, 146, RightEye: 222, 136
# LeftEye: 122, 148, RightEye: 214, 136
# LeftEye: 120, 151, RightEye: 214, 136
# LeftEye: 120, 151, RightEye: 214, 136
# LeftEye: 118, 148, RightEye: 214, 136
# LeftEye: 120, 146, RightEye: 219, 136
# LeftEye: 122, 148, RightEye: 219, 136
# LeftEye: 122, 148, RightEye: 219, 139
# LeftEye: 122, 148, RightEye: 219, 136
# LeftEye: 122, 146, RightEye: 219, 136
# LeftEye: 122, 151, RightEye: 217, 141
# LeftEye: 122, 148, RightEye: 219, 139
# LeftEye: 122, 146, RightEye: 222, 139
# LeftEye: 122, 151, RightEye: 219, 139
# LeftEye: 122, 151, RightEye: 219, 139
# LeftEye: 122, 151, RightEye: 219, 139
# LeftEye: 122, 158, RightEye: 214, 146
# LeftEye: 120, 158, RightEye: 214, 144
# LeftEye: 122, 162, RightEye: 214, 146
# LeftEye: 120, 164, RightEye: 214, 144
# LeftEye: 120, 162, RightEye: 214, 144
# LeftEye: 118, 164, RightEye: 214, 144
# LeftEye: 117, 167, RightEye: 208, 147
# LeftEye: 117, 165, RightEye: 208, 147
# LeftEye: 115, 164, RightEye: 204, 141
# LeftEye: 117, 167, RightEye: 203, 145
# LeftEye: 117, 169, RightEye: 203, 147
# LeftEye: 117, 167, RightEye: 203, 147
# LeftEye: 117, 167, RightEye: 203, 147
# LeftEye: 117, 172, RightEye: 203, 150
# LeftEye: 114, 167, RightEye: 203, 147
# LeftEye: 114, 165, RightEye: 203, 147
# LeftEye: 114, 163, RightEye: 205, 147
# LeftEye: 114, 167, RightEye: 201, 153
# LeftEye: 114, 167, RightEye: 201, 153
# LeftEye: 111, 167, RightEye: 201, 150
# LeftEye: 119, 174, RightEye: 199, 157
# LeftEye: 120, 174, RightEye: 200, 159
# LeftEye: 123, 181, RightEye: 198, 166
# LeftEye: 123, 180, RightEye: 198, 165
# LeftEye: 121, 180, RightEye: 196, 163
# LeftEye: 120, 178, RightEye: 198, 162
# LeftEye: 120, 181, RightEye: 200, 165
# LeftEye: 120, 180, RightEye: 196, 163
# LeftEye: 120, 180, RightEye: 196, 166
# LeftEye: 118, 189, RightEye: 198, 168
# LeftEye: 117, 184, RightEye: 198, 163
# LeftEye: 114, 180, RightEye: 196, 157
# LeftEye: 114, 178, RightEye: 196, 157
# LeftEye: 117, 184, RightEye: 198, 163
# LeftEye: 114, 183, RightEye: 196, 160
# LeftEye: 112, 177, RightEye: 198, 155
# LeftEye: 113, 178, RightEye: 198, 156
# LeftEye: 113, 178, RightEye: 198, 157
# LeftEye: 102, 175, RightEye: 189, 155
# LeftEye: 102, 175, RightEye: 189, 153
# LeftEye: 102, 177, RightEye: 191, 155
# LeftEye: 104, 180, RightEye: 191, 155
# LeftEye: 102, 177, RightEye: 189, 155
# LeftEye: 96, 187, RightEye: 181, 159
# LeftEye: 99, 184, RightEye: 183, 157
# LeftEye: 96, 184, RightEye: 181, 157
# LeftEye: 102, 182, RightEye: 186, 157
# LeftEye: 104, 182, RightEye: 191, 163
# LeftEye: 106, 180, RightEye: 191, 163
# LeftEye: 106, 180, RightEye: 191, 165
# LeftEye: 106, 180, RightEye: 191, 165
# LeftEye: 109, 177, RightEye: 193, 163
# LeftEye: 111, 175, RightEye: 201, 157
# LeftEye: 111, 172, RightEye: 199, 159
# LeftEye: 111, 172, RightEye: 201, 157
# LeftEye: 111, 172, RightEye: 201, 157
# LeftEye: 109, 172, RightEye: 201, 157
# LeftEye: 111, 172, RightEye: 201, 157
# LeftEye: 111, 172, RightEye: 201, 155
# LeftEye: 111, 172, RightEye: 201, 155
# LeftEye: 111, 172, RightEye: 201, 155
# LeftEye: 111, 169, RightEye: 203, 155
# LeftEye: 111, 172, RightEye: 201, 155
# LeftEye: 111, 169, RightEye: 203, 153
# LeftEye: 111, 169, RightEye: 203, 155
# LeftEye: 111, 172, RightEye: 201, 157
# LeftEye: 109, 172, RightEye: 195, 159
# LeftEye: 109, 175, RightEye: 193, 163
# LeftEye: 109, 175, RightEye: 193, 163
# LeftEye: 104, 180, RightEye: 189, 163
# LeftEye: 102, 182, RightEye: 186, 163
# LeftEye: 96, 187, RightEye: 183, 165
# LeftEye: 92, 192, RightEye: 176, 165
# LeftEye: 86, 194, RightEye: 171, 165
# LeftEye: 86, 192, RightEye: 168, 165
# LeftEye: 84, 194, RightEye: 168, 165
# LeftEye: 82, 198, RightEye: 168, 165
# LeftEye: 79, 198, RightEye: 166, 165
# LeftEye: 84, 198, RightEye: 168, 165
# LeftEye: 99, 207, RightEye: 175, 178
# LeftEye: 76, 198, RightEye: 164, 163
# LeftEye: 79, 204, RightEye: 162, 167
# LeftEye: 76, 204, RightEye: 158, 169
# LeftEye: 76, 204, RightEye: 162, 172
# LeftEye: 76, 204, RightEye: 162, 169
# LeftEye: 76, 202, RightEye: 162, 167
# LeftEye: 74, 200, RightEye: 162, 165
# LeftEye: 76, 202, RightEye: 162, 167
# LeftEye: 76, 200, RightEye: 166, 165
# LeftEye: 84, 198, RightEye: 168, 167
# LeftEye: 84, 192, RightEye: 171, 165
# LeftEye: 90, 190, RightEye: 174, 163
# LeftEye: 94, 190, RightEye: 178, 165
# LeftEye: 112, 195, RightEye: 190, 173
# LeftEye: 111, 187, RightEye: 192, 166
# LeftEye: 106, 180, RightEye: 191, 165
# LeftEye: 106, 182, RightEye: 189, 165
# LeftEye: 118, 184, RightEye: 200, 171
# LeftEye: 109, 180, RightEye: 191, 165
# LeftEye: 109, 177, RightEye: 195, 163
# LeftEye: 111, 175, RightEye: 201, 157
# LeftEye: 114, 175, RightEye: 201, 157
# LeftEye: 114, 177, RightEye: 201, 159
# LeftEye: 117, 175, RightEye: 203, 163
# LeftEye: 117, 175, RightEye: 205, 159
# LeftEye: 117, 175, RightEye: 203, 159
# LeftEye: 114, 175, RightEye: 203, 163
# LeftEye: 114, 180, RightEye: 201, 163
# LeftEye: 114, 182, RightEye: 199, 165
# LeftEye: 114, 187, RightEye: 201, 167
# LeftEye: 117, 180, RightEye: 205, 159
# LeftEye: 117, 182, RightEye: 201, 165
# LeftEye: 114, 182, RightEye: 201, 163
# LeftEye: 117, 182, RightEye: 203, 165
# LeftEye: 119, 180, RightEye: 208, 165
# LeftEye: 119, 180, RightEye: 208, 163
# LeftEye: 119, 182, RightEye: 208, 165
# LeftEye: 117, 182, RightEye: 208, 163
# LeftEye: 119, 187, RightEye: 208, 167
# LeftEye: 117, 184, RightEye: 205, 165
# LeftEye: 117, 187, RightEye: 205, 167
# LeftEye: 117, 184, RightEye: 205, 167
# LeftEye: 117, 187, RightEye: 205, 167
# LeftEye: 117, 187, RightEye: 205, 167
# LeftEye: 117, 187, RightEye: 203, 169
# LeftEye: 114, 187, RightEye: 203, 167
# LeftEye: 117, 184, RightEye: 205, 167
# LeftEye: 119, 184, RightEye: 208, 167
# LeftEye: 117, 187, RightEye: 205, 167
# LeftEye: 117, 187, RightEye: 203, 167
# LeftEye: 117, 187, RightEye: 203, 167
# LeftEye: 117, 190, RightEye: 203, 169
# LeftEye: 114, 190, RightEye: 203, 172
# LeftEye: 117, 190, RightEye: 203, 172
# LeftEye: 117, 192, RightEye: 203, 172
# LeftEye: 114, 192, RightEye: 201, 172
# LeftEye: 117, 194, RightEye: 203, 175
# LeftEye: 110, 192, RightEye: 204, 172
# LeftEye: 119, 194, RightEye: 208, 175
# LeftEye: 119, 191, RightEye: 211, 174
# LeftEye: 121, 190, RightEye: 208, 175
# LeftEye: 123, 192, RightEye: 208, 175
# LeftEye: 121, 191, RightEye: 211, 176
# LeftEye: 123, 192, RightEye: 208, 175
# LeftEye: 115, 187, RightEye: 207, 169
# LeftEye: 110, 190, RightEye: 204, 169
# LeftEye: 115, 187, RightEye: 207, 169
# LeftEye: 115, 187, RightEye: 207, 169
# LeftEye: 112, 187, RightEye: 207, 172
# LeftEye: 129, 193, RightEye: 209, 175
# LeftEye: 130, 196, RightEye: 208, 176
# LeftEye: 127, 196, RightEye: 205, 174
# LeftEye: 126, 194, RightEye: 208, 174
# LeftEye: 124, 198, RightEye: 204, 173
# LeftEye: 126, 192, RightEye: 205, 171
# LeftEye: 122, 190, RightEye: 204, 164
# LeftEye: 124, 193, RightEye: 203, 167
# LeftEye: 124, 192, RightEye: 198, 173
# LeftEye: 119, 195, RightEye: 196, 167
# LeftEye: 118, 195, RightEye: 192, 176
# LeftEye: 119, 196, RightEye: 193, 175
# LeftEye: 120, 196, RightEye: 195, 177
# LeftEye: 120, 196, RightEye: 198, 177
# LeftEye: 119, 199, RightEye: 195, 176
# LeftEye: 119, 199, RightEye: 195, 177
# LeftEye: 121, 198, RightEye: 196, 177
# LeftEye: 121, 199, RightEye: 198, 177
# LeftEye: 121, 201, RightEye: 196, 178
# LeftEye: 121, 202, RightEye: 193, 180
# LeftEye: 120, 196, RightEye: 195, 174
# LeftEye: 121, 196, RightEye: 195, 175
# LeftEye: 124, 198, RightEye: 196, 177
# LeftEye: 126, 199, RightEye: 196, 180
# LeftEye: 121, 196, RightEye: 195, 178
# LeftEye: 123, 198, RightEye: 196, 181
# LeftEye: 124, 199, RightEye: 195, 182
# LeftEye: 120, 202, RightEye: 193, 178
# LeftEye: 123, 198, RightEye: 195, 181
# LeftEye: 123, 198, RightEye: 193, 181
# LeftEye: 121, 196, RightEye: 193, 180
# LeftEye: 118, 201, RightEye: 190, 178
# LeftEye: 117, 196, RightEye: 190, 177
# LeftEye: 117, 196, RightEye: 190, 178
# LeftEye: 115, 196, RightEye: 187, 178
# LeftEye: 112, 196, RightEye: 186, 177
# LeftEye: 113, 194, RightEye: 185, 177
# LeftEye: 112, 199, RightEye: 183, 175
# LeftEye: 109, 195, RightEye: 183, 175
# LeftEye: 113, 200, RightEye: 183, 175
# LeftEye: 111, 198, RightEye: 181, 178
# LeftEye: 112, 200, RightEye: 181, 175
# LeftEye: 112, 196, RightEye: 183, 177
# LeftEye: 111, 196, RightEye: 183, 177
# LeftEye: 112, 200, RightEye: 181, 175
# LeftEye: 112, 199, RightEye: 181, 175
# LeftEye: 109, 195, RightEye: 183, 175
# LeftEye: 109, 200, RightEye: 180, 174
# LeftEye: 106, 203, RightEye: 178, 176
# LeftEye: 109, 204, RightEye: 177, 178
# LeftEye: 106, 209, RightEye: 176, 180
# LeftEye: 104, 208, RightEye: 175, 181
# LeftEye: 104, 208, RightEye: 176, 178
# LeftEye: 100, 208, RightEye: 174, 177
# LeftEye: 96, 208, RightEye: 172, 175
# LeftEye: 99, 208, RightEye: 172, 175
# LeftEye: 96, 209, RightEye: 172, 175
# LeftEye: 96, 210, RightEye: 171, 175
# LeftEye: 99, 210, RightEye: 171, 176
# LeftEye: 99, 207, RightEye: 169, 178
# LeftEye: 99, 205, RightEye: 169, 178
# LeftEye: 102, 211, RightEye: 171, 178
# LeftEye: 95, 213, RightEye: 163, 178
# LeftEye: 94, 212, RightEye: 166, 177
# LeftEye: 95, 212, RightEye: 163, 180
# LeftEye: 93, 214, RightEye: 162, 180
# LeftEye: 93, 213, RightEye: 162, 180
# LeftEye: 93, 212, RightEye: 162, 177
# LeftEye: 94, 212, RightEye: 163, 178
# LeftEye: 88, 211, RightEye: 160, 174
# LeftEye: 88, 207, RightEye: 163, 171
# LeftEye: 94, 212, RightEye: 162, 177
# LeftEye: 96, 209, RightEye: 167, 180
# LeftEye: 95, 211, RightEye: 166, 180
# LeftEye: 95, 210, RightEye: 166, 173
# LeftEye: 96, 211, RightEye: 171, 175
# LeftEye: 102, 212, RightEye: 174, 180
# LeftEye: 105, 209, RightEye: 175, 178
# LeftEye: 104, 207, RightEye: 177, 176
# LeftEye: 105, 201, RightEye: 178, 175
# LeftEye: 109, 203, RightEye: 180, 177
# LeftEye: 108, 202, RightEye: 181, 176
# LeftEye: 109, 202, RightEye: 181, 176
# LeftEye: 108, 201, RightEye: 181, 175
# LeftEye: 109, 202, RightEye: 183, 177
# LeftEye: 113, 201, RightEye: 185, 177
# LeftEye: 114, 201, RightEye: 186, 177
# LeftEye: 114, 204, RightEye: 190, 177
# LeftEye: 118, 202, RightEye: 190, 181
# LeftEye: 117, 203, RightEye: 187, 178
# LeftEye: 119, 202, RightEye: 189, 183
# LeftEye: 120, 202, RightEye: 191, 181
# LeftEye: 121, 202, RightEye: 189, 183
# LeftEye: 121, 199, RightEye: 190, 178
# LeftEye: 121, 200, RightEye: 189, 180
# LeftEye: 121, 199, RightEye: 189, 178
# LeftEye: 120, 196, RightEye: 189, 178
# LeftEye: 119, 194, RightEye: 189, 175
# LeftEye: 120, 193, RightEye: 189, 175
# LeftEye: 124, 200, RightEye: 189, 178
# LeftEye: 123, 192, RightEye: 191, 178
# LeftEye: 124, 193, RightEye: 191, 180
# LeftEye: 124, 198, RightEye: 191, 178
# LeftEye: 126, 198, RightEye: 191, 180
# LeftEye: 121, 192, RightEye: 191, 175
# LeftEye: 121, 192, RightEye: 191, 175
# LeftEye: 121, 195, RightEye: 190, 176
# LeftEye: 123, 195, RightEye: 190, 176
# LeftEye: 120, 196, RightEye: 190, 174
# LeftEye: 119, 196, RightEye: 189, 173
# LeftEye: 118, 199, RightEye: 186, 174
# LeftEye: 119, 200, RightEye: 187, 176
# LeftEye: 119, 199, RightEye: 186, 175
# LeftEye: 118, 196, RightEye: 186, 174
# LeftEye: 120, 199, RightEye: 187, 175
# LeftEye: 123, 198, RightEye: 189, 176
# LeftEye: 123, 193, RightEye: 192, 174
# LeftEye: 121, 195, RightEye: 190, 174
# LeftEye: 120, 198, RightEye: 187, 175
# LeftEye: 120, 192, RightEye: 190, 172
# LeftEye: 121, 191, RightEye: 191, 172
# LeftEye: 120, 191, RightEye: 191, 172
# LeftEye: 120, 190, RightEye: 191, 172
# LeftEye: 121, 192, RightEye: 191, 173
# LeftEye: 119, 190, RightEye: 190, 168
# LeftEye: 118, 189, RightEye: 190, 168
# LeftEye: 117, 187, RightEye: 191, 167
# LeftEye: 118, 189, RightEye: 190, 171
# LeftEye: 118, 187, RightEye: 191, 171
# LeftEye: 117, 186, RightEye: 191, 168
# LeftEye: 117, 186, RightEye: 192, 168
# LeftEye: 118, 191, RightEye: 189, 167
# LeftEye: 118, 192, RightEye: 189, 168
# LeftEye: 118, 191, RightEye: 190, 168
# LeftEye: 119, 191, RightEye: 191, 171
# LeftEye: 118, 191, RightEye: 190, 171
# LeftEye: 118, 191, RightEye: 190, 171
# LeftEye: 117, 190, RightEye: 190, 168
# LeftEye: 119, 193, RightEye: 189, 173
# LeftEye: 120, 195, RightEye: 189, 173
# LeftEye: 120, 195, RightEye: 189, 174
# LeftEye: 121, 195, RightEye: 190, 174
# LeftEye: 120, 191, RightEye: 191, 173
# LeftEye: 119, 191, RightEye: 191, 171
# LeftEye: 117, 190, RightEye: 190, 168
# LeftEye: 118, 189, RightEye: 191, 168
# LeftEye: 119, 187, RightEye: 192, 171
# LeftEye: 118, 186, RightEye: 192, 168
# LeftEye: 120, 187, RightEye: 192, 171
# LeftEye: 119, 185, RightEye: 192, 166
# LeftEye: 119, 180, RightEye: 193, 160
# LeftEye: 120, 180, RightEye: 195, 162
# LeftEye: 120, 184, RightEye: 193, 165
# LeftEye: 119, 187, RightEye: 191, 166
# LeftEye: 118, 190, RightEye: 190, 168
# LeftEye: 120, 187, RightEye: 192, 168
# LeftEye: 120, 191, RightEye: 191, 172
# LeftEye: 118, 192, RightEye: 187, 173
# LeftEye: 114, 192, RightEye: 187, 171
# LeftEye: 113, 191, RightEye: 186, 174
# LeftEye: 112, 193, RightEye: 185, 175
# LeftEye: 112, 194, RightEye: 186, 181
# LeftEye: 113, 200, RightEye: 183, 181
# LeftEye: 113, 200, RightEye: 185, 183
# LeftEye: 111, 198, RightEye: 185, 180
# LeftEye: 106, 196, RightEye: 185, 181
# LeftEye: 100, 201, RightEye: 177, 183
# LeftEye: 91, 204, RightEye: 171, 181
# LeftEye: 96, 213, RightEye: 172, 190
# LeftEye: 94, 211, RightEye: 171, 185
# LeftEye: 95, 210, RightEye: 173, 186
# LeftEye: 96, 205, RightEye: 174, 185
# LeftEye: 95, 213, RightEye: 171, 192
# LeftEye: 93, 214, RightEye: 166, 194
# LeftEye: 88, 210, RightEye: 163, 194
# LeftEye: 87, 209, RightEye: 159, 194
# LeftEye: 82, 216, RightEye: 155, 199
# LeftEye: 81, 217, RightEye: 153, 201
# LeftEye: 76, 214, RightEye: 153, 196
# LeftEye: 76, 213, RightEye: 154, 198
# LeftEye: 77, 214, RightEye: 154, 199
# LeftEye: 77, 216, RightEye: 153, 201
# LeftEye: 77, 219, RightEye: 151, 203
# LeftEye: 75, 222, RightEye: 151, 202
# LeftEye: 76, 216, RightEye: 150, 199
# LeftEye: 81, 217, RightEye: 151, 202
# LeftEye: 81, 217, RightEye: 151, 203
# LeftEye: 81, 218, RightEye: 151, 203
# LeftEye: 81, 217, RightEye: 153, 203
# LeftEye: 81, 216, RightEye: 153, 201
# LeftEye: 85, 214, RightEye: 159, 201
# LeftEye: 87, 213, RightEye: 164, 196
# LeftEye: 93, 217, RightEye: 169, 193
# LeftEye: 97, 218, RightEye: 173, 195
# LeftEye: 103, 217, RightEye: 178, 196
# LeftEye: 111, 217, RightEye: 185, 195
# LeftEye: 117, 216, RightEye: 187, 196
# LeftEye: 117, 209, RightEye: 192, 190
# LeftEye: 120, 211, RightEye: 193, 190
# LeftEye: 124, 209, RightEye: 200, 189
# LeftEye: 127, 208, RightEye: 204, 182
# LeftEye: 132, 211, RightEye: 209, 184
# LeftEye: 146, 210, RightEye: 220, 191
# LeftEye: 148, 205, RightEye: 225, 186
# LeftEye: 150, 204, RightEye: 226, 185
# LeftEye: 151, 204, RightEye: 228, 182
# LeftEye: 157, 208, RightEye: 232, 190
# LeftEye: 163, 204, RightEye: 238, 189
# LeftEye: 167, 209, RightEye: 239, 193
# LeftEye: 167, 211, RightEye: 238, 190
# LeftEye: 166, 209, RightEye: 239, 189
# LeftEye: 163, 210, RightEye: 237, 186
# LeftEye: 162, 210, RightEye: 238, 185
# LeftEye: 163, 211, RightEye: 239, 189
# LeftEye: 160, 205, RightEye: 239, 183
# LeftEye: 158, 211, RightEye: 234, 185
# LeftEye: 157, 213, RightEye: 232, 185
# LeftEye: 158, 216, RightEye: 231, 192
# LeftEye: 154, 204, RightEye: 229, 184
# LeftEye: 153, 204, RightEye: 226, 189
# LeftEye: 150, 203, RightEye: 226, 186
# LeftEye: 145, 211, RightEye: 221, 190
# LeftEye: 137, 221, RightEye: 208, 195
# LeftEye: 135, 213, RightEye: 207, 192
# LeftEye: 130, 214, RightEye: 203, 193
# LeftEye: 127, 219, RightEye: 201, 198
# LeftEye: 127, 219, RightEye: 196, 201
# LeftEye: 127, 210, RightEye: 199, 193
# LeftEye: 127, 211, RightEye: 200, 194
# LeftEye: 127, 210, RightEye: 199, 192
# LeftEye: 126, 214, RightEye: 199, 194
# LeftEye: 127, 214, RightEye: 199, 194
# LeftEye: 126, 214, RightEye: 198, 196
# LeftEye: 126, 217, RightEye: 195, 199
# LeftEye: 126, 213, RightEye: 196, 196
# LeftEye: 127, 213, RightEye: 199, 195
# LeftEye: 126, 216, RightEye: 198, 196
# LeftEye: 124, 211, RightEye: 198, 192
# LeftEye: 124, 209, RightEye: 199, 190
# LeftEye: 127, 208, RightEye: 200, 189
# LeftEye: 129, 209, RightEye: 201, 192
# LeftEye: 126, 210, RightEye: 199, 190
# LeftEye: 124, 209, RightEye: 199, 189
# LeftEye: 124, 208, RightEye: 200, 189
# LeftEye: 124, 204, RightEye: 199, 183
# LeftEye: 127, 207, RightEye: 200, 185
# LeftEye: 126, 205, RightEye: 202, 181
# LeftEye: 127, 210, RightEye: 201, 183
# LeftEye: 126, 208, RightEye: 202, 180
# LeftEye: 126, 207, RightEye: 201, 180
# LeftEye: 124, 207, RightEye: 202, 180
# LeftEye: 123, 202, RightEye: 199, 174
# LeftEye: 130, 202, RightEye: 202, 178
# LeftEye: 132, 201, RightEye: 204, 178
# LeftEye: 131, 202, RightEye: 202, 177
# LeftEye: 131, 200, RightEye: 201, 176
# LeftEye: 131, 196, RightEye: 202, 174
# LeftEye: 131, 199, RightEye: 202, 175
# LeftEye: 129, 199, RightEye: 199, 173
# LeftEye: 130, 198, RightEye: 201, 174
# LeftEye: 130, 198, RightEye: 199, 173
# LeftEye: 127, 200, RightEye: 199, 173
# LeftEye: 126, 200, RightEye: 196, 172
# LeftEye: 127, 193, RightEye: 198, 167
# LeftEye: 126, 192, RightEye: 198, 166
# LeftEye: 124, 192, RightEye: 199, 167
# LeftEye: 131, 193, RightEye: 198, 173
# LeftEye: 128, 189, RightEye: 195, 169
# LeftEye: 128, 185, RightEye: 196, 166
# LeftEye: 128, 185, RightEye: 196, 166
# LeftEye: 128, 185, RightEye: 196, 166
# LeftEye: 129, 190, RightEye: 195, 169
# LeftEye: 129, 189, RightEye: 195, 169
# LeftEye: 130, 190, RightEye: 195, 171
# LeftEye: 129, 189, RightEye: 195, 169
# LeftEye: 128, 189, RightEye: 195, 169
# LeftEye: 129, 189, RightEye: 196, 169
# LeftEye: 129, 190, RightEye: 196, 169
# LeftEye: 128, 189, RightEye: 196, 166
# LeftEye: 130, 190, RightEye: 196, 169
# LeftEye: 128, 185, RightEye: 195, 165
# LeftEye: 124, 189, RightEye: 191, 162
# LeftEye: 123, 182, RightEye: 196, 156
# LeftEye: 128, 183, RightEye: 196, 160
# LeftEye: 124, 182, RightEye: 196, 158
# LeftEye: 123, 182, RightEye: 196, 157
# LeftEye: 123, 181, RightEye: 195, 156
# LeftEye: 123, 180, RightEye: 196, 155
# LeftEye: 122, 180, RightEye: 196, 154
# LeftEye: 122, 181, RightEye: 195, 155
# LeftEye: 126, 182, RightEye: 193, 158
# LeftEye: 126, 182, RightEye: 193, 159
# LeftEye: 126, 182, RightEye: 193, 158
# LeftEye: 126, 182, RightEye: 193, 159
# LeftEye: 127, 183, RightEye: 195, 160
# LeftEye: 127, 183, RightEye: 196, 159
# LeftEye: 128, 182, RightEye: 196, 158
# LeftEye: 122, 181, RightEye: 196, 155
# LeftEye: 124, 181, RightEye: 196, 156
# LeftEye: 127, 183, RightEye: 193, 160
# LeftEye: 122, 182, RightEye: 194, 156
# LeftEye: 126, 182, RightEye: 193, 160
# LeftEye: 127, 183, RightEye: 193, 162
# LeftEye: 127, 183, RightEye: 193, 162
# LeftEye: 127, 183, RightEye: 193, 160
# LeftEye: 127, 183, RightEye: 193, 162
# LeftEye: 128, 183, RightEye: 193, 163
# LeftEye: 128, 183, RightEye: 193, 162
# LeftEye: 126, 184, RightEye: 192, 162
# LeftEye: 128, 184, RightEye: 195, 162
# LeftEye: 127, 184, RightEye: 192, 162
# LeftEye: 121, 183, RightEye: 194, 155
# LeftEye: 121, 183, RightEye: 194, 154
# LeftEye: 124, 183, RightEye: 192, 160
# LeftEye: 122, 182, RightEye: 194, 155
# LeftEye: 124, 183, RightEye: 192, 160
# LeftEye: 124, 183, RightEye: 192, 159
# LeftEye: 121, 182, RightEye: 194, 154
# LeftEye: 121, 183, RightEye: 193, 154
# LeftEye: 124, 183, RightEye: 192, 159
# LeftEye: 123, 185, RightEye: 190, 160
# LeftEye: 123, 184, RightEye: 190, 159
# LeftEye: 120, 183, RightEye: 190, 156
# LeftEye: 120, 186, RightEye: 187, 158
# LeftEye: 121, 189, RightEye: 186, 160
# LeftEye: 121, 185, RightEye: 187, 158
# LeftEye: 120, 184, RightEye: 189, 157
# LeftEye: 119, 181, RightEye: 190, 155
# LeftEye: 119, 182, RightEye: 189, 155
# LeftEye: 118, 183, RightEye: 187, 155
# LeftEye: 118, 182, RightEye: 189, 155
# LeftEye: 120, 181, RightEye: 190, 156
# LeftEye: 121, 184, RightEye: 189, 160
# LeftEye: 120, 185, RightEye: 189, 160
# LeftEye: 120, 184, RightEye: 189, 159
# LeftEye: 120, 184, RightEye: 189, 159
# LeftEye: 121, 184, RightEye: 189, 160
# LeftEye: 119, 182, RightEye: 189, 156
# LeftEye: 119, 181, RightEye: 189, 156
# LeftEye: 117, 182, RightEye: 187, 156
# LeftEye: 117, 180, RightEye: 189, 154
# LeftEye: 117, 181, RightEye: 187, 153
# LeftEye: 118, 184, RightEye: 186, 156
# LeftEye: 117, 183, RightEye: 186, 156
# LeftEye: 118, 183, RightEye: 186, 157
# LeftEye: 118, 184, RightEye: 185, 157
# LeftEye: 117, 185, RightEye: 185, 158
# LeftEye: 119, 185, RightEye: 187, 158
# LeftEye: 117, 184, RightEye: 185, 156
# LeftEye: 117, 182, RightEye: 186, 156
# LeftEye: 117, 184, RightEye: 186, 157
# LeftEye: 118, 184, RightEye: 186, 157
# LeftEye: 118, 183, RightEye: 186, 158
# LeftEye: 118, 184, RightEye: 186, 159
# LeftEye: 118, 185, RightEye: 186, 159
# LeftEye: 118, 184, RightEye: 186, 159
# LeftEye: 119, 186, RightEye: 186, 160
# LeftEye: 118, 182, RightEye: 187, 157
# LeftEye: 120, 184, RightEye: 187, 160
# LeftEye: 119, 183, RightEye: 189, 159
# LeftEye: 120, 186, RightEye: 187, 162
# LeftEye: 121, 185, RightEye: 187, 162
# LeftEye: 120, 189, RightEye: 186, 163
# LeftEye: 120, 189, RightEye: 186, 162
# LeftEye: 119, 190, RightEye: 186, 162
# LeftEye: 120, 191, RightEye: 186, 163
# LeftEye: 120, 190, RightEye: 187, 163
# LeftEye: 120, 186, RightEye: 187, 160
# LeftEye: 119, 184, RightEye: 189, 157
# LeftEye: 120, 185, RightEye: 189, 160
# LeftEye: 119, 185, RightEye: 189, 159
# LeftEye: 120, 185, RightEye: 191, 160
# LeftEye: 119, 184, RightEye: 191, 159
# LeftEye: 120, 183, RightEye: 191, 158
# LeftEye: 120, 184, RightEye: 190, 159
# LeftEye: 120, 185, RightEye: 190, 159
# LeftEye: 121, 184, RightEye: 190, 159
# LeftEye: 121, 184, RightEye: 191, 160
# LeftEye: 120, 185, RightEye: 190, 160
# LeftEye: 121, 185, RightEye: 191, 162
# LeftEye: 121, 185, RightEye: 190, 162
# LeftEye: 121, 185, RightEye: 191, 160
# LeftEye: 123, 185, RightEye: 191, 162
# LeftEye: 123, 186, RightEye: 191, 163
# LeftEye: 121, 184, RightEye: 191, 162
# LeftEye: 121, 184, RightEye: 191, 160
# LeftEye: 120, 183, RightEye: 191, 160
# LeftEye: 120, 184, RightEye: 191, 160
# LeftEye: 123, 186, RightEye: 190, 165
# LeftEye: 120, 185, RightEye: 190, 162
# LeftEye: 120, 190, RightEye: 187, 163
# LeftEye: 121, 192, RightEye: 187, 165
# LeftEye: 118, 191, RightEye: 186, 163
# LeftEye: 120, 190, RightEye: 189, 165
# LeftEye: 115, 193, RightEye: 183, 163
# LeftEye: 117, 192, RightEye: 185, 165
# LeftEye: 115, 191, RightEye: 185, 163
# LeftEye: 117, 192, RightEye: 185, 165
# LeftEye: 117, 192, RightEye: 185, 166
# LeftEye: 118, 194, RightEye: 185, 167
# LeftEye: 117, 192, RightEye: 184, 163
# LeftEye: 115, 191, RightEye: 185, 162
# LeftEye: 114, 191, RightEye: 184, 162
# LeftEye: 117, 198, RightEye: 183, 169
# LeftEye: 117, 198, RightEye: 183, 168
# LeftEye: 115, 198, RightEye: 181, 167
# LeftEye: 117, 199, RightEye: 181, 168
# LeftEye: 117, 198, RightEye: 181, 169
# LeftEye: 117, 198, RightEye: 183, 169
# LeftEye: 115, 196, RightEye: 181, 168
# LeftEye: 117, 198, RightEye: 183, 168
# LeftEye: 117, 196, RightEye: 184, 168
# LeftEye: 115, 196, RightEye: 184, 168
# LeftEye: 117, 198, RightEye: 183, 172
# LeftEye: 113, 196, RightEye: 181, 165
# LeftEye: 117, 193, RightEye: 183, 168
# LeftEye: 117, 195, RightEye: 183, 171
# LeftEye: 118, 193, RightEye: 185, 169
# LeftEye: 117, 193, RightEye: 187, 168
# LeftEye: 114, 189, RightEye: 190, 160
# LeftEye: 117, 184, RightEye: 189, 160
# LeftEye: 117, 181, RightEye: 190, 157
# LeftEye: 120, 181, RightEye: 192, 159
# LeftEye: 121, 183, RightEye: 191, 162
# LeftEye: 123, 183, RightEye: 191, 165
# LeftEye: 120, 183, RightEye: 190, 160
# LeftEye: 126, 183, RightEye: 192, 166
# LeftEye: 124, 183, RightEye: 193, 165
# LeftEye: 126, 183, RightEye: 193, 165
# LeftEye: 126, 181, RightEye: 195, 166
# LeftEye: 126, 180, RightEye: 199, 160
# LeftEye: 128, 178, RightEye: 198, 163
# LeftEye: 126, 181, RightEye: 199, 162
# LeftEye: 124, 177, RightEye: 201, 158
# LeftEye: 126, 172, RightEye: 205, 155
# LeftEye: 128, 171, RightEye: 202, 158
# LeftEye: 126, 173, RightEye: 204, 156
# LeftEye: 127, 174, RightEye: 207, 157
# LeftEye: 129, 174, RightEye: 207, 157
# LeftEye: 129, 173, RightEye: 207, 156
# LeftEye: 129, 173, RightEye: 208, 155
# LeftEye: 131, 171, RightEye: 209, 154
# LeftEye: 131, 171, RightEye: 208, 154
# LeftEye: 133, 169, RightEye: 209, 155
# LeftEye: 132, 169, RightEye: 210, 155
# LeftEye: 133, 172, RightEye: 210, 157
# LeftEye: 133, 172, RightEye: 210, 156
# LeftEye: 133, 171, RightEye: 210, 156
# LeftEye: 132, 174, RightEye: 209, 158
# LeftEye: 132, 175, RightEye: 208, 158
# LeftEye: 133, 175, RightEye: 208, 158
# LeftEye: 136, 174, RightEye: 210, 159
# LeftEye: 137, 172, RightEye: 211, 158
# LeftEye: 136, 172, RightEye: 213, 158
# LeftEye: 136, 172, RightEye: 211, 157
# LeftEye: 135, 171, RightEye: 211, 155
# LeftEye: 136, 177, RightEye: 210, 160
# LeftEye: 135, 180, RightEye: 209, 162
# LeftEye: 133, 178, RightEye: 208, 158
# LeftEye: 135, 180, RightEye: 208, 160
# LeftEye: 136, 180, RightEye: 208, 162
# LeftEye: 135, 178, RightEye: 208, 160
# LeftEye: 133, 178, RightEye: 208, 159
# LeftEye: 133, 177, RightEye: 209, 158
# LeftEye: 132, 173, RightEye: 209, 156
# LeftEye: 131, 177, RightEye: 208, 157
# LeftEye: 131, 177, RightEye: 207, 156
# LeftEye: 130, 175, RightEye: 207, 155
# LeftEye: 130, 175, RightEye: 207, 155
# LeftEye: 132, 175, RightEye: 207, 157
# LeftEye: 131, 175, RightEye: 207, 156
# LeftEye: 132, 173, RightEye: 208, 156
# LeftEye: 133, 175, RightEye: 208, 157
# LeftEye: 132, 173, RightEye: 209, 156
# LeftEye: 133, 175, RightEye: 208, 157
# LeftEye: 136, 173, RightEye: 210, 157
# LeftEye: 137, 175, RightEye: 210, 159
# LeftEye: 137, 174, RightEye: 211, 159
# LeftEye: 136, 173, RightEye: 211, 157
# LeftEye: 137, 180, RightEye: 209, 162
# LeftEye: 141, 177, RightEye: 211, 163
# LeftEye: 139, 174, RightEye: 211, 160
# LeftEye: 139, 174, RightEye: 211, 160
# LeftEye: 139, 175, RightEye: 211, 160
# LeftEye: 138, 175, RightEye: 211, 158
# LeftEye: 138, 174, RightEye: 210, 158
# LeftEye: 138, 172, RightEye: 213, 158
# LeftEye: 137, 175, RightEye: 210, 157
# LeftEye: 138, 172, RightEye: 211, 157
# LeftEye: 137, 171, RightEye: 211, 158
# LeftEye: 137, 174, RightEye: 211, 159
# LeftEye: 141, 168, RightEye: 217, 157
# LeftEye: 141, 168, RightEye: 217, 157
# LeftEye: 141, 171, RightEye: 217, 158
# LeftEye: 141, 172, RightEye: 217, 159
# LeftEye: 142, 171, RightEye: 218, 159
# LeftEye: 142, 171, RightEye: 218, 159
# LeftEye: 142, 169, RightEye: 219, 158
# LeftEye: 144, 171, RightEye: 219, 159
# LeftEye: 145, 173, RightEye: 218, 160
# LeftEye: 141, 172, RightEye: 218, 159
# LeftEye: 141, 174, RightEye: 218, 162
# LeftEye: 144, 173, RightEye: 219, 162
# LeftEye: 142, 169, RightEye: 218, 158
# LeftEye: 139, 169, RightEye: 216, 157
# LeftEye: 138, 166, RightEye: 216, 155
# LeftEye: 137, 166, RightEye: 216, 155
# LeftEye: 138, 167, RightEye: 216, 156
# LeftEye: 137, 168, RightEye: 213, 155
# LeftEye: 133, 168, RightEye: 213, 154
# LeftEye: 135, 167, RightEye: 213, 154
# LeftEye: 135, 166, RightEye: 214, 155
# LeftEye: 136, 166, RightEye: 214, 155
# LeftEye: 136, 167, RightEye: 213, 155
# LeftEye: 138, 167, RightEye: 214, 156
# LeftEye: 137, 169, RightEye: 213, 157
# LeftEye: 138, 167, RightEye: 211, 156
# LeftEye: 135, 168, RightEye: 210, 156
# LeftEye: 136, 168, RightEye: 210, 156
# LeftEye: 135, 169, RightEye: 210, 157
# LeftEye: 135, 168, RightEye: 211, 156
# LeftEye: 133, 167, RightEye: 211, 155
# LeftEye: 133, 167, RightEye: 211, 154
# LeftEye: 133, 167, RightEye: 211, 155
# LeftEye: 133, 168, RightEye: 211, 156
# LeftEye: 133, 168, RightEye: 210, 156
# LeftEye: 133, 168, RightEye: 210, 155
# LeftEye: 133, 168, RightEye: 210, 155
# LeftEye: 132, 171, RightEye: 209, 156
# LeftEye: 132, 168, RightEye: 210, 155
# LeftEye: 132, 169, RightEye: 210, 156
# LeftEye: 131, 168, RightEye: 209, 156
# LeftEye: 131, 169, RightEye: 209, 157
# LeftEye: 131, 169, RightEye: 209, 156
# LeftEye: 132, 168, RightEye: 210, 157
# LeftEye: 133, 168, RightEye: 210, 157
# LeftEye: 132, 169, RightEye: 210, 157
# LeftEye: 132, 171, RightEye: 209, 156
# LeftEye: 136, 169, RightEye: 211, 160
# LeftEye: 135, 169, RightEye: 210, 159
# LeftEye: 133, 169, RightEye: 208, 159
# LeftEye: 131, 172, RightEye: 207, 159
# LeftEye: 132, 169, RightEye: 208, 157
# LeftEye: 132, 172, RightEye: 208, 159
# LeftEye: 132, 174, RightEye: 208, 160
# LeftEye: 133, 174, RightEye: 208, 162
# LeftEye: 133, 175, RightEye: 207, 162
# LeftEye: 135, 174, RightEye: 208, 162
# LeftEye: 135, 174, RightEye: 208, 162
# LeftEye: 133, 174, RightEye: 209, 162
# LeftEye: 135, 174, RightEye: 208, 162
# LeftEye: 133, 178, RightEye: 207, 163
# LeftEye: 133, 180, RightEye: 207, 165
# LeftEye: 132, 181, RightEye: 205, 165
# LeftEye: 133, 178, RightEye: 207, 163
# LeftEye: 132, 181, RightEye: 205, 165
# LeftEye: 133, 182, RightEye: 205, 166
# LeftEye: 133, 183, RightEye: 204, 167
# LeftEye: 132, 183, RightEye: 203, 167
# LeftEye: 133, 180, RightEye: 205, 163
# LeftEye: 132, 183, RightEye: 204, 165
# LeftEye: 132, 182, RightEye: 204, 166
# LeftEye: 133, 183, RightEye: 203, 167
# LeftEye: 132, 185, RightEye: 202, 168
# LeftEye: 130, 182, RightEye: 203, 165
# LeftEye: 131, 181, RightEye: 203, 166
# LeftEye: 131, 182, RightEye: 203, 166
# LeftEye: 131, 181, RightEye: 203, 166
# LeftEye: 131, 184, RightEye: 202, 166
# LeftEye: 130, 182, RightEye: 203, 165
# LeftEye: 131, 182, RightEye: 203, 165
# LeftEye: 131, 181, RightEye: 204, 165
# LeftEye: 131, 180, RightEye: 204, 163
# LeftEye: 131, 182, RightEye: 203, 165
# LeftEye: 130, 183, RightEye: 203, 165
# LeftEye: 131, 183, RightEye: 203, 165
# LeftEye: 131, 184, RightEye: 203, 166
# LeftEye: 130, 184, RightEye: 202, 166
# LeftEye: 130, 183, RightEye: 203, 165
# LeftEye: 132, 184, RightEye: 203, 167
# LeftEye: 131, 184, RightEye: 203, 167
# LeftEye: 131, 183, RightEye: 203, 166
# LeftEye: 131, 183, RightEye: 203, 167
# LeftEye: 130, 183, RightEye: 203, 166
# LeftEye: 127, 182, RightEye: 202, 163
# LeftEye: 127, 183, RightEye: 201, 166
# LeftEye: 129, 184, RightEye: 201, 166
# LeftEye: 129, 183, RightEye: 202, 165
# LeftEye: 129, 184, RightEye: 201, 165
# LeftEye: 129, 185, RightEye: 201, 166
# LeftEye: 129, 190, RightEye: 199, 169
# LeftEye: 129, 190, RightEye: 199, 169
# LeftEye: 127, 190, RightEye: 199, 169
# LeftEye: 127, 190, RightEye: 198, 171
# LeftEye: 129, 190, RightEye: 199, 171
# LeftEye: 129, 184, RightEye: 201, 166
# LeftEye: 129, 184, RightEye: 201, 167
# LeftEye: 129, 185, RightEye: 199, 168
# LeftEye: 130, 185, RightEye: 201, 171
# LeftEye: 129, 190, RightEye: 199, 173
# LeftEye: 130, 185, RightEye: 202, 171
# LeftEye: 131, 185, RightEye: 202, 171
# LeftEye: 131, 189, RightEye: 201, 172
# LeftEye: 131, 189, RightEye: 201, 171
# LeftEye: 130, 185, RightEye: 201, 169
# LeftEye: 130, 184, RightEye: 202, 169
# LeftEye: 132, 184, RightEye: 202, 171
# LeftEye: 132, 186, RightEye: 201, 173
# LeftEye: 132, 186, RightEye: 202, 172
# LeftEye: 132, 189, RightEye: 201, 173
# LeftEye: 132, 186, RightEye: 201, 172
# LeftEye: 132, 186, RightEye: 198, 177
# LeftEye: 135, 190, RightEye: 196, 180
# LeftEye: 132, 191, RightEye: 198, 174
# LeftEye: 132, 190, RightEye: 196, 178
# LeftEye: 131, 186, RightEye: 196, 175
# LeftEye: 131, 185, RightEye: 199, 177
# LeftEye: 131, 186, RightEye: 198, 177
# LeftEye: 131, 185, RightEye: 199, 177
# LeftEye: 131, 189, RightEye: 198, 177
# LeftEye: 131, 189, RightEye: 196, 178
# LeftEye: 131, 189, RightEye: 196, 178
# LeftEye: 130, 186, RightEye: 195, 177
# LeftEye: 129, 189, RightEye: 195, 177
# LeftEye: 130, 186, RightEye: 195, 178
# LeftEye: 128, 186, RightEye: 193, 175
# LeftEye: 128, 189, RightEye: 192, 177
# LeftEye: 126, 189, RightEye: 191, 177
# LeftEye: 127, 189, RightEye: 191, 175
# LeftEye: 123, 190, RightEye: 189, 175
# LeftEye: 121, 191, RightEye: 190, 174
# LeftEye: 126, 189, RightEye: 191, 175
# LeftEye: 119, 196, RightEye: 185, 175
# LeftEye: 121, 195, RightEye: 186, 175
# LeftEye: 124, 191, RightEye: 187, 175
# LeftEye: 121, 193, RightEye: 185, 174
# LeftEye: 119, 195, RightEye: 184, 173
# LeftEye: 119, 193, RightEye: 184, 173
# LeftEye: 118, 196, RightEye: 183, 173
# LeftEye: 117, 195, RightEye: 181, 173
# LeftEye: 118, 196, RightEye: 184, 174
# LeftEye: 117, 198, RightEye: 181, 175
# LeftEye: 118, 198, RightEye: 181, 176
# LeftEye: 117, 198, RightEye: 181, 175
# LeftEye: 117, 195, RightEye: 181, 172
# LeftEye: 115, 196, RightEye: 178, 174
# LeftEye: 118, 193, RightEye: 186, 172
# LeftEye: 114, 196, RightEye: 181, 172
# LeftEye: 117, 191, RightEye: 184, 171
# LeftEye: 114, 192, RightEye: 183, 171
# LeftEye: 115, 192, RightEye: 183, 172
# LeftEye: 115, 192, RightEye: 183, 172
# LeftEye: 120, 193, RightEye: 185, 173
# LeftEye: 118, 193, RightEye: 184, 174
# LeftEye: 120, 192, RightEye: 185, 174
# LeftEye: 118, 195, RightEye: 185, 173
# LeftEye: 115, 195, RightEye: 184, 173
# LeftEye: 117, 200, RightEye: 184, 177
# LeftEye: 118, 199, RightEye: 184, 177
# LeftEye: 118, 198, RightEye: 185, 176
# LeftEye: 118, 196, RightEye: 185, 176
# LeftEye: 118, 196, RightEye: 184, 175
# LeftEye: 117, 196, RightEye: 184, 174
# LeftEye: 115, 193, RightEye: 185, 172
# LeftEye: 115, 192, RightEye: 185, 172
# LeftEye: 114, 196, RightEye: 183, 173
# LeftEye: 114, 196, RightEye: 183, 174
# LeftEye: 113, 195, RightEye: 183, 173
# LeftEye: 113, 191, RightEye: 184, 171
# LeftEye: 113, 191, RightEye: 184, 171
# LeftEye: 113, 192, RightEye: 183, 171
# LeftEye: 114, 190, RightEye: 185, 171
# LeftEye: 115, 186, RightEye: 186, 171
# LeftEye: 115, 189, RightEye: 186, 171
# LeftEye: 114, 189, RightEye: 186, 171
# LeftEye: 114, 190, RightEye: 185, 171
# LeftEye: 114, 192, RightEye: 184, 173
# LeftEye: 115, 191, RightEye: 185, 172
# LeftEye: 115, 190, RightEye: 186, 172
# LeftEye: 113, 190, RightEye: 184, 171
# LeftEye: 112, 191, RightEye: 183, 168
# LeftEye: 113, 192, RightEye: 184, 171
# LeftEye: 113, 192, RightEye: 184, 171
# LeftEye: 113, 191, RightEye: 184, 171
# LeftEye: 115, 190, RightEye: 185, 172
# LeftEye: 113, 190, RightEye: 184, 168
# LeftEye: 113, 191, RightEye: 184, 168
# LeftEye: 112, 191, RightEye: 183, 171
# LeftEye: 113, 192, RightEye: 183, 172
# LeftEye: 114, 193, RightEye: 184, 172
# LeftEye: 114, 195, RightEye: 183, 173
# LeftEye: 113, 192, RightEye: 183, 172
# LeftEye: 115, 191, RightEye: 184, 172
# LeftEye: 119, 190, RightEye: 186, 174
# LeftEye: 121, 195, RightEye: 186, 177
# LeftEye: 120, 195, RightEye: 186, 177
# LeftEye: 120, 196, RightEye: 185, 177
# LeftEye: 120, 193, RightEye: 186, 175
# LeftEye: 117, 193, RightEye: 185, 174
# LeftEye: 119, 190, RightEye: 187, 174
# LeftEye: 118, 189, RightEye: 190, 171
# LeftEye: 121, 189, RightEye: 189, 174
# LeftEye: 123, 189, RightEye: 189, 175
# LeftEye: 121, 189, RightEye: 189, 175
# LeftEye: 118, 192, RightEye: 189, 173
# LeftEye: 119, 191, RightEye: 190, 174
# LeftEye: 123, 186, RightEye: 192, 174
# LeftEye: 124, 189, RightEye: 192, 174
# LeftEye: 122, 190, RightEye: 191, 174
# LeftEye: 126, 186, RightEye: 190, 175
# LeftEye: 122, 185, RightEye: 193, 169
# LeftEye: 123, 184, RightEye: 194, 171
# LeftEye: 124, 185, RightEye: 194, 172
# LeftEye: 129, 185, RightEye: 195, 175
# LeftEye: 126, 185, RightEye: 195, 168
# LeftEye: 127, 184, RightEye: 198, 168
# LeftEye: 131, 184, RightEye: 199, 171
# LeftEye: 131, 189, RightEye: 199, 174
# LeftEye: 131, 190, RightEye: 195, 178
# LeftEye: 133, 190, RightEye: 199, 175
# LeftEye: 131, 189, RightEye: 201, 173
# LeftEye: 130, 190, RightEye: 201, 174
# LeftEye: 130, 191, RightEye: 199, 174
# LeftEye: 130, 191, RightEye: 199, 174
# LeftEye: 129, 192, RightEye: 199, 175
# LeftEye: 131, 192, RightEye: 201, 177
# LeftEye: 131, 195, RightEye: 201, 177
# LeftEye: 132, 191, RightEye: 202, 178
# LeftEye: 132, 193, RightEye: 199, 183
# LeftEye: 129, 186, RightEye: 201, 178
# LeftEye: 131, 184, RightEye: 203, 178
# LeftEye: 131, 185, RightEye: 201, 178
# LeftEye: 131, 189, RightEye: 198, 182
# LeftEye: 131, 185, RightEye: 201, 178
# LeftEye: 135, 189, RightEye: 200, 183
# LeftEye: 130, 189, RightEye: 199, 181
# LeftEye: 130, 184, RightEye: 201, 178
# LeftEye: 129, 189, RightEye: 198, 180
# LeftEye: 129, 191, RightEye: 195, 182
# LeftEye: 129, 190, RightEye: 196, 182
# LeftEye: 130, 186, RightEye: 199, 180
# LeftEye: 131, 190, RightEye: 196, 181
# LeftEye: 131, 192, RightEye: 199, 182
# LeftEye: 130, 194, RightEye: 196, 182
# LeftEye: 129, 192, RightEye: 196, 181
# LeftEye: 129, 192, RightEye: 196, 181
# LeftEye: 129, 191, RightEye: 198, 180
# LeftEye: 131, 189, RightEye: 199, 180
# LeftEye: 130, 189, RightEye: 198, 178
# LeftEye: 130, 190, RightEye: 196, 178
# LeftEye: 129, 192, RightEye: 196, 180
# LeftEye: 129, 194, RightEye: 196, 182
# LeftEye: 130, 192, RightEye: 198, 180
# LeftEye: 130, 189, RightEye: 198, 180
# LeftEye: 131, 190, RightEye: 198, 181
# LeftEye: 130, 191, RightEye: 196, 181
# LeftEye: 129, 191, RightEye: 195, 181
# LeftEye: 129, 190, RightEye: 195, 181
# LeftEye: 127, 190, RightEye: 194, 178
# LeftEye: 126, 189, RightEye: 194, 177
# LeftEye: 127, 190, RightEye: 195, 180
# LeftEye: 127, 191, RightEye: 194, 180
# LeftEye: 128, 191, RightEye: 193, 182
# LeftEye: 126, 190, RightEye: 194, 180
# LeftEye: 126, 190, RightEye: 194, 180
# LeftEye: 127, 190, RightEye: 192, 182
# LeftEye: 123, 192, RightEye: 191, 181
# LeftEye: 123, 187, RightEye: 191, 178
# LeftEye: 124, 187, RightEye: 191, 180
# LeftEye: 123, 189, RightEye: 191, 181
# LeftEye: 123, 184, RightEye: 192, 177
# LeftEye: 121, 190, RightEye: 189, 181
# LeftEye: 121, 190, RightEye: 186, 180
# LeftEye: 119, 190, RightEye: 186, 182
# LeftEye: 118, 190, RightEye: 184, 181
# LeftEye: 117, 194, RightEye: 181, 182
# LeftEye: 114, 198, RightEye: 178, 183
# LeftEye: 117, 196, RightEye: 180, 184
# LeftEye: 117, 195, RightEye: 183, 183
# LeftEye: 114, 196, RightEye: 180, 183
# LeftEye: 117, 196, RightEye: 178, 183
# LeftEye: 118, 195, RightEye: 180, 181
# LeftEye: 118, 194, RightEye: 183, 183
# LeftEye: 117, 191, RightEye: 181, 181
# LeftEye: 118, 191, RightEye: 184, 181
# LeftEye: 120, 191, RightEye: 183, 182
# LeftEye: 119, 191, RightEye: 183, 181
# LeftEye: 120, 190, RightEye: 184, 180
# LeftEye: 120, 190, RightEye: 184, 181
# LeftEye: 119, 192, RightEye: 183, 182
# LeftEye: 120, 192, RightEye: 183, 182
# LeftEye: 120, 192, RightEye: 185, 181
# LeftEye: 121, 191, RightEye: 186, 181
# LeftEye: 120, 189, RightEye: 187, 180
# LeftEye: 119, 190, RightEye: 189, 177
# LeftEye: 123, 190, RightEye: 190, 181
# LeftEye: 124, 191, RightEye: 192, 182
# LeftEye: 126, 189, RightEye: 193, 182
# LeftEye: 126, 191, RightEye: 192, 181
# LeftEye: 128, 189, RightEye: 198, 181
# LeftEye: 128, 189, RightEye: 198, 182
# LeftEye: 131, 189, RightEye: 199, 181
# LeftEye: 130, 189, RightEye: 198, 182
# LeftEye: 129, 190, RightEye: 198, 180
# LeftEye: 129, 186, RightEye: 198, 180
# LeftEye: 131, 186, RightEye: 199, 180
# LeftEye: 130, 193, RightEye: 196, 181
# LeftEye: 132, 193, RightEye: 201, 181
# LeftEye: 135, 199, RightEye: 198, 190
# LeftEye: 132, 200, RightEye: 195, 189
# LeftEye: 136, 196, RightEye: 201, 186
# LeftEye: 135, 199, RightEye: 201, 189
# LeftEye: 133, 203, RightEye: 199, 189
# LeftEye: 133, 204, RightEye: 199, 190
# LeftEye: 136, 202, RightEye: 201, 189
# LeftEye: 136, 203, RightEye: 199, 189
# LeftEye: 133, 207, RightEye: 195, 189
# LeftEye: 133, 207, RightEye: 195, 190
# LeftEye: 133, 204, RightEye: 195, 190
# LeftEye: 135, 204, RightEye: 195, 194
# LeftEye: 131, 204, RightEye: 194, 187
# LeftEye: 131, 203, RightEye: 195, 190
# LeftEye: 130, 202, RightEye: 195, 184
# LeftEye: 131, 199, RightEye: 195, 185
# LeftEye: 132, 198, RightEye: 198, 185
# LeftEye: 133, 198, RightEye: 198, 185
# LeftEye: 130, 199, RightEye: 196, 184
# LeftEye: 131, 199, RightEye: 196, 185
# LeftEye: 131, 199, RightEye: 196, 186
# LeftEye: 132, 198, RightEye: 198, 186
# LeftEye: 132, 201, RightEye: 195, 185
# LeftEye: 130, 201, RightEye: 193, 185
# LeftEye: 131, 199, RightEye: 196, 185
# LeftEye: 132, 199, RightEye: 196, 185
# LeftEye: 131, 203, RightEye: 192, 185
# LeftEye: 129, 203, RightEye: 192, 186
# LeftEye: 129, 204, RightEye: 191, 186
# LeftEye: 131, 203, RightEye: 195, 190
# LeftEye: 129, 205, RightEye: 191, 189
# LeftEye: 128, 205, RightEye: 191, 191
# LeftEye: 126, 204, RightEye: 187, 189
# LeftEye: 124, 203, RightEye: 186, 186
# LeftEye: 124, 203, RightEye: 186, 189
# LeftEye: 123, 203, RightEye: 186, 184
# LeftEye: 120, 207, RightEye: 185, 184
# LeftEye: 120, 207, RightEye: 185, 184
# LeftEye: 123, 203, RightEye: 186, 185
# LeftEye: 124, 204, RightEye: 186, 186
# LeftEye: 127, 205, RightEye: 189, 190
# LeftEye: 129, 209, RightEye: 189, 194
# LeftEye: 129, 208, RightEye: 190, 192
# LeftEye: 129, 202, RightEye: 190, 186
# LeftEye: 131, 204, RightEye: 192, 191
# LeftEye: 129, 203, RightEye: 191, 186
# LeftEye: 131, 203, RightEye: 193, 190
# LeftEye: 130, 204, RightEye: 192, 191
# LeftEye: 124, 202, RightEye: 189, 185
# LeftEye: 128, 207, RightEye: 187, 190
# LeftEye: 124, 209, RightEye: 185, 192
# LeftEye: 124, 210, RightEye: 185, 195
# LeftEye: 124, 209, RightEye: 186, 192
# LeftEye: 123, 210, RightEye: 184, 189
# LeftEye: 123, 208, RightEye: 184, 189
# LeftEye: 124, 208, RightEye: 183, 190
# LeftEye: 121, 207, RightEye: 184, 189
# LeftEye: 121, 207, RightEye: 183, 187
# LeftEye: 118, 208, RightEye: 181, 187
# LeftEye: 117, 209, RightEye: 178, 189
# LeftEye: 114, 210, RightEye: 177, 187
# LeftEye: 114, 209, RightEye: 177, 186
# LeftEye: 114, 208, RightEye: 177, 184
# LeftEye: 114, 208, RightEye: 178, 185
# LeftEye: 112, 212, RightEye: 176, 185
# LeftEye: 111, 213, RightEye: 176, 185
# LeftEye: 111, 210, RightEye: 176, 183
# LeftEye: 112, 210, RightEye: 175, 184
# LeftEye: 111, 210, RightEye: 175, 183
# LeftEye: 111, 209, RightEye: 176, 183
# LeftEye: 113, 210, RightEye: 176, 186
# LeftEye: 113, 213, RightEye: 175, 187
# LeftEye: 112, 211, RightEye: 177, 185
# LeftEye: 115, 210, RightEye: 178, 186
# LeftEye: 113, 210, RightEye: 177, 184
# LeftEye: 113, 209, RightEye: 178, 185
# LeftEye: 113, 211, RightEye: 178, 187
# LeftEye: 114, 211, RightEye: 177, 187
# LeftEye: 113, 208, RightEye: 178, 185
# LeftEye: 114, 204, RightEye: 178, 184
# LeftEye: 115, 203, RightEye: 181, 185
# LeftEye: 117, 201, RightEye: 181, 185
# LeftEye: 117, 198, RightEye: 181, 183
# LeftEye: 117, 196, RightEye: 183, 181
# LeftEye: 118, 198, RightEye: 183, 184
# LeftEye: 115, 195, RightEye: 183, 178
# LeftEye: 117, 193, RightEye: 183, 178
# LeftEye: 118, 193, RightEye: 183, 180
# LeftEye: 120, 193, RightEye: 184, 184
# LeftEye: 120, 195, RightEye: 184, 185
# LeftEye: 121, 195, RightEye: 184, 183
# LeftEye: 121, 194, RightEye: 185, 184
# LeftEye: 124, 195, RightEye: 185, 186
# LeftEye: 121, 196, RightEye: 184, 185
# LeftEye: 121, 194, RightEye: 187, 183
# LeftEye: 121, 200, RightEye: 184, 186
# LeftEye: 120, 200, RightEye: 185, 186
# LeftEye: 123, 198, RightEye: 186, 185
# LeftEye: 124, 200, RightEye: 185, 187
# LeftEye: 126, 198, RightEye: 190, 185
# LeftEye: 126, 195, RightEye: 190, 183
# LeftEye: 126, 194, RightEye: 190, 183
# LeftEye: 126, 199, RightEye: 189, 187
# LeftEye: 126, 199, RightEye: 187, 187
# LeftEye: 124, 196, RightEye: 187, 185
# LeftEye: 122, 195, RightEye: 186, 184
# LeftEye: 121, 198, RightEye: 186, 185
# LeftEye: 123, 196, RightEye: 186, 185
# LeftEye: 120, 199, RightEye: 185, 187
# LeftEye: 118, 200, RightEye: 184, 186
# LeftEye: 119, 202, RightEye: 184, 189
# LeftEye: 118, 201, RightEye: 184, 189
# LeftEye: 115, 201, RightEye: 181, 187
# LeftEye: 118, 207, RightEye: 181, 191
# LeftEye: 118, 204, RightEye: 181, 191
# LeftEye: 117, 203, RightEye: 180, 189
# LeftEye: 115, 201, RightEye: 180, 186
# LeftEye: 112, 202, RightEye: 180, 184
# LeftEye: 108, 207, RightEye: 175, 185
# LeftEye: 109, 209, RightEye: 174, 190
# LeftEye: 109, 209, RightEye: 173, 190
# LeftEye: 106, 208, RightEye: 171, 187
# LeftEye: 101, 207, RightEye: 167, 187
# LeftEye: 102, 211, RightEye: 166, 192
# LeftEye: 102, 209, RightEye: 167, 191
# LeftEye: 102, 210, RightEye: 168, 191
# LeftEye: 102, 213, RightEye: 167, 196
# LeftEye: 99, 214, RightEye: 165, 196
# LeftEye: 99, 216, RightEye: 163, 199
# LeftEye: 99, 222, RightEye: 164, 207
# LeftEye: 95, 221, RightEye: 163, 203
# LeftEye: 93, 220, RightEye: 162, 202
# LeftEye: 92, 226, RightEye: 156, 204
# LeftEye: 93, 228, RightEye: 159, 208
# LeftEye: 93, 230, RightEye: 156, 210
# LeftEye: 94, 234, RightEye: 157, 210
# LeftEye: 93, 232, RightEye: 156, 209
# LeftEye: 92, 231, RightEye: 155, 209
# LeftEye: 93, 228, RightEye: 156, 207
# LeftEye: 91, 231, RightEye: 153, 208
# LeftEye: 90, 231, RightEye: 153, 205
# LeftEye: 87, 231, RightEye: 153, 208
# LeftEye: 87, 231, RightEye: 154, 208
# LeftEye: 92, 237, RightEye: 154, 216
# LeftEye: 92, 232, RightEye: 155, 213
# LeftEye: 92, 235, RightEye: 154, 213
# LeftEye: 93, 234, RightEye: 155, 214
# LeftEye: 91, 240, RightEye: 157, 221
# LeftEye: 91, 240, RightEye: 159, 219
# ...
# LeftEye: 119, 200, RightEye: 187, 178
# LeftEye: 119, 196, RightEye: 187, 181
# LeftEye: 123, 201, RightEye: 187, 183
# LeftEye: 120, 198, RightEye: 187, 182
# LeftEye: 123, 200, RightEye: 189, 183
# LeftEye: 124, 201, RightEye: 190, 181
# LeftEye: 127, 202, RightEye: 193, 185
# LeftEye: 127, 202, RightEye: 195, 186
# LeftEye: 126, 204, RightEye: 193, 185
# LeftEye: 129, 203, RightEye: 195, 186
# LeftEye: 128, 204, RightEye: 195, 186
# LeftEye: 127, 204, RightEye: 195, 186
# LeftEye: 128, 201, RightEye: 198, 184
# LeftEye: 131, 200, RightEye: 198, 181
# LeftEye: 130, 203, RightEye: 196, 183
# LeftEye: 131, 202, RightEye: 201, 183
# LeftEye: 131, 202, RightEye: 201, 183
# LeftEye: 130, 203, RightEye: 199, 183
# LeftEye: 131, 202, RightEye: 201, 183
# LeftEye: 131, 204, RightEye: 198, 187
# LeftEye: 130, 204, RightEye: 196, 186
# LeftEye: 130, 208, RightEye: 198, 186
# LeftEye: 128, 202, RightEye: 195, 184
# LeftEye: 128, 200, RightEye: 195, 181
# LeftEye: 126, 203, RightEye: 192, 183
# LeftEye: 124, 203, RightEye: 191, 183
# LeftEye: 126, 205, RightEye: 191, 185
# LeftEye: 123, 204, RightEye: 189, 181
# LeftEye: 123, 209, RightEye: 189, 186
# LeftEye: 120, 213, RightEye: 184, 187
# LeftEye: 120, 214, RightEye: 185, 192
# LeftEye: 121, 211, RightEye: 184, 187
# LeftEye: 117, 212, RightEye: 180, 185
# LeftEye: 115, 213, RightEye: 177, 185
# LeftEye: 110, 209, RightEye: 178, 181
# LeftEye: 112, 211, RightEye: 174, 181
# LeftEye: 111, 212, RightEye: 173, 181
# LeftEye: 109, 214, RightEye: 174, 184
# LeftEye: 105, 212, RightEye: 174, 183
# LeftEye: 105, 212, RightEye: 174, 183
# LeftEye: 106, 211, RightEye: 174, 180
# LeftEye: 106, 210, RightEye: 174, 181
# LeftEye: 105, 211, RightEye: 174, 180
# LeftEye: 105, 214, RightEye: 171, 185
# LeftEye: 105, 211, RightEye: 171, 180
# LeftEye: 105, 210, RightEye: 172, 181
# LeftEye: 106, 211, RightEye: 173, 183
# LeftEye: 108, 210, RightEye: 174, 181
# LeftEye: 106, 210, RightEye: 174, 181
# LeftEye: 109, 209, RightEye: 175, 181
# LeftEye: 111, 209, RightEye: 175, 184
# LeftEye: 112, 210, RightEye: 176, 185
# LeftEye: 112, 204, RightEye: 178, 183
# LeftEye: 114, 201, RightEye: 181, 181
# LeftEye: 114, 201, RightEye: 181, 181
# LeftEye: 117, 195, RightEye: 184, 182
# LeftEye: 114, 199, RightEye: 183, 180
# LeftEye: 119, 195, RightEye: 189, 181
# LeftEye: 119, 192, RightEye: 191, 178
# LeftEye: 120, 191, RightEye: 192, 178
# LeftEye: 124, 190, RightEye: 193, 183
# LeftEye: 127, 189, RightEye: 195, 184
# LeftEye: 127, 189, RightEye: 195, 181
# LeftEye: 127, 189, RightEye: 195, 181
# LeftEye: 126, 189, RightEye: 195, 178
# LeftEye: 128, 184, RightEye: 196, 180
# LeftEye: 128, 185, RightEye: 196, 180
# LeftEye: 128, 186, RightEye: 196, 180
# LeftEye: 129, 185, RightEye: 199, 181
# LeftEye: 131, 186, RightEye: 199, 182
# LeftEye: 131, 185, RightEye: 202, 180
# LeftEye: 130, 185, RightEye: 198, 181
# LeftEye: 131, 186, RightEye: 199, 181
# LeftEye: 131, 190, RightEye: 199, 181
# LeftEye: 135, 190, RightEye: 201, 184
# LeftEye: 135, 191, RightEye: 199, 185
# LeftEye: 135, 190, RightEye: 199, 183
# LeftEye: 136, 191, RightEye: 200, 185
# LeftEye: 136, 191, RightEye: 203, 184
# LeftEye: 135, 185, RightEye: 203, 180
# LeftEye: 135, 191, RightEye: 199, 184
# LeftEye: 136, 189, RightEye: 203, 181
# LeftEye: 132, 190, RightEye: 200, 181
# LeftEye: 135, 189, RightEye: 203, 180
# LeftEye: 135, 190, RightEye: 203, 182
# LeftEye: 136, 189, RightEye: 204, 181
# LeftEye: 136, 189, RightEye: 203, 181
# LeftEye: 136, 189, RightEye: 204, 181
# LeftEye: 138, 192, RightEye: 204, 183
# LeftEye: 137, 190, RightEye: 201, 185
# LeftEye: 137, 190, RightEye: 201, 184
# LeftEye: 135, 190, RightEye: 203, 180
# LeftEye: 136, 191, RightEye: 203, 183
# LeftEye: 136, 190, RightEye: 204, 182
# LeftEye: 137, 190, RightEye: 201, 185
# LeftEye: 137, 192, RightEye: 204, 183
# LeftEye: 137, 193, RightEye: 203, 183
# LeftEye: 136, 192, RightEye: 203, 182
# LeftEye: 136, 194, RightEye: 200, 184
# LeftEye: 137, 195, RightEye: 200, 185
# LeftEye: 137, 194, RightEye: 200, 185
# LeftEye: 135, 196, RightEye: 201, 184
# LeftEye: 133, 194, RightEye: 202, 182
# LeftEye: 135, 192, RightEye: 203, 181
# LeftEye: 132, 191, RightEye: 200, 181
# LeftEye: 135, 191, RightEye: 201, 182
# LeftEye: 137, 195, RightEye: 199, 185
# LeftEye: 137, 192, RightEye: 200, 184
# LeftEye: 136, 193, RightEye: 200, 184
# LeftEye: 137, 194, RightEye: 200, 185
# LeftEye: 133, 193, RightEye: 202, 182
# LeftEye: 132, 191, RightEye: 199, 182
# LeftEye: 135, 192, RightEye: 200, 184
# LeftEye: 135, 192, RightEye: 199, 184
# LeftEye: 133, 194, RightEye: 201, 183
# LeftEye: 136, 192, RightEye: 200, 184
# LeftEye: 136, 193, RightEye: 200, 186
# LeftEye: 133, 193, RightEye: 202, 181
# LeftEye: 136, 195, RightEye: 196, 186
# LeftEye: 133, 196, RightEye: 199, 183
# LeftEye: 136, 195, RightEye: 201, 183
# LeftEye: 137, 191, RightEye: 200, 184
# LeftEye: 136, 192, RightEye: 200, 184
# LeftEye: 136, 193, RightEye: 199, 184
# LeftEye: 135, 191, RightEye: 199, 183
# LeftEye: 133, 194, RightEye: 201, 181
# LeftEye: 136, 193, RightEye: 198, 184
# LeftEye: 131, 191, RightEye: 196, 181
# LeftEye: 132, 191, RightEye: 202, 177
# LeftEye: 135, 190, RightEye: 204, 180
# LeftEye: 135, 189, RightEye: 205, 177
# LeftEye: 133, 191, RightEye: 203, 177
# LeftEye: 132, 190, RightEye: 203, 175
# LeftEye: 132, 191, RightEye: 204, 177
# LeftEye: 135, 191, RightEye: 204, 178
# LeftEye: 132, 191, RightEye: 203, 177
# LeftEye: 133, 193, RightEye: 202, 181
# LeftEye: 135, 193, RightEye: 203, 181
# LeftEye: 135, 193, RightEye: 203, 182
# LeftEye: 133, 193, RightEye: 203, 180
# LeftEye: 136, 192, RightEye: 201, 182
# LeftEye: 133, 191, RightEye: 204, 180
# LeftEye: 133, 191, RightEye: 204, 180
# LeftEye: 135, 191, RightEye: 204, 180
# LeftEye: 136, 192, RightEye: 205, 181
# LeftEye: 137, 193, RightEye: 205, 181
# LeftEye: 137, 194, RightEye: 204, 182
# LeftEye: 139, 190, RightEye: 209, 182
# LeftEye: 139, 189, RightEye: 209, 183
# LeftEye: 138, 189, RightEye: 205, 184
# LeftEye: 139, 190, RightEye: 208, 183
# LeftEye: 139, 191, RightEye: 208, 184
# LeftEye: 139, 190, RightEye: 204, 185
# LeftEye: 138, 190, RightEye: 203, 184
# LeftEye: 138, 190, RightEye: 204, 184
# LeftEye: 136, 193, RightEye: 205, 184
# LeftEye: 136, 192, RightEye: 205, 182
# LeftEye: 135, 189, RightEye: 205, 178
# LeftEye: 135, 186, RightEye: 205, 177
# LeftEye: 135, 189, RightEye: 205, 177
# LeftEye: 133, 190, RightEye: 204, 177
# LeftEye: 135, 190, RightEye: 202, 181
# LeftEye: 133, 189, RightEye: 204, 177
# LeftEye: 133, 189, RightEye: 204, 177
# LeftEye: 135, 189, RightEye: 204, 175
# LeftEye: 135, 190, RightEye: 204, 177
# LeftEye: 136, 190, RightEye: 204, 178
# LeftEye: 136, 186, RightEye: 207, 177
# LeftEye: 136, 186, RightEye: 203, 180
# LeftEye: 136, 186, RightEye: 205, 177
# LeftEye: 136, 186, RightEye: 203, 180
# LeftEye: 135, 189, RightEye: 205, 178
# LeftEye: 135, 189, RightEye: 204, 178
# LeftEye: 135, 185, RightEye: 201, 178
# LeftEye: 135, 191, RightEye: 202, 178
# LeftEye: 136, 192, RightEye: 200, 183
# LeftEye: 135, 190, RightEye: 204, 178
# LeftEye: 135, 191, RightEye: 203, 180
# LeftEye: 133, 192, RightEye: 203, 180
# LeftEye: 135, 191, RightEye: 200, 183
# LeftEye: 136, 192, RightEye: 200, 184
# LeftEye: 133, 195, RightEye: 203, 180
# LeftEye: 135, 192, RightEye: 199, 183
# LeftEye: 136, 192, RightEye: 199, 183
# LeftEye: 135, 198, RightEye: 201, 180
# LeftEye: 137, 195, RightEye: 201, 183
# LeftEye: 136, 192, RightEye: 203, 180
# LeftEye: 135, 193, RightEye: 203, 180
# LeftEye: 139, 196, RightEye: 203, 185
# LeftEye: 139, 201, RightEye: 202, 189
# LeftEye: 138, 193, RightEye: 200, 186
# LeftEye: 136, 192, RightEye: 199, 184
# LeftEye: 137, 193, RightEye: 199, 186
# LeftEye: 137, 192, RightEye: 198, 185
# LeftEye: 135, 190, RightEye: 198, 181
# LeftEye: 136, 191, RightEye: 198, 182
# LeftEye: 139, 192, RightEye: 198, 184
# LeftEye: 139, 191, RightEye: 199, 184
# LeftEye: 138, 190, RightEye: 196, 182
# LeftEye: 138, 191, RightEye: 195, 184
# LeftEye: 141, 195, RightEye: 198, 184
# LeftEye: 138, 192, RightEye: 195, 184
# LeftEye: 139, 190, RightEye: 198, 182
# LeftEye: 138, 186, RightEye: 196, 180
# LeftEye: 136, 186, RightEye: 195, 178
# LeftEye: 135, 186, RightEye: 201, 171
# LeftEye: 137, 186, RightEye: 201, 172
# LeftEye: 132, 185, RightEye: 199, 168
# LeftEye: 133, 185, RightEye: 199, 169
# LeftEye: 135, 183, RightEye: 196, 173
# LeftEye: 135, 184, RightEye: 201, 168
# LeftEye: 132, 182, RightEye: 198, 171
# LeftEye: 135, 178, RightEye: 199, 168
# LeftEye: 137, 182, RightEye: 196, 172
# LeftEye: 136, 176, RightEye: 201, 167
# LeftEye: 135, 180, RightEye: 199, 167
# LeftEye: 135, 181, RightEye: 199, 167
# LeftEye: 136, 178, RightEye: 198, 169
# LeftEye: 135, 177, RightEye: 199, 168
# LeftEye: 135, 177, RightEye: 198, 168
# LeftEye: 135, 174, RightEye: 199, 166
# LeftEye: 136, 174, RightEye: 199, 167
# LeftEye: 136, 175, RightEye: 199, 168
# LeftEye: 136, 175, RightEye: 200, 167
# LeftEye: 135, 177, RightEye: 199, 168
# LeftEye: 132, 175, RightEye: 199, 167
# LeftEye: 132, 177, RightEye: 198, 167
# LeftEye: 132, 173, RightEye: 200, 165
# LeftEye: 132, 169, RightEye: 201, 160
# LeftEye: 132, 171, RightEye: 201, 162
# LeftEye: 132, 172, RightEye: 201, 162
# LeftEye: 132, 173, RightEye: 199, 165
# LeftEye: 131, 172, RightEye: 199, 162
# LeftEye: 131, 174, RightEye: 198, 165
# LeftEye: 130, 171, RightEye: 198, 160
# LeftEye: 131, 172, RightEye: 199, 162
# LeftEye: 131, 173, RightEye: 198, 163
# LeftEye: 131, 172, RightEye: 199, 162
# LeftEye: 131, 172, RightEye: 198, 163
# LeftEye: 130, 171, RightEye: 198, 160
# LeftEye: 129, 172, RightEye: 196, 162
# LeftEye: 130, 171, RightEye: 198, 162
# LeftEye: 130, 173, RightEye: 196, 163
# LeftEye: 131, 175, RightEye: 196, 166
# LeftEye: 132, 178, RightEye: 196, 167
# LeftEye: 131, 175, RightEye: 198, 166
# LeftEye: 130, 174, RightEye: 199, 163
# LeftEye: 130, 178, RightEye: 198, 165
# LeftEye: 130, 178, RightEye: 198, 166
# LeftEye: 131, 177, RightEye: 198, 167
# LeftEye: 131, 178, RightEye: 198, 167
# LeftEye: 131, 178, RightEye: 196, 168
# LeftEye: 131, 180, RightEye: 196, 169
# LeftEye: 129, 177, RightEye: 196, 166
# LeftEye: 130, 175, RightEye: 198, 167
# LeftEye: 129, 177, RightEye: 196, 166
# LeftEye: 129, 178, RightEye: 196, 167
# LeftEye: 129, 177, RightEye: 196, 166
# LeftEye: 129, 177, RightEye: 196, 166
# LeftEye: 131, 177, RightEye: 196, 168
# LeftEye: 129, 178, RightEye: 195, 168
# LeftEye: 130, 178, RightEye: 196, 168
# LeftEye: 130, 180, RightEye: 195, 168
# LeftEye: 130, 177, RightEye: 196, 167
# LeftEye: 129, 178, RightEye: 195, 167
# LeftEye: 129, 178, RightEye: 195, 167
# LeftEye: 129, 180, RightEye: 195, 167
# LeftEye: 127, 177, RightEye: 193, 165
# LeftEye: 128, 177, RightEye: 195, 166
# LeftEye: 127, 177, RightEye: 195, 165
# LeftEye: 128, 178, RightEye: 195, 165
# LeftEye: 129, 174, RightEye: 198, 165
# LeftEye: 127, 174, RightEye: 196, 163
# LeftEye: 128, 175, RightEye: 195, 165
# LeftEye: 128, 175, RightEye: 195, 165
# LeftEye: 128, 175, RightEye: 198, 163
# LeftEye: 128, 174, RightEye: 198, 165
# LeftEye: 128, 177, RightEye: 196, 165
# LeftEye: 127, 171, RightEye: 196, 157
# LeftEye: 128, 172, RightEye: 196, 159
# LeftEye: 128, 173, RightEye: 196, 159
# LeftEye: 128, 173, RightEye: 196, 159
# LeftEye: 128, 173, RightEye: 196, 159
# LeftEye: 127, 173, RightEye: 195, 159
# LeftEye: 127, 172, RightEye: 196, 159
# LeftEye: 127, 174, RightEye: 195, 159
# LeftEye: 127, 174, RightEye: 195, 159
# LeftEye: 127, 174, RightEye: 195, 159
# LeftEye: 127, 173, RightEye: 195, 159
# LeftEye: 127, 173, RightEye: 196, 159
# LeftEye: 127, 172, RightEye: 196, 158
# LeftEye: 127, 173, RightEye: 195, 159
# LeftEye: 128, 173, RightEye: 198, 160
# LeftEye: 128, 173, RightEye: 196, 160
# LeftEye: 128, 174, RightEye: 196, 160
# LeftEye: 127, 174, RightEye: 195, 160
# LeftEye: 129, 172, RightEye: 198, 159
# LeftEye: 124, 174, RightEye: 199, 155
# LeftEye: 127, 173, RightEye: 195, 158
# LeftEye: 127, 173, RightEye: 196, 158
# LeftEye: 124, 174, RightEye: 198, 155
# LeftEye: 127, 172, RightEye: 196, 159
# LeftEye: 127, 173, RightEye: 195, 159
# LeftEye: 126, 174, RightEye: 195, 159
# LeftEye: 126, 175, RightEye: 195, 160
# LeftEye: 122, 173, RightEye: 198, 155
# LeftEye: 126, 174, RightEye: 196, 159
# LeftEye: 126, 174, RightEye: 195, 159
# LeftEye: 127, 175, RightEye: 195, 160
# LeftEye: 126, 175, RightEye: 195, 160
# LeftEye: 127, 177, RightEye: 195, 160
# LeftEye: 127, 177, RightEye: 193, 162
# LeftEye: 127, 177, RightEye: 195, 162
# LeftEye: 124, 175, RightEye: 198, 157
# LeftEye: 127, 175, RightEye: 195, 160
# LeftEye: 124, 177, RightEye: 196, 157
# LeftEye: 124, 177, RightEye: 196, 157
# LeftEye: 127, 174, RightEye: 195, 159
# LeftEye: 128, 174, RightEye: 196, 160
# LeftEye: 127, 173, RightEye: 195, 160
# LeftEye: 126, 174, RightEye: 195, 159
# LeftEye: 127, 173, RightEye: 196, 159
# LeftEye: 127, 169, RightEye: 196, 157
# LeftEye: 127, 171, RightEye: 196, 158
# LeftEye: 127, 171, RightEye: 198, 158
# LeftEye: 128, 173, RightEye: 196, 160
# LeftEye: 123, 174, RightEye: 198, 155
# LeftEye: 123, 174, RightEye: 196, 155
# LeftEye: 126, 175, RightEye: 193, 160
# LeftEye: 123, 175, RightEye: 196, 155
# LeftEye: 124, 175, RightEye: 193, 159
# LeftEye: 123, 174, RightEye: 196, 155
# LeftEye: 126, 174, RightEye: 193, 158
# LeftEye: 127, 174, RightEye: 193, 159
# LeftEye: 126, 174, RightEye: 193, 158
# LeftEye: 126, 174, RightEye: 193, 158
# LeftEye: 122, 174, RightEye: 196, 154
# LeftEye: 122, 174, RightEye: 196, 154
# LeftEye: 126, 172, RightEye: 195, 156
# LeftEye: 126, 172, RightEye: 195, 156
# LeftEye: 126, 173, RightEye: 195, 157
# LeftEye: 126, 174, RightEye: 195, 158
# LeftEye: 127, 173, RightEye: 195, 157
# LeftEye: 127, 173, RightEye: 195, 157
# LeftEye: 126, 172, RightEye: 193, 157
# LeftEye: 127, 171, RightEye: 195, 156
# LeftEye: 126, 174, RightEye: 193, 157
# LeftEye: 126, 174, RightEye: 192, 158
# LeftEye: 126, 174, RightEye: 192, 156
# LeftEye: 126, 174, RightEye: 192, 157
# LeftEye: 126, 174, RightEye: 193, 157
# LeftEye: 126, 174, RightEye: 192, 156
# LeftEye: 126, 174, RightEye: 192, 157
# LeftEye: 126, 173, RightEye: 193, 157
# LeftEye: 126, 173, RightEye: 193, 157
# LeftEye: 126, 173, RightEye: 193, 157
# LeftEye: 126, 177, RightEye: 192, 159
# LeftEye: 126, 177, RightEye: 191, 159
# LeftEye: 126, 177, RightEye: 191, 160
# LeftEye: 127, 177, RightEye: 191, 159
# LeftEye: 126, 177, RightEye: 191, 160
# LeftEye: 126, 177, RightEye: 191, 162
# LeftEye: 126, 178, RightEye: 191, 162
# LeftEye: 126, 180, RightEye: 190, 163
# LeftEye: 126, 178, RightEye: 190, 160
# LeftEye: 126, 178, RightEye: 190, 160
# LeftEye: 124, 175, RightEye: 191, 158
# LeftEye: 126, 175, RightEye: 191, 159
# LeftEye: 126, 175, RightEye: 191, 159
# LeftEye: 126, 177, RightEye: 191, 160
# LeftEye: 126, 175, RightEye: 192, 158
# LeftEye: 124, 174, RightEye: 191, 158
# LeftEye: 126, 175, RightEye: 192, 159
# LeftEye: 124, 175, RightEye: 192, 158
# LeftEye: 126, 175, RightEye: 191, 159
# LeftEye: 124, 175, RightEye: 191, 158
# LeftEye: 124, 175, RightEye: 191, 158
# LeftEye: 124, 175, RightEye: 191, 158
# LeftEye: 127, 175, RightEye: 192, 159
# LeftEye: 126, 175, RightEye: 192, 158
# LeftEye: 126, 174, RightEye: 192, 158
# LeftEye: 126, 174, RightEye: 192, 157
# LeftEye: 126, 174, RightEye: 192, 156
# LeftEye: 126, 174, RightEye: 192, 157
# LeftEye: 126, 174, RightEye: 192, 156
# LeftEye: 126, 174, RightEye: 192, 157
# LeftEye: 124, 177, RightEye: 191, 158
# LeftEye: 126, 177, RightEye: 192, 158
# LeftEye: 126, 178, RightEye: 192, 158
# LeftEye: 126, 177, RightEye: 192, 158
# LeftEye: 126, 177, RightEye: 192, 158
# LeftEye: 127, 177, RightEye: 192, 159
# LeftEye: 126, 175, RightEye: 192, 157
# LeftEye: 124, 174, RightEye: 192, 157
# LeftEye: 126, 178, RightEye: 191, 158
# LeftEye: 126, 178, RightEye: 191, 159
# LeftEye: 127, 178, RightEye: 192, 158
# LeftEye: 126, 178, RightEye: 191, 158
# LeftEye: 129, 178, RightEye: 193, 165
# LeftEye: 130, 178, RightEye: 193, 165
# LeftEye: 130, 180, RightEye: 193, 167
# LeftEye: 129, 178, RightEye: 192, 166
# LeftEye: 130, 178, RightEye: 193, 166
# LeftEye: 129, 177, RightEye: 193, 165
# LeftEye: 130, 177, RightEye: 193, 165
# LeftEye: 129, 177, RightEye: 193, 163
# LeftEye: 129, 177, RightEye: 193, 163
# LeftEye: 130, 177, RightEye: 195, 165
# LeftEye: 130, 178, RightEye: 193, 165
# LeftEye: 129, 177, RightEye: 193, 163
# LeftEye: 128, 174, RightEye: 193, 159
# LeftEye: 128, 174, RightEye: 193, 159
# LeftEye: 129, 175, RightEye: 193, 160
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/darkice/miniconda3/envs/pyside6rknn/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
a = []
print( a.)
